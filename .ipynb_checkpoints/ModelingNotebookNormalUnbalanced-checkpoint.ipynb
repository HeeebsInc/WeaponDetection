# %% [markdown]
# ## CNN

# %%
import numpy as np 
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten 
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, AveragePooling2D
from keras.optimizers import Adam
from keras import regularizers
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
import pickle
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
from PyFunctions import Functions as func
from PyFunctions import var
from PyFunctions import Viz
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using plaidml.keras.backend backend.

# %% [markdown]
# ### CNN Model
# - The function below will compile and return a CNN model given the input dimensions
# - Categorical Crossentropy was used because the model is used to predict between three classes (0 = No Weapon, 1 = Handgun, 2 = Rifle)
# - Softmax output was used because this is a ternary classification problem
# - To ensure that training continued for more than 20 epochs
# - Dimension for thie model is optimized at (150, 150, 1)
# - All visualization functions can be found in the Viz.py file within the PyFunctions folder

# %%
#change edge parameter to false if you are using a non edges train_test_split
edge = False
x_train, x_test, y_train, y_test = func.get_samples('normal', edge = edge)
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (6062, 150, 150, 3) (674, 150, 150, 3)
# (6062, 3) (674, 3)

# %% [markdown]
# - Running the cell below will show you what the input images look like.
# - Creating these images used a gaussian filter that outline the edges within a photo
# - Using this approach allowed the algorithm to learn distinctive shapes between weapons

# %%
import cv2 

cv2.imshow('test', x_train[1000])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def get_conv_model_normal(dim):
    '''This function will create and compile a CNN given the input dimension'''
    inp_shape = dim
    act = 'relu'
    drop = .25
    kernal_reg = regularizers.l1(.001)
    optimizer = Adam(lr = .0001)
    
    model = Sequential() 
    
    model.add(Conv2D(64, kernel_size=(3,3),activation=act, input_shape = inp_shape, 
                     kernel_regularizer = kernal_reg,
                     kernel_initializer = 'he_uniform',  padding = 'same', name = 'Input_Layer'))
    model.add(MaxPooling2D(pool_size=(2, 2),  strides = (3,3)))
    
    
    model.add(Conv2D(64, (3, 3), activation=act, kernel_regularizer = kernal_reg, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = (3,3)))
    

    
    model.add(Conv2D(128, (3, 3), activation=act, kernel_regularizer = kernal_reg, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(Conv2D(128, (3, 3), activation=act, kernel_regularizer = kernal_reg, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = (3,3)))

    
    model.add(Flatten())

    
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))

    model.add(Dropout(drop))

    model.add(Dense(3, activation='softmax', name = 'Output_Layer'))
    
    model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])
    return model

# %% [markdown]
# # With Augmentation
# - First started with augmentation of each image to determine if this would make the accuracy better

# %%
early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=10, min_delta = .00075)
model_checkpoint = ModelCheckpoint('ModelWeights/NormalUnbalancedAugment.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 2, mode = 'min')
epochs = 1000
batch_size = 32

if edge == True: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
    
normal_model = get_conv_model_normal(dim =dim)


augmentation =ImageDataGenerator(rotation_range = 20, width_shift_range = .2, height_shift_range = .2, 
                                                       horizontal_flip = True, shear_range = .15, 
                                 fill_mode = 'nearest', zoom_range = .15)
augmentation.fit(x_train)
normal_history = normal_model.fit_generator(augmentation.flow(x_train, y_train, batch_size = batch_size),
            epochs = epochs, 
     callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
# Out:
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"
# Epoch 1/1000
#  44/190 [=====>........................] - ETA: 55s - loss: 12.0415 - acc: 0.4489
# INFO:plaidml:Analyzing Ops: 90 of 422 operations complete
# 190/190 [==============================] - 56s 295ms/step - loss: 10.6895 - acc: 0.5857 - val_loss: 9.0195 - val_acc: 0.7136
#
# Epoch 00001: val_loss improved from inf to 9.01948, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 2/1000
# 190/190 [==============================] - 32s 168ms/step - loss: 7.9004 - acc: 0.6734 - val_loss: 6.8501 - val_acc: 0.7047
#
# Epoch 00002: val_loss improved from 9.01948 to 6.85011, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 3/1000
# 190/190 [==============================] - 32s 168ms/step - loss: 6.0854 - acc: 0.6993 - val_loss: 5.5027 - val_acc: 0.5979
#
# Epoch 00003: val_loss improved from 6.85011 to 5.50271, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 4/1000
# 190/190 [==============================] - 32s 168ms/step - loss: 4.9183 - acc: 0.7112 - val_loss: 4.4300 - val_acc: 0.7596
#
# Epoch 00004: val_loss improved from 5.50271 to 4.43000, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 5/1000
# 190/190 [==============================] - 32s 166ms/step - loss: 4.1868 - acc: 0.7204 - val_loss: 3.9293 - val_acc: 0.6929
#
# Epoch 00005: val_loss improved from 4.43000 to 3.92932, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 6/1000
# 190/190 [==============================] - 32s 168ms/step - loss: 3.7425 - acc: 0.7377 - val_loss: 3.5478 - val_acc: 0.7552
#
# Epoch 00006: val_loss improved from 3.92932 to 3.54785, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 7/1000
# 190/190 [==============================] - 32s 167ms/step - loss: 3.4582 - acc: 0.7320 - val_loss: 3.3365 - val_acc: 0.7374
#
# Epoch 00007: val_loss improved from 3.54785 to 3.33649, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 8/1000
# 190/190 [==============================] - 32s 166ms/step - loss: 3.2259 - acc: 0.7397 - val_loss: 3.0809 - val_acc: 0.7359
#
# Epoch 00008: val_loss improved from 3.33649 to 3.08086, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 9/1000
# 190/190 [==============================] - 31s 166ms/step - loss: 3.0368 - acc: 0.7364 - val_loss: 2.9852 - val_acc: 0.7181
#
# Epoch 00009: val_loss improved from 3.08086 to 2.98518, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 10/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 2.8669 - acc: 0.7405 - val_loss: 2.7518 - val_acc: 0.7596
#
# Epoch 00010: val_loss improved from 2.98518 to 2.75175, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 11/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 2.7196 - acc: 0.7453 - val_loss: 2.7265 - val_acc: 0.6766
#
# Epoch 00011: val_loss improved from 2.75175 to 2.72650, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 12/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 2.5922 - acc: 0.7464 - val_loss: 2.5096 - val_acc: 0.7433
#
# Epoch 00012: val_loss improved from 2.72650 to 2.50960, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 13/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 2.4851 - acc: 0.7480 - val_loss: 2.3418 - val_acc: 0.7760
#
# Epoch 00013: val_loss improved from 2.50960 to 2.34182, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 14/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 2.3776 - acc: 0.7521 - val_loss: 2.2745 - val_acc: 0.7730
#
# Epoch 00014: val_loss improved from 2.34182 to 2.27450, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 15/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 2.2869 - acc: 0.7522 - val_loss: 2.1602 - val_acc: 0.7774
#
# Epoch 00015: val_loss improved from 2.27450 to 2.16015, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 16/1000
# 190/190 [==============================] - 32s 166ms/step - loss: 2.1971 - acc: 0.7510 - val_loss: 2.0806 - val_acc: 0.7908
#
# Epoch 00016: val_loss improved from 2.16015 to 2.08061, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 17/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 2.1215 - acc: 0.7552 - val_loss: 2.1050 - val_acc: 0.7211
#
# Epoch 00017: val_loss did not improve from 2.08061
# Epoch 18/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 2.0565 - acc: 0.7507 - val_loss: 1.9928 - val_acc: 0.7685
#
# Epoch 00018: val_loss improved from 2.08061 to 1.99280, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 19/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.9815 - acc: 0.7585 - val_loss: 1.8777 - val_acc: 0.7908
#
# Epoch 00019: val_loss improved from 1.99280 to 1.87771, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 20/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.9316 - acc: 0.7583 - val_loss: 1.8911 - val_acc: 0.7611
#
# Epoch 00020: val_loss did not improve from 1.87771
# Epoch 21/1000
# 190/190 [==============================] - 32s 168ms/step - loss: 1.8748 - acc: 0.7567 - val_loss: 1.7655 - val_acc: 0.7953
#
# Epoch 00021: val_loss improved from 1.87771 to 1.76554, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 22/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.8365 - acc: 0.7487 - val_loss: 1.7617 - val_acc: 0.7730
#
# Epoch 00022: val_loss improved from 1.76554 to 1.76173, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 23/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.7723 - acc: 0.7610 - val_loss: 1.7495 - val_acc: 0.7344
#
# Epoch 00023: val_loss improved from 1.76173 to 1.74947, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 24/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.7253 - acc: 0.7577 - val_loss: 1.6277 - val_acc: 0.7908
#
# Epoch 00024: val_loss improved from 1.74947 to 1.62767, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 25/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.6788 - acc: 0.7684 - val_loss: 1.6416 - val_acc: 0.7641
#
# Epoch 00025: val_loss did not improve from 1.62767
# Epoch 26/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.6574 - acc: 0.7582 - val_loss: 1.6013 - val_acc: 0.7507
#
# Epoch 00026: val_loss improved from 1.62767 to 1.60127, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 27/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.6319 - acc: 0.7536 - val_loss: 1.5463 - val_acc: 0.7745
#
# Epoch 00027: val_loss improved from 1.60127 to 1.54634, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 28/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.5768 - acc: 0.7621 - val_loss: 1.5855 - val_acc: 0.7418
#
# Epoch 00028: val_loss did not improve from 1.54634
# Epoch 29/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.5467 - acc: 0.7671 - val_loss: 1.4674 - val_acc: 0.7849
#
# Epoch 00029: val_loss improved from 1.54634 to 1.46741, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 30/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.5167 - acc: 0.7680 - val_loss: 1.5347 - val_acc: 0.7359
#
# Epoch 00030: val_loss did not improve from 1.46741
# Epoch 31/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.4927 - acc: 0.7614 - val_loss: 1.4160 - val_acc: 0.7908
#
# Epoch 00031: val_loss improved from 1.46741 to 1.41598, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 32/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.4600 - acc: 0.7698 - val_loss: 1.4507 - val_acc: 0.7567
#
# Epoch 00032: val_loss did not improve from 1.41598
# Epoch 33/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.4594 - acc: 0.7652 - val_loss: 1.3704 - val_acc: 0.7878
# Epoch 00033: val_loss improved from 1.41598 to 1.37037, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 34/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.4149 - acc: 0.7657 - val_loss: 1.4187 - val_acc: 0.7418
#
# Epoch 00034: val_loss did not improve from 1.37037
# Epoch 35/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.3927 - acc: 0.7643 - val_loss: 1.3142 - val_acc: 0.7923
#
# Epoch 00035: val_loss improved from 1.37037 to 1.31420, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 36/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.3695 - acc: 0.7745 - val_loss: 1.2822 - val_acc: 0.7982
#
# Epoch 00036: val_loss improved from 1.31420 to 1.28216, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 37/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.3495 - acc: 0.7725 - val_loss: 1.2641 - val_acc: 0.7982
#
# Epoch 00037: val_loss improved from 1.28216 to 1.26411, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 38/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.3299 - acc: 0.7687 - val_loss: 1.2524 - val_acc: 0.7997
#
# Epoch 00038: val_loss improved from 1.26411 to 1.25242, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 39/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.3146 - acc: 0.7737 - val_loss: 1.2890 - val_acc: 0.7700
#
# Epoch 00039: val_loss did not improve from 1.25242
# Epoch 40/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.2982 - acc: 0.7757 - val_loss: 1.2352 - val_acc: 0.7760
#
# Epoch 00040: val_loss improved from 1.25242 to 1.23524, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 41/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.2787 - acc: 0.7735 - val_loss: 1.2005 - val_acc: 0.7878
#
# Epoch 00041: val_loss improved from 1.23524 to 1.20048, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 42/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.2630 - acc: 0.7780 - val_loss: 1.1916 - val_acc: 0.7849
#
# Epoch 00042: val_loss improved from 1.20048 to 1.19160, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 43/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.2534 - acc: 0.7679 - val_loss: 1.1717 - val_acc: 0.7893
#
# Epoch 00043: val_loss improved from 1.19160 to 1.17167, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 44/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.2192 - acc: 0.7772 - val_loss: 1.1626 - val_acc: 0.7938
#
# Epoch 00044: val_loss improved from 1.17167 to 1.16260, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 45/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.2033 - acc: 0.7833 - val_loss: 1.1524 - val_acc: 0.7804
#
# Epoch 00045: val_loss improved from 1.16260 to 1.15236, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 46/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.2012 - acc: 0.7816 - val_loss: 1.1422 - val_acc: 0.7938
#
# Epoch 00046: val_loss improved from 1.15236 to 1.14219, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 47/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.1874 - acc: 0.7814 - val_loss: 1.1997 - val_acc: 0.7552
#
# Epoch 00047: val_loss did not improve from 1.14219
# Epoch 48/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.1787 - acc: 0.7777 - val_loss: 1.1146 - val_acc: 0.7849
#
# Epoch 00048: val_loss improved from 1.14219 to 1.11457, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 49/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.1661 - acc: 0.7811 - val_loss: 1.0921 - val_acc: 0.7864
#
# Epoch 00049: val_loss improved from 1.11457 to 1.09208, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 50/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.1513 - acc: 0.7836 - val_loss: 1.1317 - val_acc: 0.7730
#
# Epoch 00050: val_loss did not improve from 1.09208
# Epoch 51/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.1387 - acc: 0.7785 - val_loss: 1.0758 - val_acc: 0.7864
#
# Epoch 00051: val_loss improved from 1.09208 to 1.07575, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 52/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.1192 - acc: 0.7923 - val_loss: 1.0937 - val_acc: 0.7849
#
# Epoch 00052: val_loss did not improve from 1.07575
# Epoch 53/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.1205 - acc: 0.7814 - val_loss: 1.0752 - val_acc: 0.7745
#
# Epoch 00053: val_loss improved from 1.07575 to 1.07522, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 54/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.1042 - acc: 0.7810 - val_loss: 1.0768 - val_acc: 0.7834
#
# Epoch 00054: val_loss did not improve from 1.07522
# Epoch 55/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.0991 - acc: 0.7861 - val_loss: 1.0320 - val_acc: 0.7908
#
# Epoch 00055: val_loss improved from 1.07522 to 1.03204, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 56/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.0837 - acc: 0.7915 - val_loss: 1.0880 - val_acc: 0.7700
#
# Epoch 00056: val_loss did not improve from 1.03204
# Epoch 57/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.0691 - acc: 0.7899 - val_loss: 1.0167 - val_acc: 0.7938
#
# Epoch 00057: val_loss improved from 1.03204 to 1.01672, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 58/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.0644 - acc: 0.7888 - val_loss: 1.0164 - val_acc: 0.7760
#
# Epoch 00058: val_loss improved from 1.01672 to 1.01641, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 59/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.0571 - acc: 0.7877 - val_loss: 1.0021 - val_acc: 0.8086
#
# Epoch 00059: val_loss improved from 1.01641 to 1.00211, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 60/1000
# 190/190 [==============================] - 31s 164ms/step - loss: 1.0451 - acc: 0.7925 - val_loss: 1.0171 - val_acc: 0.7804
#
# Epoch 00060: val_loss did not improve from 1.00211
# Epoch 61/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.0388 - acc: 0.7836 - val_loss: 1.0659 - val_acc: 0.7374
#
# Epoch 00061: val_loss did not improve from 1.00211
# Epoch 62/1000
# 190/190 [==============================] - 32s 166ms/step - loss: 1.0141 - acc: 0.7994 - val_loss: 0.9893 - val_acc: 0.7804
#
# Epoch 00062: val_loss improved from 1.00211 to 0.98932, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 63/1000
# 190/190 [==============================] - 32s 167ms/step - loss: 1.0099 - acc: 0.7976 - val_loss: 0.9933 - val_acc: 0.7804
#
# Epoch 00063: val_loss did not improve from 0.98932
# Epoch 64/1000
# 190/190 [==============================] - 32s 166ms/step - loss: 1.0074 - acc: 0.8004 - val_loss: 0.9785 - val_acc: 0.7878
#
# Epoch 00064: val_loss improved from 0.98932 to 0.97853, saving model to ModelWeights/NormalCNN-ModelCheckpointWeightsAugment.h5
# Epoch 65/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.0014 - acc: 0.8005 - val_loss: 0.9864 - val_acc: 0.7834
#
# Epoch 00065: val_loss did not improve from 0.97853
# Epoch 66/1000
# 190/190 [==============================] - 32s 166ms/step - loss: 1.0031 - acc: 0.8035 - val_loss: 0.9795 - val_acc: 0.7938
#
# Epoch 00066: val_loss did not improve from 0.97853
# Epoch 67/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.0026 - acc: 0.8028 - val_loss: 0.9791 - val_acc: 0.7908
#
# Epoch 00067: val_loss did not improve from 0.97853
# Epoch 68/1000
# 190/190 [==============================] - 31s 165ms/step - loss: 1.0043 - acc: 0.7940 - val_loss: 0.9800 - val_acc: 0.7893
#
# Epoch 00068: val_loss did not improve from 0.97853
# Epoch 69/1000
# 190/190 [==============================] - 32s 167ms/step - loss: 1.0025 - acc: 0.8015 - val_loss: 0.9798 - val_acc: 0.7893
#
# Epoch 00069: val_loss did not improve from 0.97853
# Epoch 70/1000
# 190/190 [==============================] - 32s 171ms/step - loss: 1.0037 - acc: 0.7979 - val_loss: 0.9797 - val_acc: 0.7893
#
# Epoch 00070: val_loss did not improve from 0.97853
# Epoch 71/1000
# 190/190 [==============================] - 32s 167ms/step - loss: 1.0131 - acc: 0.7965 - val_loss: 0.9797 - val_acc: 0.7893
#
# Epoch 00071: val_loss did not improve from 0.97853
# Epoch 72/1000
# 190/190 [==============================] - 32s 166ms/step - loss: 0.9988 - acc: 0.7960 - val_loss: 0.9796 - val_acc: 0.7893
#
# Epoch 00072: val_loss did not improve from 0.97853
# Epoch 73/1000
# 190/190 [==============================] - 32s 166ms/step - loss: 1.0000 - acc: 0.8018 - val_loss: 0.9796 - val_acc: 0.7893
#
# Epoch 00073: val_loss did not improve from 0.97853
# Epoch 74/1000
# 190/190 [==============================] - 32s 166ms/step - loss: 0.9998 - acc: 0.8025 - val_loss: 0.9796 - val_acc: 0.7893
#
# Epoch 00074: val_loss did not improve from 0.97853
# Epoch 00074: early stopping

# %%
# print(normal_model.summary())

# %% [markdown]
# ### Loss & Accuracy With Augment

# %%
Viz.plot_loss_accuracy(normal_history, 'dark_background')

# %% [markdown]
# ### AUC and ROC Curves With Augment

# %%
if edge == True: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
    
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('ModelWeights/NormalUnbalancedAugment.h5') #load the best weights before overfitting
 


Viz.plot_roc_auc(normal_model, x_test, y_test, 'dark_background')
# Out:
# F1 Scores Test
# ~~~~~~~~~~~~~~~~~~~~~~
# No Weapon: 0.9039301310043669
# HandGun: 0.7763157894736842
# Rifle: 0.624113475177305

# %% [markdown]
# ### Confusion Matrix With Augment

# %%
if edge == True: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
        
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('ModelWeights/NormalUnbalancedAugment.h5') #load the best weights before overfitting





y_test_prob = [np.argmax(i) for i in normal_model.predict(x_test)]
y_test_labels = [np.argmax(
    i) for i in y_test]
test_cnf = confusion_matrix(y_test_labels, y_test_prob)

y_train_prob = [np.argmax(i) for i in normal_model.predict(x_train)]
y_train_labels = [np.argmax(i) for i in y_train]
train_cnf = confusion_matrix(y_train_labels, y_train_prob)

Viz.plot_model_cm(test_cnf, train_cnf, classes = ['No Weapon', 'Handgun', 'Rifle'], theme = 'dark_background', 
                  )

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-a871fdc9ebee> in <module>
# ----> 1 assert False
#
# AssertionError:

# %% [markdown]
# # No Augmention

# %%
early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=10, min_delta = .00075)
model_checkpoint = ModelCheckpoint('ModelWeights/NormalUnbalancedNoAugment.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 2, mode = 'min')
epochs = 1000
batch_size = 32

if edge == True: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
    
normal_model = get_conv_model_normal(dim =dim)


normal_history = normal_model.fit(x_train, y_train, batch_size = batch_size,
            epochs = epochs, 
     callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
# Out:
# Train on 6062 samples, validate on 674 samples
# Epoch 1/1000
# 6062/6062 [==============================] - 56s 9ms/step - loss: 10.7804 - acc: 0.6095 - val_loss: 9.2580 - val_acc: 0.7493
#
# Epoch 00001: val_loss improved from inf to 9.25804, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 2/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 8.1984 - acc: 0.7206 - val_loss: 7.2201 - val_acc: 0.7285
#
# Epoch 00002: val_loss improved from 9.25804 to 7.22008, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 3/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 6.5022 - acc: 0.7550 - val_loss: 5.7951 - val_acc: 0.7893
#
# Epoch 00003: val_loss improved from 7.22008 to 5.79512, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 4/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 5.3627 - acc: 0.7646 - val_loss: 4.9592 - val_acc: 0.7685
#
# Epoch 00004: val_loss improved from 5.79512 to 4.95916, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 5/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 4.6404 - acc: 0.7755 - val_loss: 4.3783 - val_acc: 0.7938
#
# Epoch 00005: val_loss improved from 4.95916 to 4.37834, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 6/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 4.1792 - acc: 0.7880 - val_loss: 3.9828 - val_acc: 0.7982
#
# Epoch 00006: val_loss improved from 4.37834 to 3.98282, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 7/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 3.8477 - acc: 0.8016 - val_loss: 3.7110 - val_acc: 0.8101
#
# Epoch 00007: val_loss improved from 3.98282 to 3.71101, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 8/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 3.6124 - acc: 0.8025 - val_loss: 3.4812 - val_acc: 0.7982
#
# Epoch 00008: val_loss improved from 3.71101 to 3.48124, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 9/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 3.3819 - acc: 0.8086 - val_loss: 3.3085 - val_acc: 0.7953
#
# Epoch 00009: val_loss improved from 3.48124 to 3.30853, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 10/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 3.2058 - acc: 0.8101 - val_loss: 3.1056 - val_acc: 0.8042
#
# Epoch 00010: val_loss improved from 3.30853 to 3.10562, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 11/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 3.0450 - acc: 0.8073 - val_loss: 2.9974 - val_acc: 0.7819
#
# Epoch 00011: val_loss improved from 3.10562 to 2.99744, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 12/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 2.8816 - acc: 0.8162 - val_loss: 2.8344 - val_acc: 0.8042
#
# Epoch 00012: val_loss improved from 2.99744 to 2.83435, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 13/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 2.7453 - acc: 0.8197 - val_loss: 2.7192 - val_acc: 0.7982
#
# Epoch 00013: val_loss improved from 2.83435 to 2.71919, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 14/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 2.6142 - acc: 0.8312 - val_loss: 2.6358 - val_acc: 0.7685
#
# Epoch 00014: val_loss improved from 2.71919 to 2.63578, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 15/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 2.4870 - acc: 0.8423 - val_loss: 2.5020 - val_acc: 0.8131
#
# Epoch 00015: val_loss improved from 2.63578 to 2.50200, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 16/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 2.3931 - acc: 0.8423 - val_loss: 2.4173 - val_acc: 0.8086
#
# Epoch 00016: val_loss improved from 2.50200 to 2.41728, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 17/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 2.3184 - acc: 0.8372 - val_loss: 2.3065 - val_acc: 0.8175
#
# Epoch 00017: val_loss improved from 2.41728 to 2.30652, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 18/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 2.2042 - acc: 0.8507 - val_loss: 2.2578 - val_acc: 0.8145
#
# Epoch 00018: val_loss improved from 2.30652 to 2.25781, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 19/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 2.1249 - acc: 0.8593 - val_loss: 2.1925 - val_acc: 0.7819
#
# Epoch 00019: val_loss improved from 2.25781 to 2.19248, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 20/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 2.0503 - acc: 0.8557 - val_loss: 2.1124 - val_acc: 0.8116
#
# Epoch 00020: val_loss improved from 2.19248 to 2.11245, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 21/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.9776 - acc: 0.8654 - val_loss: 2.0279 - val_acc: 0.8071
#
# Epoch 00021: val_loss improved from 2.11245 to 2.02788, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 22/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.9071 - acc: 0.8718 - val_loss: 1.9972 - val_acc: 0.8086
#
# Epoch 00022: val_loss improved from 2.02788 to 1.99725, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 23/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.8445 - acc: 0.8788 - val_loss: 1.9324 - val_acc: 0.8205
#
# Epoch 00023: val_loss improved from 1.99725 to 1.93239, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 24/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.7937 - acc: 0.8783 - val_loss: 1.9186 - val_acc: 0.7938
#
# Epoch 00024: val_loss improved from 1.93239 to 1.91856, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 25/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.7252 - acc: 0.8868 - val_loss: 1.8377 - val_acc: 0.8220
#
# Epoch 00025: val_loss improved from 1.91856 to 1.83766, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 26/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.6742 - acc: 0.8931 - val_loss: 1.7985 - val_acc: 0.8160
#
# Epoch 00026: val_loss improved from 1.83766 to 1.79850, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 27/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.6347 - acc: 0.8949 - val_loss: 1.7911 - val_acc: 0.7967
#
# Epoch 00027: val_loss improved from 1.79850 to 1.79111, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 28/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 1.5866 - acc: 0.8989 - val_loss: 1.7374 - val_acc: 0.8264
#
# Epoch 00028: val_loss improved from 1.79111 to 1.73737, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 29/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.5404 - acc: 0.9027 - val_loss: 1.7197 - val_acc: 0.8071
#
# Epoch 00029: val_loss improved from 1.73737 to 1.71969, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 30/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.4905 - acc: 0.9121 - val_loss: 1.6892 - val_acc: 0.8131
#
# Epoch 00030: val_loss improved from 1.71969 to 1.68923, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 31/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.4649 - acc: 0.9147 - val_loss: 1.6851 - val_acc: 0.8116
#
# Epoch 00031: val_loss improved from 1.68923 to 1.68514, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 32/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.4101 - acc: 0.9253 - val_loss: 1.6314 - val_acc: 0.8309
#
# Epoch 00032: val_loss improved from 1.68514 to 1.63145, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 33/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.3619 - acc: 0.9348 - val_loss: 1.5999 - val_acc: 0.8249
#
# Epoch 00033: val_loss improved from 1.63145 to 1.59988, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 34/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.3480 - acc: 0.9264 - val_loss: 1.5798 - val_acc: 0.8249
#
# Epoch 00034: val_loss improved from 1.59988 to 1.57975, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 35/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.2933 - acc: 0.9400 - val_loss: 1.5696 - val_acc: 0.8086
#
# Epoch 00035: val_loss improved from 1.57975 to 1.56962, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 36/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.2662 - acc: 0.9391 - val_loss: 1.5299 - val_acc: 0.8190
#
# Epoch 00036: val_loss improved from 1.56962 to 1.52994, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 37/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.2494 - acc: 0.9395 - val_loss: 1.4944 - val_acc: 0.8338
#
# Epoch 00037: val_loss improved from 1.52994 to 1.49441, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 38/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 1.1986 - acc: 0.9479 - val_loss: 1.4813 - val_acc: 0.8323
#
# Epoch 00038: val_loss improved from 1.49441 to 1.48130, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 39/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.1772 - acc: 0.9512 - val_loss: 1.4737 - val_acc: 0.8323
#
# Epoch 00039: val_loss improved from 1.48130 to 1.47366, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 40/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.1311 - acc: 0.9593 - val_loss: 1.4774 - val_acc: 0.8294
#
# Epoch 00040: val_loss did not improve from 1.47366
# Epoch 41/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.1061 - acc: 0.9604 - val_loss: 1.4564 - val_acc: 0.8264
#
# Epoch 00041: val_loss improved from 1.47366 to 1.45638, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 42/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 1.0918 - acc: 0.9596 - val_loss: 1.4300 - val_acc: 0.8234
#
# Epoch 00042: val_loss improved from 1.45638 to 1.42999, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 43/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.0526 - acc: 0.9668 - val_loss: 1.4329 - val_acc: 0.8264
#
# Epoch 00043: val_loss did not improve from 1.42999
# Epoch 44/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.0233 - acc: 0.9718 - val_loss: 1.4060 - val_acc: 0.8487
#
# Epoch 00044: val_loss improved from 1.42999 to 1.40599, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 45/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.0152 - acc: 0.9668 - val_loss: 1.3763 - val_acc: 0.8279
#
# Epoch 00045: val_loss improved from 1.40599 to 1.37633, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 46/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 1.0216 - acc: 0.9597 - val_loss: 1.4489 - val_acc: 0.8323
#
# Epoch 00046: val_loss did not improve from 1.37633
# Epoch 47/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.9627 - acc: 0.9776 - val_loss: 1.4784 - val_acc: 0.8309
#
# Epoch 00047: val_loss did not improve from 1.37633
# Epoch 48/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.9289 - acc: 0.9865 - val_loss: 1.3409 - val_acc: 0.8650
#
# Epoch 00048: val_loss improved from 1.37633 to 1.34089, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 49/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.9146 - acc: 0.9891 - val_loss: 1.3507 - val_acc: 0.8635
#
# Epoch 00049: val_loss did not improve from 1.34089
# Epoch 50/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.9109 - acc: 0.9899 - val_loss: 1.3372 - val_acc: 0.8665
#
# Epoch 00050: val_loss improved from 1.34089 to 1.33719, saving model to ModelWeights/NormalUnbalancedCNN-ModelCheckpointWeightsNoAugment.h5
# Epoch 51/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.9045 - acc: 0.9898 - val_loss: 1.3420 - val_acc: 0.8591
#
# Epoch 00051: val_loss did not improve from 1.33719
# Epoch 52/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.9009 - acc: 0.9908 - val_loss: 1.3378 - val_acc: 0.8620
#
# Epoch 00052: val_loss did not improve from 1.33719
# Epoch 53/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.8985 - acc: 0.9899 - val_loss: 1.3415 - val_acc: 0.8605
#
# Epoch 00053: val_loss did not improve from 1.33719
# Epoch 54/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.8961 - acc: 0.9919 - val_loss: 1.3389 - val_acc: 0.8591
#
# Epoch 00054: val_loss did not improve from 1.33719
# Epoch 55/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.8964 - acc: 0.9901 - val_loss: 1.3386 - val_acc: 0.8591
#
# Epoch 00055: val_loss did not improve from 1.33719
# Epoch 56/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.8939 - acc: 0.9906 - val_loss: 1.3383 - val_acc: 0.8591
#
# Epoch 00056: val_loss did not improve from 1.33719
# Epoch 57/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.8969 - acc: 0.9898 - val_loss: 1.3383 - val_acc: 0.8591
#
# Epoch 00057: val_loss did not improve from 1.33719
# Epoch 58/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 0.8952 - acc: 0.9908 - val_loss: 1.3383 - val_acc: 0.8591
#
# Epoch 00058: val_loss did not improve from 1.33719
# Epoch 59/1000
# 6062/6062 [==============================] - 32s 5ms/step - loss: 0.8960 - acc: 0.9906 - val_loss: 1.3383 - val_acc: 0.8591
#
# Epoch 00059: val_loss did not improve from 1.33719
# Epoch 60/1000
# 6062/6062 [==============================] - 33s 5ms/step - loss: 0.8953 - acc: 0.9909 - val_loss: 1.3383 - val_acc: 0.8591
#
# Epoch 00060: val_loss did not improve from 1.33719
# Epoch 00060: early stopping

# %% [markdown]
# ### Loss and Accuracy without Augment

# %%
Viz.plot_loss_accuracy(normal_history, 'dark_background', path = 'figures/LossAccNormalUnbalNoAugment')

# %% [markdown]
# ### ROC and AUC without Augment

# %%
if edge == True: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
    
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('ModelWeights/NormalUnbalancedNoAugment.h5') #load the best weights before overfitting
 


Viz.plot_roc_auc(normal_model, x_test, y_test, 'dark_background')
# Out:
# F1 Scores Test
# ~~~~~~~~~~~~~~~~~~~~~~
# No Weapon: 0.9140461215932915
# HandGun: 0.866779089376054
# Rifle: 0.7841726618705037

# %% [markdown]
# ### Confusion Matrix Without Augment

# %%
if edge == True: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
        
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('ModelWeights/NormalUnbalancedNoAugment.h5') #load the best weights before overfitting





y_test_prob = [np.argmax(i) for i in normal_model.predict(x_test)]
y_test_labels = [np.argmax(
    i) for i in y_test]
test_cnf = confusion_matrix(y_test_labels, y_test_prob)

y_train_prob = [np.argmax(i) for i in normal_model.predict(x_train)]
y_train_labels = [np.argmax(i) for i in y_train]
train_cnf = confusion_matrix(y_train_labels, y_train_prob)

Viz.plot_model_cm(test_cnf, train_cnf, classes = ['No Weapon', 'Handgun', 'Rifle'], theme = 'dark_background')

# %% [markdown]
# ## Results
#
# - Comparing the confusion matrix of the augmented model with the non-augmented model, we can see that the non-augmented model performs much better at detection the presence of the weapon.
# - This difference can be due to the fact that the images that are being fed into the algorithm are already processes in a way that only makes it more confusing when applying augmentation as well
# - The model weights `CNN-ModelCheckpointWeightsNoAugment.h5` correspond to the final model used throughout the visualizations found in `OpenCVTesting` notebook
