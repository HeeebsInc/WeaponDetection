# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, AveragePooling2D
from keras import regularizers
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
import pickle
from sklearn.metrics import confusion_matrix
import Functions
import var
import Viz
from keras.applications.vgg16 import VGG16, preprocess_input
# Out:
# Using plaidml.keras.backend backend.

# %%
def get_vgg16(dim):
    model = Sequential()
    baseModel = VGG16(weights="imagenet", include_top=False,
        input_tensor=Input(shape=dim))
    
    model.add(baseModel)
    headModel = model.add(AveragePooling2D(pool_size=(7, 7)))
    headModel = model.add(Flatten(name="flatten"))
    headModel = model.add(Dense(128, activation="relu"))
    headModel = model.add(Dropout(0.3))
    headModel = model.add(Dense(3, activation="softmax", name = 'Output'))

    # place the head FC model on top of the base model (this will become
    # the actual model we will train)


    # loop over all layers in the base model and freeze them so they will
    # *not* be updated during the first training process
    for layer in baseModel.layers:
        layer.trainable = False
    
    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

# %%
x_train, x_test, y_train, y_test = Functions.get_samples('vgg16')
print(x_train.shape, x_test.shape) 
print(y_train.shape, y_test.shape)
# Out:
# (6512, 224, 224, 3) (724, 224, 224, 3)
# (6512, 3) (724, 3)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator


augment = False 

early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=18)
model_checkpoint = ModelCheckpoint('../models/VGG16-ModelCheckpointWeights.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 5, mode = 'min')
epochs = 350
batch_size = 32
if var.img_type == 'grey': 
    dim = (var.vgg_dimension[0], var.vgg_dimension[1], 1)
else: 
    dim = (var.vgg_dimension[0], var.vgg_dimension[1], 3)
    
vgg_16 = get_vgg16(dim =dim)

if augment: 
    augmentation =ImageDataGenerator(rotation_range = 15, width_shift_range = .1, height_shift_range = .1, 
                                                           horizontal_flip = True, fill_mode = 'nearest')
    augmentation.fit(x_train)
    vgg_16_history = vgg_16.fit_generator(augmentation.flow(x_train, y_train, batch_size = batch_size),
                epochs = epochs, steps_per_epoch = 8,
         callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
else: 
    
    vgg16_history = vgg_16.fit(x_train, y_train, batch_size = batch_size,
                epochs = epochs, 
         callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
# Out:
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"
# Train on 6512 samples, validate on 724 samples
# Epoch 1/350
# 6512/6512 [==============================] - 188s 29ms/step - loss: 0.6359 - acc: 0.7320 - val_loss: 0.5378 - val_acc: 0.7970
#
# Epoch 00001: val_loss improved from inf to 0.53780, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 2/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.4976 - acc: 0.8028 - val_loss: 0.4858 - val_acc: 0.8080
#
# Epoch 00002: val_loss improved from 0.53780 to 0.48584, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 3/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.4540 - acc: 0.8182 - val_loss: 0.4514 - val_acc: 0.8218
#
# Epoch 00003: val_loss improved from 0.48584 to 0.45136, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 4/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.4297 - acc: 0.8254 - val_loss: 0.4360 - val_acc: 0.8204
#
# Epoch 00004: val_loss improved from 0.45136 to 0.43597, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 5/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.4172 - acc: 0.8311 - val_loss: 0.4378 - val_acc: 0.8273
#
# Epoch 00005: val_loss did not improve from 0.43597
# Epoch 6/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.4039 - acc: 0.8378 - val_loss: 0.4194 - val_acc: 0.8467
#
# Epoch 00006: val_loss improved from 0.43597 to 0.41937, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 7/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3907 - acc: 0.8443 - val_loss: 0.4065 - val_acc: 0.8494
#
# Epoch 00007: val_loss improved from 0.41937 to 0.40646, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 8/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3829 - acc: 0.8466 - val_loss: 0.4142 - val_acc: 0.8425
#
# Epoch 00008: val_loss did not improve from 0.40646
# Epoch 9/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3741 - acc: 0.8514 - val_loss: 0.3939 - val_acc: 0.8425
#
# Epoch 00009: val_loss improved from 0.40646 to 0.39390, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 10/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3664 - acc: 0.8549 - val_loss: 0.4005 - val_acc: 0.8425
#
# Epoch 00010: val_loss did not improve from 0.39390
# Epoch 11/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3612 - acc: 0.8580 - val_loss: 0.3822 - val_acc: 0.8536
#
# Epoch 00011: val_loss improved from 0.39390 to 0.38215, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 12/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3592 - acc: 0.8575 - val_loss: 0.3774 - val_acc: 0.8522
#
# Epoch 00012: val_loss improved from 0.38215 to 0.37739, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 13/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3446 - acc: 0.8623 - val_loss: 0.3994 - val_acc: 0.8398
#
# Epoch 00013: val_loss did not improve from 0.37739
# Epoch 14/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3465 - acc: 0.8632 - val_loss: 0.3698 - val_acc: 0.8591
#
# Epoch 00014: val_loss improved from 0.37739 to 0.36983, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 15/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3309 - acc: 0.8667 - val_loss: 0.4289 - val_acc: 0.8246
#
# Epoch 00015: val_loss did not improve from 0.36983
# Epoch 16/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3360 - acc: 0.8678 - val_loss: 0.3716 - val_acc: 0.8591
#
# Epoch 00016: val_loss did not improve from 0.36983
# Epoch 17/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3297 - acc: 0.8735 - val_loss: 0.3658 - val_acc: 0.8605
#
# Epoch 00017: val_loss improved from 0.36983 to 0.36582, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 18/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3251 - acc: 0.8742 - val_loss: 0.3577 - val_acc: 0.8619
#
# Epoch 00018: val_loss improved from 0.36582 to 0.35766, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 19/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3201 - acc: 0.8761 - val_loss: 0.3733 - val_acc: 0.8660
#
# Epoch 00019: val_loss did not improve from 0.35766
# Epoch 20/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3247 - acc: 0.8725 - val_loss: 0.3849 - val_acc: 0.8564
#
# Epoch 00020: val_loss did not improve from 0.35766
# Epoch 21/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3156 - acc: 0.8781 - val_loss: 0.3541 - val_acc: 0.8688
#
# Epoch 00021: val_loss improved from 0.35766 to 0.35414, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 22/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3095 - acc: 0.8791 - val_loss: 0.3695 - val_acc: 0.8564
#
# Epoch 00022: val_loss did not improve from 0.35414
# Epoch 23/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.3094 - acc: 0.8779 - val_loss: 0.3502 - val_acc: 0.8646
#
# Epoch 00023: val_loss improved from 0.35414 to 0.35022, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 24/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2981 - acc: 0.8844 - val_loss: 0.3536 - val_acc: 0.8633
#
# Epoch 00024: val_loss did not improve from 0.35022
# Epoch 25/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2956 - acc: 0.8833 - val_loss: 0.3730 - val_acc: 0.8550
#
# Epoch 00025: val_loss did not improve from 0.35022
# Epoch 26/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2966 - acc: 0.8841 - val_loss: 0.3518 - val_acc: 0.8715
#
# Epoch 00026: val_loss did not improve from 0.35022
# Epoch 27/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2917 - acc: 0.8868 - val_loss: 0.3641 - val_acc: 0.8591
#
# Epoch 00027: val_loss did not improve from 0.35022
# Epoch 28/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2875 - acc: 0.8907 - val_loss: 0.3354 - val_acc: 0.8798
#
# Epoch 00028: val_loss improved from 0.35022 to 0.33543, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 29/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2820 - acc: 0.8887 - val_loss: 0.3479 - val_acc: 0.8729
#
# Epoch 00029: val_loss did not improve from 0.33543
# Epoch 30/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2816 - acc: 0.8874 - val_loss: 0.3407 - val_acc: 0.8729
#
# Epoch 00030: val_loss did not improve from 0.33543
# Epoch 31/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2738 - acc: 0.8920 - val_loss: 0.3468 - val_acc: 0.8715
#
# Epoch 00031: val_loss did not improve from 0.33543
# Epoch 32/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2756 - acc: 0.8939 - val_loss: 0.3374 - val_acc: 0.8702
#
# Epoch 00032: val_loss did not improve from 0.33543
# Epoch 33/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2710 - acc: 0.8911 - val_loss: 0.3354 - val_acc: 0.8771
#
# Epoch 00033: val_loss improved from 0.33543 to 0.33537, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 34/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2497 - acc: 0.9074 - val_loss: 0.3299 - val_acc: 0.8757
#
# Epoch 00034: val_loss improved from 0.33537 to 0.32987, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 35/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2465 - acc: 0.9046 - val_loss: 0.3308 - val_acc: 0.8840
#
# Epoch 00035: val_loss did not improve from 0.32987
# Epoch 36/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2437 - acc: 0.9065 - val_loss: 0.3283 - val_acc: 0.8743
#
# Epoch 00036: val_loss improved from 0.32987 to 0.32826, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 37/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2444 - acc: 0.9085 - val_loss: 0.3302 - val_acc: 0.8785
#
# Epoch 00037: val_loss did not improve from 0.32826
# Epoch 38/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2420 - acc: 0.9085 - val_loss: 0.3296 - val_acc: 0.8826
#
# Epoch 00038: val_loss did not improve from 0.32826
# Epoch 39/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2424 - acc: 0.9062 - val_loss: 0.3287 - val_acc: 0.8826
#
# Epoch 00039: val_loss did not improve from 0.32826
# Epoch 40/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2420 - acc: 0.9083 - val_loss: 0.3257 - val_acc: 0.8798
#
# Epoch 00040: val_loss improved from 0.32826 to 0.32568, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 41/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2416 - acc: 0.9082 - val_loss: 0.3237 - val_acc: 0.8743
#
# Epoch 00041: val_loss improved from 0.32568 to 0.32369, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 42/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2381 - acc: 0.9083 - val_loss: 0.3250 - val_acc: 0.8785
#
# Epoch 00042: val_loss did not improve from 0.32369
# Epoch 43/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2390 - acc: 0.9091 - val_loss: 0.3235 - val_acc: 0.8785
#
# Epoch 00043: val_loss improved from 0.32369 to 0.32353, saving model to ../models/VGG16-ModelCheckpointWeights.h5
# Epoch 44/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2359 - acc: 0.9117 - val_loss: 0.3267 - val_acc: 0.8826
#
# Epoch 00044: val_loss did not improve from 0.32353
# Epoch 45/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2387 - acc: 0.9103 - val_loss: 0.3266 - val_acc: 0.8743
#
# Epoch 00045: val_loss did not improve from 0.32353
# Epoch 46/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2372 - acc: 0.9140 - val_loss: 0.3272 - val_acc: 0.8798
#
# Epoch 00046: val_loss did not improve from 0.32353
# Epoch 47/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2358 - acc: 0.9123 - val_loss: 0.3256 - val_acc: 0.8854
#
# Epoch 00047: val_loss did not improve from 0.32353
# Epoch 48/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2315 - acc: 0.9099 - val_loss: 0.3235 - val_acc: 0.8840
#
# Epoch 00048: val_loss did not improve from 0.32353
# Epoch 49/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2352 - acc: 0.9094 - val_loss: 0.3236 - val_acc: 0.8840
#
# Epoch 00049: val_loss did not improve from 0.32353
# Epoch 50/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2349 - acc: 0.9119 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00050: val_loss did not improve from 0.32353
# Epoch 51/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2325 - acc: 0.9132 - val_loss: 0.3237 - val_acc: 0.8826
#
# Epoch 00051: val_loss did not improve from 0.32353
# Epoch 52/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2331 - acc: 0.9128 - val_loss: 0.3240 - val_acc: 0.8826
#
# Epoch 00052: val_loss did not improve from 0.32353
# Epoch 53/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2348 - acc: 0.9120 - val_loss: 0.3237 - val_acc: 0.8826
#
# Epoch 00053: val_loss did not improve from 0.32353
# Epoch 54/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2326 - acc: 0.9140 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00054: val_loss did not improve from 0.32353
# Epoch 55/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2327 - acc: 0.9115 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00055: val_loss did not improve from 0.32353
# Epoch 56/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2308 - acc: 0.9140 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00056: val_loss did not improve from 0.32353
# Epoch 57/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2340 - acc: 0.9099 - val_loss: 0.3237 - val_acc: 0.8826
#
# Epoch 00057: val_loss did not improve from 0.32353
# Epoch 58/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2330 - acc: 0.9145 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00058: val_loss did not improve from 0.32353
# Epoch 59/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2310 - acc: 0.9140 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00059: val_loss did not improve from 0.32353
# Epoch 60/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2316 - acc: 0.9131 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00060: val_loss did not improve from 0.32353
# Epoch 61/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2353 - acc: 0.9085 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00061: val_loss did not improve from 0.32353
# Epoch 62/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2316 - acc: 0.9162 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00062: val_loss did not improve from 0.32353
# Epoch 63/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2322 - acc: 0.9105 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00063: val_loss did not improve from 0.32353
# Epoch 64/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2324 - acc: 0.9119 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00064: val_loss did not improve from 0.32353
# Epoch 65/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2298 - acc: 0.9146 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00065: val_loss did not improve from 0.32353
# Epoch 66/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2341 - acc: 0.9112 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00066: val_loss did not improve from 0.32353
# Epoch 67/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2314 - acc: 0.9112 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00067: val_loss did not improve from 0.32353
# Epoch 68/350
# 6512/6512 [==============================] - 168s 26ms/step - loss: 0.2306 - acc: 0.9139 - val_loss: 0.3236 - val_acc: 0.8826
#
# Epoch 00068: val_loss did not improve from 0.32353
# Epoch 00068: early stopping

# %% [markdown]
# ### Loss and Accuracy

# %%
Viz.plot_loss_accuracy(vgg16_history)

# %% [markdown]
# ### ROC & AUC

# %%
if var.img_type == 'grey': 
    dim = (var.vgg_dimension[0], var.vgg_dimension[1], 1)
else: 
    dim = (var.vgg_dimension[0], var.vgg_dimension[1], 3)
    
vgg_16 = get_vgg16(dim =dim)
vgg_16.load_weights('../models/VGG16-ModelCheckpointWeights.h5')
Viz.plot_roc_auc(vgg_16, x_test, y_test)
# Out:
# F1 Scores Test
# ~~~~~~~~~~~~~~~~~~~~~~
# No Weapon: 0.9335604770017036
# HandGun: 0.8656716417910447
# Rifle: 0.7829457364341086

# %% [markdown]
# ### Confusion Matrix

# %%
if var.img_type == 'grey': 
    dim = (var.vgg_dimension[0], var.vgg_dimension[1], 1)
else: 
    dim = (var.vgg_dimension[0], var.vgg_dimension[1], 3)
    
vgg_16 = get_vgg16(dim =dim)
vgg_16.load_weights('../models/VGG16-ModelCheckpointWeights.h5')





y_test_prob = [np.argmax(i) for i in vgg_16.predict(x_test)]
y_test_labels = [np.argmax(
    i) for i in y_test]
test_cnf = confusion_matrix(y_test_labels, y_test_prob)

y_train_prob = [np.argmax(i) for i in vgg_16.predict(x_train)]
y_train_labels = [np.argmax(i) for i in y_train]
train_cnf = confusion_matrix(y_train_labels, y_train_prob)

Viz.plot_model_cm(test_cnf, train_cnf, classes = ['No Weapon', 'Handgun', 'Rifle'])

# %% [markdown]
# ### Test on Google

# %%
import cv2
from lime import lime_image
from skimage.segmentation import mark_boundaries

# %%
base_path = '../TestImages'
if var.img_type == 'grey': 
    dim = (var.vgg_dimension[0], var.vgg_dimension[1], 1)
else: 
    dim = (var.vgg_dimension[0], var.vgg_dimension[1], 3)
    
vgg16 = get_vgg16(dim =dim)
vgg16.load_weights('../models/VGG16-ModelCheckpointWeights.h5')


for file in os.listdir(base_path): 
    if file == '.ipynb_checkpoints':
        continue
    full_path = f'{base_path}/{file}'
    img = Functions.get_image_value(full_path, var.vgg_dimension, var.img_type)
    img = img.reshape(1, img.shape[0], img.shape[1], img.shape[2])
    pred = vgg16.predict(img)[0]
    print(f'{file}\t\t{np.argmax(pred)}\t\t{pred.max()}\t\t{pred}')
# Out:
# AR.jpg		2		0.9996071457862854		[2.1330284e-06 3.9071142e-04 9.9960715e-01]
# NonGun.jpeg		2		0.5367690324783325		[0.45799974 0.00523127 0.53676903]
# Pistol.jpg		1		0.9991779923439026		[2.6393452e-04 9.9917799e-01 5.5800361e-04]
# Pistol2.jpg		1		1.0		[3.6227252e-09 1.0000000e+00 3.0504799e-10]
# Pistol3.jpg		1		0.997253954410553		[0.00142326 0.99725395 0.00132284]

# %%
img = Functions.get_image_value('../TestImages/AR.jpg', var.vgg_dimension, var.img_type)

explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(img, vgg16.predict, top_labels = 5, hide_color = 0, 
                                         num_samples = 1000)

temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only = False,
                                           num_features = 10, hide_rest = False)
plt.imshow(mark_boundaries(temp/2 + .5, mask))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
Functions.get_prediction_bounding_box('../TestImages/Pistol2.jpg', vgg16, var.vgg_dimension)
# Out:
# ../TestImages/Pistol2.jpg		1||Handgun		1.0		[3.6227252e-09 1.0000000e+00 3.0504799e-10]
