# %% [markdown]
# ## CNN

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten 
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, AveragePooling2D
from keras import regularizers
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
import pickle
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
import Functions as func
import GetPickles
import var
import Viz
# Out:
# Using plaidml.keras.backend backend.

# %%
def get_conv_model_normal(dim):
    
    inp_shape = dim
    act = 'relu'
    drop = .5 
    kernal_reg = regularizers.l1(.001)
    dil_rate = 2
    
    
    model = Sequential() 
    
    model.add(Conv2D(64, kernel_size=(3,3),activation=act, input_shape = inp_shape, 
                     kernel_regularizer = kernal_reg,
                     kernel_initializer = 'he_uniform',  padding = 'same', name = 'Input_Layer'))
    model.add(Dense(64, activation = 'relu'))
    model.add(MaxPooling2D(pool_size=(2, 2),  strides = (2,2)))
    
    
    model.add(Conv2D(64, (3, 3), activation=act, kernel_regularizer = kernal_reg, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(Dense(64, activation = 'relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = (2,2)))
    

    
    model.add(Conv2D(128, (3, 3), activation=act, kernel_regularizer = kernal_reg, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(Conv2D(128, (3, 3), activation=act, kernel_regularizer = kernal_reg, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = (2,2)))

    
    model.add(Flatten())

    
#     model.add(Dense(128, activation='relu'))
#     model.add(Dense(64, activation='relu'))
#     model.add(Dense(32, activation='relu'))


    model.add(Dropout(drop))

    model.add(Dense(3, activation='softmax', name = 'Output_Layer'))
    
    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

# %%
x_train, x_test, y_train, y_test = GetPickles.get_samples('normal2')

# %%
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (6512, 96, 96, 3) (724, 96, 96, 3)
# (6512, 3) (724, 3)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator


augment = True 
early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=14)
model_checkpoint = ModelCheckpoint('../models/CNN-ModelCheckpointWeights3.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 3, mode = 'min')
epochs = 100
batch_size = 32
if var.img_type == 'grey': 
    dim = (x_train.shape[1], x_train.shape[2], 1)
else: 
    dim = (x_train.shape[1], x_train.shape[2], 3)
    
normal_model = get_conv_model_normal(dim =dim)

if augment: 
    augmentation =ImageDataGenerator(rotation_range = 20, width_shift_range = .1, height_shift_range = .1, 
                                                           horizontal_flip = True, fill_mode = 'nearest')
    augmentation.fit(x_train)
    normal_history = normal_model.fit_generator(augmentation.flow(x_train, y_train, batch_size = batch_size),
                epochs = epochs, 
         callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
else: 
    
    normal_history = normal_model.fit(x_train, y_train, batch_size = batch_size,
                epochs = epochs, 
         callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
# Out:
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"
# Epoch 1/100
# 204/204 [==============================] - 53s 261ms/step - loss: 4.5619 - acc: 0.6821 - val_loss: 1.9159 - val_acc: 0.7610
#
# Epoch 00001: val_loss improved from inf to 1.91594, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 2/100
# 204/204 [==============================] - 27s 133ms/step - loss: 1.6155 - acc: 0.7468 - val_loss: 1.4133 - val_acc: 0.7707
#
# Epoch 00002: val_loss improved from 1.91594 to 1.41326, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 3/100
# 204/204 [==============================] - 27s 134ms/step - loss: 1.4097 - acc: 0.7483 - val_loss: 1.4245 - val_acc: 0.7210
#
# Epoch 00003: val_loss did not improve from 1.41326
# Epoch 4/100
# 204/204 [==============================] - 27s 133ms/step - loss: 1.2030 - acc: 0.7635 - val_loss: 1.4781 - val_acc: 0.6782
#
# Epoch 00004: val_loss did not improve from 1.41326
# Epoch 5/100
# 204/204 [==============================] - 27s 133ms/step - loss: 1.1078 - acc: 0.7750 - val_loss: 1.3271 - val_acc: 0.7251
#
# Epoch 00005: val_loss improved from 1.41326 to 1.32709, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 6/100
# 204/204 [==============================] - 27s 133ms/step - loss: 1.0897 - acc: 0.7687 - val_loss: 1.1876 - val_acc: 0.7459
#
# Epoch 00006: val_loss improved from 1.32709 to 1.18763, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 7/100
# 204/204 [==============================] - 27s 133ms/step - loss: 1.1038 - acc: 0.7753 - val_loss: 1.0875 - val_acc: 0.7887
#
# Epoch 00007: val_loss improved from 1.18763 to 1.08750, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 8/100
# 204/204 [==============================] - 27s 133ms/step - loss: 1.0656 - acc: 0.7760 - val_loss: 1.0610 - val_acc: 0.7859
#
# Epoch 00008: val_loss improved from 1.08750 to 1.06103, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 9/100
# 204/204 [==============================] - 27s 134ms/step - loss: 1.0528 - acc: 0.7802 - val_loss: 1.3370 - val_acc: 0.7362
#
# Epoch 00009: val_loss did not improve from 1.06103
# Epoch 10/100
# 204/204 [==============================] - 27s 134ms/step - loss: 1.0985 - acc: 0.7665 - val_loss: 1.5363 - val_acc: 0.7376
#
# Epoch 00010: val_loss did not improve from 1.06103
# Epoch 11/100
# 204/204 [==============================] - 27s 134ms/step - loss: 1.0210 - acc: 0.7848 - val_loss: 1.0340 - val_acc: 0.7873
#
# Epoch 00011: val_loss improved from 1.06103 to 1.03402, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 12/100
# 204/204 [==============================] - 27s 134ms/step - loss: 0.9566 - acc: 0.7909 - val_loss: 1.2566 - val_acc: 0.7528
#
# Epoch 00012: val_loss did not improve from 1.03402
# Epoch 13/100
# 204/204 [==============================] - 27s 133ms/step - loss: 0.9386 - acc: 0.7884 - val_loss: 1.0031 - val_acc: 0.7818
#
# Epoch 00013: val_loss improved from 1.03402 to 1.00313, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 14/100
# 204/204 [==============================] - 27s 132ms/step - loss: 0.9377 - acc: 0.7846 - val_loss: 0.9237 - val_acc: 0.8191
#
# Epoch 00014: val_loss improved from 1.00313 to 0.92368, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 15/100
# 204/204 [==============================] - 27s 132ms/step - loss: 0.9615 - acc: 0.7825 - val_loss: 1.0480 - val_acc: 0.7983
#
# Epoch 00015: val_loss did not improve from 0.92368
# Epoch 16/100
# 204/204 [==============================] - 27s 133ms/step - loss: 0.9994 - acc: 0.7862 - val_loss: 1.3046 - val_acc: 0.7307
#
# Epoch 00016: val_loss did not improve from 0.92368
# Epoch 17/100
# 204/204 [==============================] - 27s 132ms/step - loss: 0.9250 - acc: 0.7865 - val_loss: 1.2454 - val_acc: 0.7251
#
# Epoch 00017: val_loss did not improve from 0.92368
# Epoch 18/100
# 204/204 [==============================] - 27s 132ms/step - loss: 0.8330 - acc: 0.8090 - val_loss: 0.9052 - val_acc: 0.8108
#
# Epoch 00018: val_loss improved from 0.92368 to 0.90516, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 19/100
# 204/204 [==============================] - 27s 133ms/step - loss: 0.7944 - acc: 0.8199 - val_loss: 0.9054 - val_acc: 0.8039
#
# Epoch 00019: val_loss did not improve from 0.90516
# Epoch 20/100
# 204/204 [==============================] - 27s 133ms/step - loss: 0.7784 - acc: 0.8272 - val_loss: 0.9211 - val_acc: 0.7983
#
# Epoch 00020: val_loss did not improve from 0.90516
# Epoch 21/100
# 204/204 [==============================] - 27s 134ms/step - loss: 0.7727 - acc: 0.8251 - val_loss: 0.8434 - val_acc: 0.8135
#
# Epoch 00021: val_loss improved from 0.90516 to 0.84343, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 22/100
# 204/204 [==============================] - 28s 135ms/step - loss: 0.7647 - acc: 0.8272 - val_loss: 0.9179 - val_acc: 0.8094
#
# Epoch 00022: val_loss did not improve from 0.84343
# Epoch 23/100
# 204/204 [==============================] - 28s 136ms/step - loss: 0.7619 - acc: 0.8309 - val_loss: 0.8750 - val_acc: 0.8039
#
# Epoch 00023: val_loss did not improve from 0.84343
# Epoch 24/100
# 204/204 [==============================] - 28s 135ms/step - loss: 0.7531 - acc: 0.8274 - val_loss: 0.8021 - val_acc: 0.8260
#
# Epoch 00024: val_loss improved from 0.84343 to 0.80212, saving model to ../models/CNN-ModelCheckpointWeights3.h5
# Epoch 25/100
# 204/204 [==============================] - 28s 135ms/step - loss: 0.7442 - acc: 0.8307 - val_loss: 0.8729 - val_acc: 0.8066
#
# Epoch 00025: val_loss did not improve from 0.80212
# Epoch 26/100
# 204/204 [==============================] - 28s 135ms/step - loss: 0.7416 - acc: 0.8258 - val_loss: 0.8410 - val_acc: 0.8163
#
# Epoch 00026: val_loss did not improve from 0.80212
# Epoch 27/100
# 204/204 [==============================] - 27s 135ms/step - loss: 0.7340 - acc: 0.8333 - val_loss: 0.8682 - val_acc: 0.8080
#
# Epoch 00027: val_loss did not improve from 0.80212
# Epoch 28/100
# 204/204 [==============================] - 27s 134ms/step - loss: 0.7239 - acc: 0.8362 - val_loss: 0.8303 - val_acc: 0.8246
#
# Epoch 00028: val_loss did not improve from 0.80212
# Epoch 29/100
# 204/204 [==============================] - 27s 134ms/step - loss: 0.7227 - acc: 0.8332 - val_loss: 0.8287 - val_acc: 0.8204
#
# Epoch 00029: val_loss did not improve from 0.80212
# Epoch 30/100
# 204/204 [==============================] - 27s 134ms/step - loss: 0.7160 - acc: 0.8341 - val_loss: 0.8312 - val_acc: 0.8218
#
# Epoch 00030: val_loss did not improve from 0.80212
# Epoch 31/100
# 204/204 [==============================] - 28s 136ms/step - loss: 0.7168 - acc: 0.8362 - val_loss: 0.8381 - val_acc: 0.8191
#
# Epoch 00031: val_loss did not improve from 0.80212
# Epoch 32/100
# 204/204 [==============================] - 27s 135ms/step - loss: 0.7153 - acc: 0.8353 - val_loss: 0.8412 - val_acc: 0.8191
#
# Epoch 00032: val_loss did not improve from 0.80212
# Epoch 33/100
# 204/204 [==============================] - 27s 135ms/step - loss: 0.7120 - acc: 0.8370 - val_loss: 0.8422 - val_acc: 0.8191
#
# Epoch 00033: val_loss did not improve from 0.80212
# Epoch 34/100
# 204/204 [==============================] - 27s 134ms/step - loss: 0.7138 - acc: 0.8358 - val_loss: 0.8418 - val_acc: 0.8191
#
# Epoch 00034: val_loss did not improve from 0.80212
# Epoch 35/100
# 204/204 [==============================] - 27s 134ms/step - loss: 0.7168 - acc: 0.8366 - val_loss: 0.8415 - val_acc: 0.8204
#
# Epoch 00035: val_loss did not improve from 0.80212
# Epoch 36/100
# 204/204 [==============================] - 27s 134ms/step - loss: 0.7123 - acc: 0.8372 - val_loss: 0.8412 - val_acc: 0.8191
#
# Epoch 00036: val_loss did not improve from 0.80212
# Epoch 37/100
# 204/204 [==============================] - 27s 134ms/step - loss: 0.7142 - acc: 0.8349 - val_loss: 0.8411 - val_acc: 0.8191
#
# Epoch 00037: val_loss did not improve from 0.80212
# Epoch 38/100
# 204/204 [==============================] - 27s 134ms/step - loss: 0.7196 - acc: 0.8329 - val_loss: 0.8411 - val_acc: 0.8191
#
# Epoch 00038: val_loss did not improve from 0.80212
# Epoch 00038: early stopping

# %%
print(normal_model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Layer (Conv2D)         (None, 96, 96, 64)        1792
# _________________________________________________________________
# dense_1 (Dense)              (None, 96, 96, 64)        4160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# dense_2 (Dense)              (None, 48, 48, 64)        4160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# Output_Layer (Dense)         (None, 3)                 55299
# =================================================================
# Total params: 323,779
# Trainable params: 323,779
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Loss & Accuracy

# %%
Viz.plot_loss_accuracy(normal_history)

# %%
Viz.plot_loss_accuracy(normal_history)

# %%
Viz.plot_loss_accuracy(normal_history)

# %% [markdown]
# ### AUC and ROC Curves

# %%
if var.img_type == 'grey': 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
    
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights3.h5') #load the best weights before overfitting
 


    
Viz.plot_roc_auc(normal_model, x_test, y_test)
# Out:
# F1 Scores Test
# ~~~~~~~~~~~~~~~~~~~~~~
# No Weapon: 0.919175911251981
# HandGun: 0.8543046357615893
# Rifle: 0.4694835680751174

# %%
if var.img_type == 'grey': 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
    
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights2.h5') #load the best weights before overfitting
 


    
Viz.plot_roc_auc(normal_model, x_test, y_test)
# Out:
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"
# F1 Scores Test
# ~~~~~~~~~~~~~~~~~~~~~~
# No Weapon: 0.9185441941074522
# HandGun: 0.7868852459016394
# Rifle: 0.6360153256704981

# %% [markdown]
# ### Confusion Matrix

# %%
if var.img_type == 'grey': 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
        
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights3.h5') #load the best weights before overfitting





y_test_prob = [np.argmax(i) for i in normal_model.predict(x_test)]
y_test_labels = [np.argmax(
    i) for i in y_test]
test_cnf = confusion_matrix(y_test_labels, y_test_prob)

y_train_prob = [np.argmax(i) for i in normal_model.predict(x_train)]
y_train_labels = [np.argmax(i) for i in y_train]
train_cnf = confusion_matrix(y_train_labels, y_train_prob)

Viz.plot_model_cm(test_cnf, train_cnf, classes = ['No Weapon', 'Handgun', 'Rifle'])

# %%
if var.img_type == 'grey': 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
        
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights2.h5') #load the best weights before overfitting





y_test_prob = [np.argmax(i) for i in normal_model.predict(x_test)]
y_test_labels = [np.argmax(
    i) for i in y_test]
test_cnf = confusion_matrix(y_test_labels, y_test_prob)

y_train_prob = [np.argmax(i) for i in normal_model.predict(x_train)]
y_train_labels = [np.argmax(i) for i in y_train]
train_cnf = confusion_matrix(y_train_labels, y_train_prob)

Viz.plot_model_cm(test_cnf, train_cnf, classes = ['No Weapon', 'Handgun', 'Rifle'])

# %%
if var.img_type == 'grey': 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
        
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights.h5') #load the best weights before overfitting





y_test_prob = [np.argmax(i) for i in normal_model.predict(x_test)]
y_test_labels = [np.argmax(
    i) for i in y_test]
test_cnf = confusion_matrix(y_test_labels, y_test_prob)

y_train_prob = [np.argmax(i) for i in normal_model.predict(x_train)]
y_train_labels = [np.argmax(i) for i in y_train]
train_cnf = confusion_matrix(y_train_labels, y_train_prob)

Viz.plot_model_cm(test_cnf, train_cnf, classes = ['No Weapon', 'Handgun', 'Rifle'])
# Out:
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"

# %%
assert False

# %% [markdown]
# #### Test on Google Data

# %%
import cv2
from lime import lime_image
from skimage.segmentation import mark_boundaries

# %%
base_path = '../TestImages'
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights.h5')

for file in os.listdir(base_path): 
    if file == '.ipynb_checkpoints':
        continue
    full_path = f'{base_path}/{file}'
    img = func.get_image_value(full_path, var.norm_dimension, var.img_type)
    img = img.reshape(1, img.shape[0], img.shape[1], img.shape[2])
    pred = normal_model.predict(img)[0]
    print(f'{file}\t\t{np.argmax(pred)}\t\t{pred.max()}\t\t{pred}')
# Out:
# AR.jpg		0		0.9849305152893066		[0.9849305  0.00909123 0.00597824]
# NonGun.jpeg		0		0.8449652194976807		[0.8449652  0.09366439 0.06137041]
# Pistol.jpg		0		0.5849882960319519		[0.5849883  0.18931518 0.22569647]
# Pistol2.jpg		0		0.9999939203262329		[9.999939e-01 3.747293e-07 5.689508e-06]

# %%
base_path = '../TestImages'

normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights2.h5')
for file in os.listdir(base_path): 
    if file == '.ipynb_checkpoints':
        continue
    full_path = f'{base_path}/{file}'
    img = func.get_image_value(full_path, var.norm_dimension, var.img_type)
    img = img.reshape(1, img.shape[0], img.shape[1], img.shape[2])
    pred = normal_model.predict(img)[0]
    print(f'{file}\t\t{np.argmax(pred)}\t\t{pred.max()}\t\t{pred}')
# Out:
# AR.jpg		2		0.8100496530532837		[0.00751655 0.18243375 0.81004965]
# NonGun.jpeg		2		0.8993415236473083		[0.00231877 0.09833971 0.8993415 ]
# Pistol.jpg		1		0.8810046315193176		[0.00089267 0.88100463 0.11810275]
# Pistol2.jpg		2		0.9681897759437561		[5.2023225e-04 3.1290054e-02 9.6818978e-01]

# %%
base_path = '../TestImages'
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights3.h5')

for file in os.listdir(base_path): 
    if file == '.ipynb_checkpoints':
        continue
    full_path = f'{base_path}/{file}'
    img = func.get_image_value(full_path, var.norm_dimension, var.img_type)
    img = img.reshape(1, img.shape[0], img.shape[1], img.shape[2])
    pred = normal_model.predict(img)[0]
    print(f'{file}\t\t{np.argmax(pred)}\t\t{pred.max()}\t\t{pred}')
# Out:
# AR.jpg		0		0.9924888610839844		[9.9248886e-01 1.1887848e-04 7.3922407e-03]
# NonGun.jpeg		0		0.9870736598968506		[0.98707366 0.00146516 0.01146114]
# Pistol.jpg		0		0.9667770266532898		[0.966777   0.01465641 0.01856658]
# Pistol2.jpg		0		1.0		[1.00000000e+00 6.77395806e-10 1.03148725e-08]

# %%
#model 3
if var.img_type == 'grey': 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
        

img = func.get_image_value('../TestImages/AR.jpg', var.norm_dimension, var.img_type)

explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(img, normal_model.predict, top_labels = 5, hide_color = 0, 
                                         num_samples = 1000)

temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only = False,
                                           num_features = 10, hide_rest = False)
plt.imshow(mark_boundaries(temp/2 + .5, mask))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
if var.img_type == 'grey': 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
        

img = func.get_image_value('../TestImages/AR.jpg', var.norm_dimension, var.img_type)

explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(img, normal_model.predict, top_labels = 5, hide_color = 0, 
                                         num_samples = 1000)

temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only = False,
                                           num_features = 10, hide_rest = False)
plt.imshow(mark_boundaries(temp/2 + .5, mask))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
assert False

# %%
if var.img_type == 'grey': 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 1)
else: 
    dim = (var.norm_dimension[0], var.norm_dimension[1], 3)
        
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights2.h5')

img = cv2.imread('../TestImages/AR.jpg')
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
ss.setBaseImage(img)
ss.switchToSelectiveSearchFast()
rects = ss.process() 

windows = []
locations = []
for x, y, w,h in rects: 
    startx = x 
    starty = y 
    endx = x+w 
    endy = y+h 
    roi = img[starty:endy, startx:endx]
    roi = cv2.resize(roi, dsize =var.norm_dimension, interpolation = cv2.INTER_CUBIC)
    windows.append(roi)
    locations.append((startx, starty, endx, endy))

# %%
windows = np.array(windows[:2000])

predictions = normal_model.predict(windows)

# %%
# for i in predictions:
#     print(i)

# %%
clone = img.copy()
new_loc = [] 
new_prob = [] 
no_gun = predictions[:, 0].sum()
handgun = predictions[:,1].sum()
rifle = predictions[:,2].sum()
sum_array = np.array([no_gun, handgun, rifle])
index_unit = np.argmax(sum_array)
cat_types = ['No Gun', 'Handgun', 'Rifle']
print(index_unit)
print(no_gun, handgun, rifle)
new_locations = []
for idx, i in enumerate(predictions):
    category = i[index_unit]
    if category > .5:
        startx, starty, endx, endy = locations[idx]
        new_locations.append([startx, starty, endx, endy])
        new_loc.append(locations[idx])
        new_prob.append(category)

new_locations = np.array(new_locations)

startx = int(new_locations[:,0].mean())
starty =int( new_locations[:,1].mean())
endx = int(new_locations[:,2].mean())
endy = int(new_locations[:,3].mean())


# startx = int(np.median (new_locations[:,0]))
# starty =int( np.median (new_locations[:,1]))
# endx = int(np.median (new_locations[:,2]))
# endy = int(np.median(new_locations[:,3]))

prob_avg = np.array(new_prob).mean()


cv2.rectangle(clone, (startx, starty), (endx, endy),  (0,255,0),2)

text = f'{cat_types[index_unit]}: {int(prob_avg*100)}'
cv2.putText(clone, text, (startx, starty), cv2.FONT_HERSHEY_SIMPLEX, .45, (0,255,0),2)
   
    
cv2.imshow('test', clone)
cv2.waitKey(0)
# Out:
# 2
# 267.50977 58.117844 296.3724
# -1

# %%
assert False

# %%
clone = img.copy()
  
startx, starty, endx, endy = new_loc[boxid]
cv2.rectangle(clone, (startx, starty), (endx, endy),  (0,255,0),2)
text = f'Weapon: {i*100}'
cv2.putText(clone, text, (startx, y), cv2.FONT_HERSHEY_SIMPLEX, .45, (0,255,0),2)
cv2.imshow('test', clone)
cv2.waitKey(0)

# %%
clone = img.copy()
roi = clone[starty:endy, startx:endx]
roi = cv2.resize(roi, dsize =var.dimension, interpolation = cv2.INTER_CUBIC)
# cv2.imshow('test', roi)
# cv2.waitKey(0)
explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(roi, normal_model.predict, top_labels = 5, hide_color = 0, 
                                         num_samples = 1000)


temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only = False,
                                           num_features = 10, hide_rest = False)
plt.imshow(mark_boundaries(temp/2 + .5, mask))
