# %% [markdown]
# ## CNN

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten 
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import regularizers
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
import pickle
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
import Functions as func
import var
# Out:
# Using plaidml.keras.backend backend.

# %%
def get_conv_model_normal(dim):
    
    inp_shape = dim
    act = 'relu'
    drop = .5 
    kernal_reg = regularizers.l1(.001)
    dil_rate = 2
    
    
    model = Sequential() 
    
    model.add(Conv2D(64, kernel_size=(3,3),activation=act, input_shape = inp_shape, 
                     kernel_regularizer = kernal_reg,
                     kernel_initializer = 'he_uniform',  padding = 'same', name = 'Input_Layer'))
    model.add(Dense(64, activation = 'relu'))
    model.add(MaxPooling2D(pool_size=(2, 2),  strides = (2,2)))
    
    
    model.add(Conv2D(64, (3, 3), activation=act, kernel_regularizer = kernal_reg, dilation_rate = dil_rate, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(Dense(64, activation = 'relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = (2,2)))
    

    
    model.add(Conv2D(128, (3, 3), activation=act, kernel_regularizer = kernal_reg, dilation_rate = dil_rate, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(Conv2D(128, (3, 3), activation=act, kernel_regularizer = kernal_reg, dilation_rate = dil_rate, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = (2,2)))

    
    model.add(Flatten())

    
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))


    model.add(Dropout(drop))

    model.add(Dense(1, activation='sigmoid', name = 'Output_Layer'))
    
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

# %%
def get_samples_norm(): 
    x_train = pickle.load(open(f'../Pickles/x_train.p', 'rb'))
    x_test = pickle.load(open(f'../Pickles/x_test.p', 'rb'))
    y_train = pickle.load(open(f'../Pickles/y_train.p', 'rb'))
    y_test = pickle.load(open(f'../Pickles/y_test.p', 'rb'))
    return x_train, x_test, y_train, y_test
x_train, x_test, y_train, y_test = get_samples_norm()

# %%
x_train.shape
# Out:
# (151, 96, 96, 3)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator


augment = True 
early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=15, min_delta = .002)
model_checkpoint = ModelCheckpoint('../models/CNN-ModelCheckpointWeights.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 3, mode = 'min')
epochs = 50
batch_size = 32
if var.img_type == 'grey': 
    dim = (var.dimension[0], var.dimension[1], 1)
else: 
    dim = (var.dimension[0], var.dimension[1], 3)
    
normal_model = get_conv_model_normal(dim =dim)

if augment: 
    augmentation =ImageDataGenerator(rotation_range = 15, width_shift_range = .1, height_shift_range = .1, 
                                                           horizontal_flip = True, fill_mode = 'nearest')
    augmentation.fit(x_train)
    normal_history = normal_model.fit_generator(augmentation.flow(x_train, y_train, batch_size = batch_size),
                epochs = epochs, 
         callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
else: 
    
    normal_history = normal_model.fit(x_train, y_train, batch_size = batch_size,
                epochs = epochs, 
         callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 26s 5s/step - loss: 11.8102 - acc: 0.6785 - val_loss: 11.1656 - val_acc: 0.6615
#
# Epoch 00001: val_loss improved from inf to 11.16562, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch
saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 17/50
# 5/5 [==============================] - 1s 139ms/step - loss: 2.9250 - acc: 0.8530 - val_loss: 2.7942 - val_acc: 0.8769
#
# Epoch 00017: val_loss improved from 2.93767 to 2.79419, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 18/50
# 5/5 [==============================] - 1s 137ms/step - loss: 2.6728 - acc: 0.8907 - val_loss: 2.5742 - val_acc: 0.8923
#
# Epoch 00018: val_loss improved from 2.79419 to 2.57421, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 19/50
# 5/5 [==============================] - 1s 139ms/step - loss: 2.6111 - acc: 0.8699 - val_loss: 2.4879 - val_acc: 0.8462
#
# Epoch 00019: val_loss improved from 2.57421 to 2.48787, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 20/50
# 5/5 [==============================] - 1s 137ms/step - loss: 2.4812 - acc: 0.8719 - val_loss: 2.5072 - val_acc: 0.8308
#
# Epoch 00020: val_loss did not improve from 2.48787
# Epoch 21/50
# 5/5 [==============================] - 1s 140ms/step - loss: 2.3372 - acc: 0.8676 - val_loss: 2.2523 - val_acc: 0.8769
#
# Epoch 00021: val_loss improved from 2.48787 to 2.25232, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 22/50
# 5/5 [==============================] - 1s 140ms/step - loss: 2.3612 - acc: 0.8088 - val_loss: 2.2615 - val_acc: 0.8462
#
# Epoch 00022: val_loss did not improve from 2.25232
# Epoch 23/50
# 5/5 [==============================] - 1s 139ms/step - loss: 2.2649 - acc: 0.8300 - val_loss: 2.1865 - val_acc: 0.8308
#
# Epoch 00023: val_loss improved from 2.25232 to 2.18648, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 24/50
# 5/5 [==============================] - 1s 136ms/step - loss: 2.1872 - acc: 0.8634 - val_loss: 2.0696 - val_acc: 0.8615
#
# Epoch 00024: val_loss improved from 2.18648 to 2.06959, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 25/50
# 5/5 [==============================] - 1s 139ms/step - loss: 2.0705 - acc: 0.8740 - val_loss: 2.0364 - val_acc: 0.8615
#
# Epoch 00025: val_loss improved from 2.06959 to 2.03643, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 26/50
# 5/5 [==============================] - 1s 140ms/step - loss: 2.0309 - acc: 0.8823 - val_loss: 1.9860 - val_acc: 0.8615
#
# Epoch 00026: val_loss improved from 2.03643 to 1.98605, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 27/50
# 5/5 [==============================] - 1s 137ms/step - loss: 1.9321 - acc: 0.8886 - val_loss: 1.9357 - val_acc: 0.8462
#
# Epoch 00027: val_loss improved from 1.98605 to 1.93568, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 28/50
# 5/5 [==============================] - 1s 139ms/step - loss: 1.8961 - acc: 0.8699 - val_loss: 1.8878 - val_acc: 0.8462
#
# Epoch 00028: val_loss improved from 1.93568 to 1.88782, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 29/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.8001 - acc: 0.8699 - val_loss: 1.8956 - val_acc: 0.8154
#
# Epoch 00029: val_loss did not improve from 1.88782
# Epoch 30/50
# 5/5 [==============================] - 1s 139ms/step - loss: 1.7758 - acc: 0.8886 - val_loss: 1.8331 - val_acc: 0.8615
#
# Epoch 00030: val_loss improved from 1.88782 to 1.83307, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 31/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.7040 - acc: 0.8825 - val_loss: 1.7153 - val_acc: 0.8615
#
# Epoch 00031: val_loss improved from 1.83307 to 1.71535, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 32/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.7646 - acc: 0.8363 - val_loss: 1.8497 - val_acc: 0.8308
#
# Epoch 00032: val_loss did not improve from 1.71535
# Epoch 33/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.6792 - acc: 0.8697 - val_loss: 1.6622 - val_acc: 0.8462
#
# Epoch 00033: val_loss improved from 1.71535 to 1.66222, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 34/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.6367 - acc: 0.8843 - val_loss: 1.7549 - val_acc: 0.8000
#
# Epoch 00034: val_loss did not improve from 1.66222
# Epoch 35/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.6062 - acc: 0.8699 - val_loss: 1.6894 - val_acc: 0.8154
#
# Epoch 00035: val_loss did not improve from 1.66222
# Epoch 36/50
# 5/5 [==============================] - 1s 139ms/step - loss: 1.5950 - acc: 0.8762 - val_loss: 1.6428 - val_acc: 0.8615
#
# Epoch 00036: val_loss improved from 1.66222 to 1.64277, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 37/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.5709 - acc: 0.8803 - val_loss: 1.7124 - val_acc: 0.8154
#
# Epoch 00037: val_loss did not improve from 1.64277
# Epoch 38/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.5049 - acc: 0.8949 - val_loss: 1.5844 - val_acc: 0.8462
#
# Epoch 00038: val_loss improved from 1.64277 to 1.58444, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 39/50
# 5/5 [==============================] - 1s 139ms/step - loss: 1.4903 - acc: 0.8845 - val_loss: 1.6142 - val_acc: 0.8462
#
# Epoch 00039: val_loss did not improve from 1.58444
# Epoch 40/50
# 5/5 [==============================] - 1s 139ms/step - loss: 1.4683 - acc: 0.8886 - val_loss: 1.5697 - val_acc: 0.8000
#
# Epoch 00040: val_loss improved from 1.58444 to 1.56966, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 41/50
# 5/5 [==============================] - 1s 139ms/step - loss: 1.3940 - acc: 0.9159 - val_loss: 1.5632 - val_acc: 0.8308
#
# Epoch 00041: val_loss improved from 1.56966 to 1.56316, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 42/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.3760 - acc: 0.9159 - val_loss: 1.5801 - val_acc: 0.8462
#
# Epoch 00042: val_loss did not improve from 1.56316
# Epoch 43/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.3398 - acc: 0.9096 - val_loss: 1.7919 - val_acc: 0.8000
#
# Epoch 00043: val_loss did not improve from 1.56316
# Epoch 44/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.4214 - acc: 0.8634 - val_loss: 1.5780 - val_acc: 0.8154
#
# Epoch 00044: val_loss did not improve from 1.56316
# Epoch 45/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.3630 - acc: 0.8823 - val_loss: 1.5638 - val_acc: 0.8154
#
# Epoch 00045: val_loss did not improve from 1.56316
# Epoch 46/50
# 5/5 [==============================] - 1s 137ms/step - loss: 1.3168 - acc: 0.9179 - val_loss: 1.4815 - val_acc: 0.8308
#
# Epoch 00046: val_loss improved from 1.56316 to 1.48152, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 47/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.3234 - acc: 0.9116 - val_loss: 1.4391 - val_acc: 0.8615
#
# Epoch 00047: val_loss improved from 1.48152 to 1.43913, saving model to ../models/CNN-ModelCheckpointWeights.h5
# Epoch 48/50
# 5/5 [==============================] - 1s 139ms/step - loss: 1.3070 - acc: 0.9222 - val_loss: 1.4464 - val_acc: 0.8615
#
# Epoch 00048: val_loss did not improve from 1.43913
# Epoch 49/50
# 5/5 [==============================] - 1s 140ms/step - loss: 1.3030 - acc: 0.9222 - val_loss: 1.4995 - val_acc: 0.8308
#
# Epoch 00049: val_loss did not improve from 1.43913
# Epoch 50/50
# 5/5 [==============================] - 1s 137ms/step - loss: 1.2772 - acc: 0.9202 - val_loss: 1.5158 - val_acc: 0.8308
#
# Epoch 00050: val_loss did not improve from 1.43913

# %%
print(normal_model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Layer (Conv2D)         (None, 96, 96, 64)        1792
# _________________________________________________________________
# dense_6 (Dense)              (None, 96, 96, 64)        4160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# dense_7 (Dense)              (None, 48, 48, 64)        4160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               2359424
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# Output_Layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 2,638,273
# Trainable params: 2,638,273
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Loss & Accuracy

# %%
train_loss = normal_history.history['loss']
train_acc = normal_history.history['acc']
test_loss = normal_history.history['val_loss']
test_acc = normal_history.history['val_acc']
epochs = [i for i in range(1, len(test_acc)+1)]

fig, ax = plt.subplots(1,2, figsize = (15,5))
ax[0].plot(epochs, train_loss, label = 'Train Loss')
ax[0].plot(epochs, test_loss, label = 'Test Loss')
ax[0].set_title('Train/Test Loss')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].legend()

ax[1].plot(epochs, train_acc, label = 'Train Accuracy')
ax[1].plot(epochs, test_acc, label = 'Test Accuracy')
ax[1].set_title('Train/Test Accuracy')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend()

# %%
y_test.shape
# Out:
# (65, 1)

# %% [markdown]
# ### AUC and ROC Curves

# %%
from sklearn.metrics import roc_curve, roc_auc_score, precision_recall_curve, f1_score, auc

if var.img_type == 'grey': 
    dim = (var.dimension[0], var.dimension[1], 1)
else: 
    dim = (var.dimension[0], var.dimension[1], 3)
    
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights.h5') #load the best weights before overfitting
 

fig, ax = plt.subplots(1,2, figsize = (15,6))
#AUC CURVE
y_test_prob = normal_model.predict(x_test)

y_test_precision, y_test_recall, spec = precision_recall_curve(y_test, y_test_prob)
y_test_predict = np.where(y_test_prob >= .5, 1, 0).ravel()
y_test_f1= f1_score(y_test, y_test_predict)
y_test_auc = auc(y_test_recall, y_test_precision)
no_skill = len(y_test[y_test==1]) / len(y_test)
ax[0].plot(y_test_recall, y_test_precision, marker='.', label='CNN')
ax[0].plot([0, 1], [no_skill, no_skill], linestyle='--', label='50/50', color = 'Black')
ax[0].set_xlabel('Recall')
ax[0].set_ylabel('Precision')
ax[0].set_title(f'AUC Curve')
ax[0].legend()

#ROC CURVE
ns_probs = [0 for i in range(len(y_test))]
ns_auc = roc_auc_score(y_test, ns_probs)
y_test_roc = roc_auc_score(y_test, y_test_prob)

ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
y_test_fpr, y_test_tpr, threshold = roc_curve(y_test, y_test_prob)
ax[1].plot(ns_fpr, ns_tpr, linestyle='--', label='50/50')
ax[1].plot(y_test_fpr, y_test_tpr, marker='.', label='CNN')
ax[1].set_xlabel('False Positive Rate')
ax[1].set_ylabel('True Positive Rate')
ax[1].set_title(f'ROC Curve')
ax[1].legend()
plt.show()

pd.DataFrame({'F1 Score': round(y_test_f1, 3), 'AUC': round(y_test_auc, 3), 'ROC':round(y_test_roc, 3)}, index = [0])
# Out:
#    F1 Score    AUC    ROC
# 0     0.809  0.901  0.942

# %%
df = pd.DataFrame({'Threshold': threshold, 'FPR': y_test_fpr, 'TPR': y_test_tpr})
plt.plot(df.Threshold, df.FPR, label = 'False Positive Rate')
plt.plot(df.Threshold, df.TPR, label = 'True Positive Rate')
plt.xlabel('Threshold')
plt.ylabel('FPR/TPR')
plt.title('Change in FPR/TPR with Threshold')
plt.xlim(0, 1)
plt.legend()
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import itertools
import seaborn as sns
def plot_confusion_matrix(y_test,y_train, y_train_prob, y_test_prob,thresholds, classes,
                          cmap=plt.cm.Blues):
    fig, ax = plt.subplots(len(thresholds),2, figsize = (10,10))

    for idx, thresh in enumerate(thresholds):
        y_test_predict = np.where(y_test_prob >= thresh, 1, 0)
        y_train_predict = np.where(y_train_prob >= thresh, 1, 0)
        train_cm = confusion_matrix(y_train, y_train_predict) 
        test_cm = confusion_matrix(y_test, y_test_predict)
        
        #test confusion
        ax[idx, 0].imshow(test_cm,  cmap=plt.cm.Blues) 

        ax[idx, 0].set_title(f'Test: Confusion Matrix | Threshold: {thresh}')
        ax[idx, 0].set_ylabel('True label')
        ax[idx, 0].set_xlabel('Predicted label')

        class_names = classes 
        tick_marks = np.arange(len(class_names))
        ax[idx, 0].set_xticks(tick_marks)
        ax[idx,0].set_xticklabels(class_names)
        ax[idx, 0].set_yticks(tick_marks)
        ax[idx, 0].set_yticklabels(class_names)

        th = test_cm.max() / 2. 

        for i, j in itertools.product(range(test_cm.shape[0]), range(test_cm.shape[1])):
                ax[idx, 0].text(j, i, f'{test_cm[i, j]}',# | {int(round(test_cm[i,j]/test_cm.ravel().sum(),5)*100)}%',
                         horizontalalignment='center',
                         color='white' if test_cm[i, j] > th else 'black')
        ax[idx, 0].set_ylim([-.5,1.5])
        
        #TRAIN CONFUSION
        ax[idx, 1].imshow(train_cm,  cmap=plt.cm.Blues) 

        ax[idx, 1].set_title(f'Train: Confusion Matrix | Threshold: {thresh}')
        ax[idx, 1].set_ylabel('True label')
        ax[idx, 1].set_xlabel('Predicted label')

        class_names = classes 
        tick_marks = np.arange(len(class_names))
        ax[idx, 1].set_xticks(tick_marks)
        ax[idx,1].set_xticklabels(class_names)
        ax[idx, 1].set_yticks(tick_marks)
        ax[idx, 1].set_yticklabels(class_names)


        th = train_cm.max() / 2. 

        for i, j in itertools.product(range(train_cm.shape[0]), range(train_cm.shape[1])):
                ax[idx, 1].text(j, i, f'{train_cm[i, j]}',# | {int(round(train_cm[i,j]/train_cm.ravel().sum(),5)*100)}%',
                         horizontalalignment='center',
                         color='white' if train_cm[i, j] > th else 'black')
        ax[idx, 1].set_ylim([-.5,1.5])
    plt.tight_layout()
 
    plt.show()
if var.img_type == 'grey': 
    dim = (var.dimension[0], var.dimension[1], 1)
else: 
    dim = (var.dimension[0], var.dimension[1], 3)
        
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights.h5') #load the best weights before overfitting

y_test_prob = normal_model.predict(x_test).ravel()

y_train_prob = normal_model.predict(x_train).ravel()

plot_confusion_matrix(y_train = y_train, y_test = y_test, y_train_prob = y_train_prob,
                      y_test_prob = y_test_prob,classes = ['No Weapon', 'Weapon'], thresholds = [.2, .5,.6])

# %% [markdown]
# #### Test on Google Data

# %%
import cv2
from lime import lime_image
from skimage.segmentation import mark_boundaries

if var.img_type == 'grey': 
    dim = (var.dimension[0], var.dimension[1], 1)
else: 
    dim = (var.dimension[0], var.dimension[1], 3)
        
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights.h5')
img = func.get_image_value('../test2.jpg', var.dimension, var.img_type)

explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(img, normal_model.predict, top_labels = 5, hide_color = 0, 
                                         num_samples = 1000)

temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only = False,
                                           num_features = 10, hide_rest = False)
plt.imshow(mark_boundaries(temp/2 + .5, mask))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
if var.img_type == 'grey': 
    dim = (var.dimension[0], var.dimension[1], 1)
else: 
    dim = (var.dimension[0], var.dimension[1], 3)
        
normal_model = get_conv_model_normal(dim)
normal_model.load_weights('../models/CNN-ModelCheckpointWeights.h5')

img = cv2.imread('../test2.jpg')
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
ss.setBaseImage(img)
ss.switchToSelectiveSearchFast()
rects = ss.process() 

windows = []
locations = []
for x, y, w,h in rects: 
    startx = x 
    starty = y 
    endx = x+w 
    endy = y+h 
    roi = img[starty:endy, startx:endx]
    roi = cv2.resize(roi, dsize =var.dimension, interpolation = cv2.INTER_CUBIC)
    windows.append(roi)
    locations.append((startx, starty, endx, endy))

# %%
windows = np.array(windows)

predictions = normal_model.predict(windows)

# %%
clone = img.copy()
new_loc = [] 
new_prob = [] 
for idx, i in enumerate(predictions): 
    if i < .5: 
        continue
    startx, starty, endx, endy = locations[idx]
    cv2.rectangle(clone, (startx, starty), (endx, endy),  (0,255,0),2)
    text = f'Weapon: {i*100}'
    cv2.putText(clone, text, (startx, y), cv2.FONT_HERSHEY_SIMPLEX, .45, (0,255,0),2)
    new_loc.append(locations[idx])
    new_prob.append(i[0])

# %%
new_loc
# Out:
# [(370, 139, 419, 223),
#  (863, 304, 919, 400),
#  (871, 360, 912, 496),
#  (682, 368, 693, 414),
#  (936, 155, 952, 179),
#  (367, 138, 640, 391),
#  (376, 77, 392, 141),
#  (517, 186, 723, 217),
#  (386, 78, 442, 90),
#  (801, 560, 862, 591),
#  (0, 0, 624, 720),
#  (909, 306, 943, 320),
#  (693, 283, 814, 345),
#  (733, 454, 776, 475),
#  (272, 64, 504, 220),
#  (656, 124, 728, 127),
#  (861, 220, 1041, 408),
#  (865, 236, 954, 284),
#  (375, 71, 418, 134),
#  (876, 233, 917, 244),
#  (397, 161, 464, 178),
#  (637, 512, 675, 542),
#  (506, 360, 533, 368),
#  (783, 10, 1280, 720),
#  (816, 545, 856, 576),
#  (672, 223, 833, 367),
#  (873, 287, 965, 346),
#  (880, 401, 905, 513),
#  (693, 424, 864, 553),
#  (587, 202, 661, 237),
#  (740, 330, 812, 345),
#  (809, 142, 945, 159),
#  (875, 288, 965, 320),
#  (832, 144, 945, 159),
#  (912, 284, 995, 379),
#  (796, 155, 968, 284),
#  (433, 268, 528, 377),
#  (796, 155, 968, 280),
#  (369, 100, 993, 575),
#  (320, 64, 475, 352),
#  (369, 100, 879, 323),
#  (795, 219, 968, 522),
#  (867, 269, 993, 380),
#  (474, 209, 700, 417),
#  (320, 64, 631, 428),
#  (413, 173, 581, 239),
#  (663, 368, 718, 529),
#  (679, 155, 971, 541),
#  (705, 523, 856, 576),
#  (863, 224, 1064, 432),
#  (373, 100, 593, 239),
#  (272, 64, 529, 220),
#  (433, 234, 736, 559),
#  (416, 0, 1191, 304),
#  (720, 464, 909, 623),
#  (141, 0, 591, 113),
#  (871, 319, 971, 560),
#  (320, 0, 982, 720),
#  (433, 258, 626, 393),
#  (369, 86, 948, 342),
#  (682, 279, 859, 552),
#  (369, 120, 657, 335),
#  (255, 138, 807, 720),
#  (369, 139, 879, 266),
#  (856, 287, 971, 541),
#  (655, 368, 718, 529),
#  (369, 120, 626, 335),
#  (594, 208, 701, 416),
#  (369, 23, 1280, 720),
#  (679, 152, 971, 720),
#  (360, 0, 1260, 319),
#  (861, 305, 968, 512),
#  (433, 181, 581, 239),
#  (365, 77, 759, 393),
#  (419, 165, 607, 239),
#  (691, 266, 847, 418),
#  (368, 77, 1064, 592),
#  (813, 0, 1280, 720),
#  (795, 214, 969, 387),
#  (369, 189, 504, 288),
#  (893, 202, 1064, 379),
#  (556, 199, 884, 575),
#  (800, 214, 970, 426),
#  (684, 424, 864, 564),
#  (387, 78, 961, 192),
#  (757, 0, 1280, 720),
#  (861, 224, 1064, 573),
#  (480, 340, 665, 416),
#  (320, 0, 982, 524),
#  (757, 0, 1280, 624),
#  (472, 207, 747, 408),
#  (352, 71, 504, 353),
#  (416, 0, 1257, 319),
#  (795, 214, 993, 526),
#  (657, 504, 831, 561),
#  (261, 224, 807, 720),
#  (655, 368, 728, 545),
#  (369, 77, 952, 335),
#  (352, 71, 948, 447),
#  (656, 369, 889, 574),
#  (420, 247, 719, 592),
#  (608, 491, 927, 720),
#  (0, 0, 832, 287),
#  (448, 0, 974, 164),
#  (796, 155, 963, 265),
#  ...]

# %%
boxids = func.non_max_suppression(np.array(new_loc), np.array(new_prob))[0]
boxids
# Out:
# 1095

# %%
clone = img.copy()
  
startx, starty, endx, endy = new_loc[268]
cv2.rectangle(clone, (startx, starty), (endx, endy),  (0,255,0),2)
text = f'Weapon: {i*100}'
cv2.putText(clone, text, (startx, y), cv2.FONT_HERSHEY_SIMPLEX, .45, (0,255,0),2)
cv2.imshow('test', clone)
cv2.waitKey(0)
# Out:
# -1

# %%
clone = img.copy()
roi = clone[starty:endy, startx:endx]
roi = cv2.resize(roi, dsize =var.dimension, interpolation = cv2.INTER_CUBIC)
# cv2.imshow('test', roi)
# cv2.waitKey(0)
explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(roi, normal_model.predict, top_labels = 5, hide_color = 0, 
                                         num_samples = 1000)


temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only = False,
                                           num_features = 10, hide_rest = False)
plt.imshow(mark_boundaries(temp/2 + .5, mask))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
