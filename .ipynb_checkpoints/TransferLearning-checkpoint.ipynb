# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import MobileNetV2
from keras.layers import AveragePooling2D, Dropout, Flatten, Dense, Input
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.applications.mobilenet_v2 import preprocess_input
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os
import pandas as pd
from PyFunctions import Functions as func
from PyFunctions import var
from PyFunctions import Viz
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# Out:
# Using plaidml.keras.backend backend.

# %% [markdown]
# ### Mobilenet

# %%
def get_mobilenet(dim):
    model = Sequential()
    optimizer = Adam(lr = .0005)
    baseModel = MobileNetV2(weights="imagenet", include_top=False,
        input_tensor=Input(shape=dim))
    
    model.add(baseModel)
    headModel = model.add(AveragePooling2D(pool_size=(7, 7)))
    headModel = model.add(Flatten(name="flatten"))
    headModel = model.add(Dense(256, activation="relu"))
    headModel = model.add(Dropout(0.3))
    headModel = model.add(Dense(3, activation="softmax", name = 'Output'))

    for layer in baseModel.layers:
        layer.trainable = False
    
    model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])
    return model

# %%
x_train, x_test, y_train, y_test = func.get_tts('mobilenet', version =2, edge = False, balance = True)
# Out:
# Train Value Counts
# 1    1368
# 0    1368
# 2    1233
# dtype: int64
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Test Value Counts
# 1    152
# 0    152
# 2    137
# dtype: int64
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# X Train Shape
# (3969, 224, 224, 3)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# X Test Shape
# (441, 224, 224, 3)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=30, min_delta = .00075)
model_checkpoint = ModelCheckpoint('ModelWeights/Mobilenet.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 5, mode = 'min')
epochs = 2000
batch_size = 16

dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 3)
    
mobile_net = get_mobilenet(dim =dim)

    
mobilenet_history = mobile_net.fit(x_train, y_train, batch_size = batch_size,
            epochs = epochs, 
     callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
# Out:
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"
# C:\Users\Heeeb\Anaconda3\lib\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Train on 3969 samples, validate on 441 samples
# Epoch 1/2000
# 3969/3969 [==============================] - 75s 19ms/step - loss: 0.5884 - acc: 0.7503 - val_loss: 0.8567 - val_acc: 0.6531
#
# Epoch 00001: val_loss improved from inf to 0.85672, saving model to ModelWeights/Mobilenet.h5
# Epoch 2/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.4936 - acc: 0.7994 - val_loss: 1.0359 - val_acc: 0.6145
#
# Epoch 00002: val_loss did not improve from 0.85672
# Epoch 3/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.4457 - acc: 0.8188 - val_loss: 0.5701 - val_acc: 0.7846
#
# Epoch 00003: val_loss improved from 0.85672 to 0.57008, saving model to ModelWeights/Mobilenet.h5
# Epoch 4/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.4156 - acc: 0.8282 - val_loss: 0.7766 - val_acc: 0.7392
#
# Epoch 00004: val_loss did not improve from 0.57008
# Epoch 5/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.4065 - acc: 0.8304 - val_loss: 0.5470 - val_acc: 0.7710
#
# Epoch 00005: val_loss improved from 0.57008 to 0.54703, saving model to ModelWeights/Mobilenet.h5
# Epoch 6/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.4125 - acc: 0.8330 - val_loss: 0.4759 - val_acc: 0.8163
#
# Epoch 00006: val_loss improved from 0.54703 to 0.47591, saving model to ModelWeights/Mobilenet.h5
# Epoch 7/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.3784 - acc: 0.8478 - val_loss: 0.4443 - val_acc: 0.8141
#
# Epoch 00007: val_loss improved from 0.47591 to 0.44430, saving model to ModelWeights/Mobilenet.h5
# Epoch 8/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.3533 - acc: 0.8597 - val_loss: 0.4965 - val_acc: 0.8163
#
# Epoch 00008: val_loss did not improve from 0.44430
# Epoch 9/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.3529 - acc: 0.8556 - val_loss: 0.4685 - val_acc: 0.8050
#
# Epoch 00009: val_loss did not improve from 0.44430
# Epoch 10/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.3566 - acc: 0.8549 - val_loss: 0.5000 - val_acc: 0.8050
#
# Epoch 00010: val_loss did not improve from 0.44430
# Epoch 11/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.3364 - acc: 0.8622 - val_loss: 0.4393 - val_acc: 0.8322
#
# Epoch 00011: val_loss improved from 0.44430 to 0.43930, saving model to ModelWeights/Mobilenet.h5
# Epoch 12/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.3176 - acc: 0.8682 - val_loss: 0.3957 - val_acc: 0.8435
#
# Epoch 00012: val_loss improved from 0.43930 to 0.39574, saving model to ModelWeights/Mobilenet.h5
# Epoch 13/2000
# 3969/3969 [==============================] - 27s 7ms/step - loss: 0.3238 - acc: 0.8695 - val_loss: 0.3934 - val_acc: 0.8413
#
# Epoch 00013: val_loss improved from 0.39574 to 0.39338, saving model to ModelWeights/Mobilenet.h5
# Epoch 14/2000
# 3969/3969 [==============================] - 28s 7ms/step - loss: 0.3085 - acc: 0.8758 - val_loss: 0.3644 - val_acc: 0.8390
#
# Epoch 00014: val_loss improved from 0.39338 to 0.36437, saving model to ModelWeights/Mobilenet.h5
# Epoch 15/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.2938 - acc: 0.8869 - val_loss: 0.3568 - val_acc: 0.8571
#
# Epoch 00015: val_loss improved from 0.36437 to 0.35679, saving model to ModelWeights/Mobilenet.h5
# Epoch 16/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.2904 - acc: 0.8899 - val_loss: 0.3806 - val_acc: 0.8277
#
# Epoch 00016: val_loss did not improve from 0.35679
# Epoch 17/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.2898 - acc: 0.8841 - val_loss: 0.4045 - val_acc: 0.8435
#
# Epoch 00017: val_loss did not improve from 0.35679
# Epoch 18/2000
# 3969/3969 [==============================] - 27s 7ms/step - loss: 0.2689 - acc: 0.8879 - val_loss: 0.3548 - val_acc: 0.8503
#
# Epoch 00018: val_loss improved from 0.35679 to 0.35476, saving model to ModelWeights/Mobilenet.h5
# Epoch 19/2000
# 3969/3969 [==============================] - 27s 7ms/step - loss: 0.2652 - acc: 0.8934 - val_loss: 0.3732 - val_acc: 0.8526
#
# Epoch 00019: val_loss did not improve from 0.35476
# Epoch 20/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.2589 - acc: 0.9030 - val_loss: 0.3808 - val_acc: 0.8413
#
# Epoch 00020: val_loss did not improve from 0.35476
# Epoch 21/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.2337 - acc: 0.9080 - val_loss: 0.3832 - val_acc: 0.8526
#
# Epoch 00021: val_loss did not improve from 0.35476
# Epoch 22/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.2589 - acc: 0.9033 - val_loss: 0.3512 - val_acc: 0.8503
#
# Epoch 00022: val_loss improved from 0.35476 to 0.35117, saving model to ModelWeights/Mobilenet.h5
# Epoch 23/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.2293 - acc: 0.9148 - val_loss: 0.3715 - val_acc: 0.8526
#
# Epoch 00023: val_loss did not improve from 0.35117
# Epoch 24/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.2116 - acc: 0.9186 - val_loss: 0.3466 - val_acc: 0.8707
#
# Epoch 00024: val_loss improved from 0.35117 to 0.34655, saving model to ModelWeights/Mobilenet.h5
# Epoch 25/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.2364 - acc: 0.9078 - val_loss: 0.4056 - val_acc: 0.8571
#
# Epoch 00025: val_loss did not improve from 0.34655
# Epoch 26/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.2068 - acc: 0.9219 - val_loss: 0.3544 - val_acc: 0.8594
#
# Epoch 00026: val_loss did not improve from 0.34655
# Epoch 27/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.2269 - acc: 0.9101 - val_loss: 0.3423 - val_acc: 0.8639
#
# Epoch 00027: val_loss improved from 0.34655 to 0.34232, saving model to ModelWeights/Mobilenet.h5
# Epoch 28/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1964 - acc: 0.9282 - val_loss: 0.3451 - val_acc: 0.8639
#
# Epoch 00028: val_loss did not improve from 0.34232
# Epoch 29/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.1983 - acc: 0.9237 - val_loss: 0.3416 - val_acc: 0.8730
#
# Epoch 00029: val_loss improved from 0.34232 to 0.34158, saving model to ModelWeights/Mobilenet.h5
# Epoch 30/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.2061 - acc: 0.9229 - val_loss: 0.3527 - val_acc: 0.8662
#
# Epoch 00030: val_loss did not improve from 0.34158
# Epoch 31/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.2075 - acc: 0.9158 - val_loss: 0.3518 - val_acc: 0.8753
#
# Epoch 00031: val_loss did not improve from 0.34158
# Epoch 32/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.1828 - acc: 0.9335 - val_loss: 0.4161 - val_acc: 0.8526
#
# Epoch 00032: val_loss did not improve from 0.34158
# Epoch 33/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.1908 - acc: 0.9244 - val_loss: 0.3380 - val_acc: 0.8798
#
# Epoch 00033: val_loss improved from 0.34158 to 0.33802, saving model to ModelWeights/Mobilenet.h5
# Epoch 34/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1755 - acc: 0.9350 - val_loss: 0.4144 - val_acc: 0.8594
#
# Epoch 00034: val_loss did not improve from 0.33802
# Epoch 35/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1940 - acc: 0.9267 - val_loss: 0.4394 - val_acc: 0.8526
#
# Epoch 00035: val_loss did not improve from 0.33802
# Epoch 36/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1700 - acc: 0.9335 - val_loss: 0.3642 - val_acc: 0.8844
#
# Epoch 00036: val_loss did not improve from 0.33802
# Epoch 37/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1832 - acc: 0.9332 - val_loss: 0.3574 - val_acc: 0.8776
#
# Epoch 00037: val_loss did not improve from 0.33802
# Epoch 38/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1728 - acc: 0.9365 - val_loss: 0.3905 - val_acc: 0.8639
#
# Epoch 00038: val_loss did not improve from 0.33802
# Epoch 39/2000
# 3969/3969 [==============================] - 27s 7ms/step - loss: 0.1305 - acc: 0.9541 - val_loss: 0.3388 - val_acc: 0.8798
#
# Epoch 00039: val_loss did not improve from 0.33802
# Epoch 40/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1262 - acc: 0.9559 - val_loss: 0.3408 - val_acc: 0.8798
#
# Epoch 00040: val_loss did not improve from 0.33802
# Epoch 41/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1219 - acc: 0.9599 - val_loss: 0.3451 - val_acc: 0.8798
#
# Epoch 00041: val_loss did not improve from 0.33802
# Epoch 42/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1151 - acc: 0.9620 - val_loss: 0.3548 - val_acc: 0.8821
#
# Epoch 00042: val_loss did not improve from 0.33802
# Epoch 43/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1205 - acc: 0.9569 - val_loss: 0.3512 - val_acc: 0.8844
#
# Epoch 00043: val_loss did not improve from 0.33802
# Epoch 44/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1088 - acc: 0.9620 - val_loss: 0.3505 - val_acc: 0.8866
#
# Epoch 00044: val_loss did not improve from 0.33802
# Epoch 45/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1203 - acc: 0.9564 - val_loss: 0.3476 - val_acc: 0.8866
#
# Epoch 00045: val_loss did not improve from 0.33802
# Epoch 46/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1221 - acc: 0.9564 - val_loss: 0.3484 - val_acc: 0.8866
#
# Epoch 00046: val_loss did not improve from 0.33802
# Epoch 47/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1108 - acc: 0.9607 - val_loss: 0.3487 - val_acc: 0.8844
#
# Epoch 00047: val_loss did not improve from 0.33802
# Epoch 48/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1092 - acc: 0.9615 - val_loss: 0.3484 - val_acc: 0.8866
#
# Epoch 00048: val_loss did not improve from 0.33802
# Epoch 49/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1176 - acc: 0.9579 - val_loss: 0.3488 - val_acc: 0.8866
#
# Epoch 00049: val_loss did not improve from 0.33802
# Epoch 50/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1163 - acc: 0.9592 - val_loss: 0.3482 - val_acc: 0.8866
#
# Epoch 00050: val_loss did not improve from 0.33802
# Epoch 51/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1134 - acc: 0.9602 - val_loss: 0.3485 - val_acc: 0.8866
#
# Epoch 00051: val_loss did not improve from 0.33802
# Epoch 52/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1229 - acc: 0.9552 - val_loss: 0.3482 - val_acc: 0.8866
#
# Epoch 00052: val_loss did not improve from 0.33802
# Epoch 53/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1036 - acc: 0.9662 - val_loss: 0.3483 - val_acc: 0.8866
#
# Epoch 00053: val_loss did not improve from 0.33802
# Epoch 54/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.1199 - acc: 0.9557 - val_loss: 0.3483 - val_acc: 0.8866
#
# Epoch 00054: val_loss did not improve from 0.33802
# Epoch 55/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1186 - acc: 0.9534 - val_loss: 0.3482 - val_acc: 0.8866
#
# Epoch 00055: val_loss did not improve from 0.33802
# Epoch 56/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.1196 - acc: 0.9549 - val_loss: 0.3481 - val_acc: 0.8866
#
# Epoch 00056: val_loss did not improve from 0.33802
# Epoch 57/2000
# 3969/3969 [==============================] - 26s 6ms/step - loss: 0.1167 - acc: 0.9562 - val_loss: 0.3477 - val_acc: 0.8866
#
# Epoch 00057: val_loss did not improve from 0.33802
# Epoch 58/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1071 - acc: 0.9627 - val_loss: 0.3476 - val_acc: 0.8866
#
# Epoch 00058: val_loss did not improve from 0.33802
# Epoch 59/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1184 - acc: 0.9589 - val_loss: 0.3477 - val_acc: 0.8866
#
# Epoch 00059: val_loss did not improve from 0.33802
# Epoch 60/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1134 - acc: 0.9604 - val_loss: 0.3476 - val_acc: 0.8866
#
# Epoch 00060: val_loss did not improve from 0.33802
# Epoch 61/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1080 - acc: 0.9637 - val_loss: 0.3471 - val_acc: 0.8866
#
# Epoch 00061: val_loss did not improve from 0.33802
# Epoch 62/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1221 - acc: 0.9584 - val_loss: 0.3467 - val_acc: 0.8866
#
# Epoch 00062: val_loss did not improve from 0.33802
# Epoch 63/2000
# 3969/3969 [==============================] - 26s 7ms/step - loss: 0.1187 - acc: 0.9567 - val_loss: 0.3467 - val_acc: 0.8866
#
# Epoch 00063: val_loss did not improve from 0.33802
# Epoch 00063: early stopping

# %%
Viz.plot_loss_accuracy(mobilenet_history, 'dark_background', path = 'figures/MobileLossAcc.png')

# %%
mobilenet = get_mobilenet(dim)
mobilenet.load_weights('ModelWeights/Mobilenet.h5') #load the best weights before overfitting

Viz.plot_roc_auc(mobilenet, x_test, y_test, 'dark_background', 'figures/MobileROC.png')
# Out:
# F1 Scores Test
# ~~~~~~~~~~~~~~~~~~~~~~
# No Weapon: 0.9205298013245033
# HandGun: 0.8516129032258065
# Rifle: 0.8666666666666667

# %%
mobilenet = get_mobilenet(dim)
mobilenet.load_weights('ModelWeights/Mobilenet.h5') #load the best weights before overfitting

y_test_prob = [np.argmax(i) for i in mobilenet.predict(x_test)]
y_test_labels = [np.argmax(
    i) for i in y_test]
test_cnf = confusion_matrix(y_test_labels, y_test_prob)

y_train_prob = [np.argmax(i) for i in mobilenet.predict(x_train)]
y_train_labels = [np.argmax(i) for i in y_train]
train_cnf = confusion_matrix(y_train_labels, y_train_prob)

Viz.plot_model_cm(test_cnf, train_cnf, classes = ['No Weapon', 'Handgun', 'Rifle'], theme = 'dark_background', 
                  path = 'figures/MobileCM.png')
