# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import MobileNetV2
from keras.layers import AveragePooling2D, Dropout, Flatten, Dense, Input
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.applications.mobilenet_v2 import preprocess_input
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os
import pandas as pd
import GetPickles
import var
# Out:
# Using plaidml.keras.backend backend.

# %%
def get_mobile_net(dim):
    model = Sequential()
    baseModel = MobileNetV2(weights="imagenet", include_top=False,
        input_tensor=Input(shape=dim))
    
    model.add(baseModel)
    headModel = model.add(AveragePooling2D(pool_size=(7, 7)))
    headModel = model.add(Flatten(name="flatten"))
    headModel = model.add(Dense(256, activation="relu"))
    headModel = model.add(Dropout(0.3))
    headModel = model.add(Dense(1, activation="sigmoid", name = 'Output'))

    # place the head FC model on top of the base model (this will become
    # the actual model we will train)


    # loop over all layers in the base model and freeze them so they will
    # *not* be updated during the first training process
    for layer in baseModel.layers:
        layer.trainable = False
    
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

# %%
x_train, x_test, y_train, y_test = GetPickles.get_samples('test')
print(x_train.shape, x_test.shape) 
print(y_train.shape, y_test.shape)

# %%
# Out:
# (7239, 224, 224, 3) (381, 224, 224, 3)
# (7239, 1) (381, 1)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator


augment = True 

early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=50,)
model_checkpoint = ModelCheckpoint('../models/Test_MobileNet-ModelCheckpointWeights.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 5, mode = 'min')
epochs = 300
batch_size = 16
if var.img_type == 'grey': 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 1)
else: 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 3)
    
mobile_net = get_mobile_net(dim =dim)

if augment: 
    augmentation =ImageDataGenerator(rotation_range = 15, width_shift_range = .1, height_shift_range = .1, 
                                                           horizontal_flip = True, fill_mode = 'nearest')
    augmentation.fit(x_train)
    mobile_net_history = mobile_net.fit_generator(augmentation.flow(x_train, y_train, batch_size = batch_size),
                epochs = epochs, steps_per_epoch = 8,
         callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
else: 
    
    mobile_net_history = mobile_net.fit(x_train, y_train, batch_size = batch_size,
                epochs = epochs, 
         callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
# Out:
# C:\Users\Heeeb\Anaconda3\lib\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"
# Epoch 1/300
# INFO:plaidml:Analyzing Ops: 1583 of 2049 operations complete
# 8/8 [==============================] - 39s 5s/step - loss: 0.3429 - acc: 0.8125 - val_loss: 0.1725 - val_acc: 0.9449
#
# Epoch 00001: val_loss improved from inf to 0.17248, saving model to ../models/Test_MobileNet-ModelCheckpointWeights.h5
# Epoch 2/300
# 8/8 [==============================] - 2s 237ms/step - loss: 0.1373 - acc: 0.9531 - val_loss: 0.2994 - val_acc: 0.8793
#
# Epoch 00002: val_loss did not improve from 0.17248
# Epoch 3/300
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0484 - acc: 0.9922 - val_loss: 0.0540 - val_acc: 0.9869
#
# Epoch 00003: val_loss improved from 0.17248 to 0.05397, saving model to ../models/Test_MobileNet-ModelCheckpointWeights.h5
# Epoch 4/300
# 8/8 [==============================] - 2s 223ms/step - loss: 0.0796 - acc: 0.9766 - val_loss: 0.4289 - val_acc: 0.8556
#
# Epoch 00004: val_loss did not improve from 0.05397
# Epoch 5/300
# 8/8 [==============================] - 2s 224ms/step - loss: 0.1380 - acc: 0.9531 - val_loss: 0.1603 - val_acc: 0.9423
#
# Epoch 00005: val_loss did not improve from 0.05397
# Epoch 6/300
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0310 - acc: 0.9844 - val_loss: 0.0600 - val_acc: 0.9843
#
# Epoch 00006: val_loss did not improve from 0.05397
# Epoch 7/300
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0740 - acc: 0.9688 - val_loss: 0.4897 - val_acc: 0.8320
#
# Epoch 00007: val_loss did not improve from 0.05397
# Epoch 8/300
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0664 - acc: 0.9688 - val_loss: 0.5472 - val_acc: 0.8294
#
# Epoch 00008: val_loss did not improve from 0.05397
# Epoch 9/300
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0479 - acc: 0.9766 - val_loss: 0.3730 - val_acc: 0.8845
#
# Epoch 00009: val_loss did not improve from 0.05397
# Epoch 10/300
# 8/8 [==============================] - 2s 225ms/step - loss: 0.0280 - acc: 0.9844 - val_loss: 0.2342 - val_acc: 0.9239
#
# Epoch 00010: val_loss did not improve from 0.05397
# Epoch 11/300
# 8/8 [==============================] - 2s 224ms/step - loss: 0.0404 - acc: 0.9766 - val_loss: 0.1839 - val_acc: 0.9370
#
# Epoch 00011: val_loss did not improve from 0.05397
# Epoch 12/300
# 8/8 [==============================] - 2s 225ms/step - loss: 0.0518 - acc: 0.9844 - val_loss: 0.1694 - val_acc: 0.9370
#
# Epoch 00012: val_loss did not improve from 0.05397
# Epoch 13/300
# 8/8 [==============================] - 2s 223ms/step - loss: 0.0323 - acc: 0.9922 - val_loss: 0.1909 - val_acc: 0.9344
#
# Epoch 00013: val_loss did not improve from 0.05397
# Epoch 14/300
# 8/8 [==============================] - 2s 224ms/step - loss: 0.0617 - acc: 0.9844 - val_loss: 0.1945 - val_acc: 0.9318
#
# Epoch 00014: val_loss did not improve from 0.05397
# Epoch 15/300
# 8/8 [==============================] - 2s 226ms/step - loss: 0.1117 - acc: 0.9688 - val_loss: 0.1938 - val_acc: 0.9318
#
# Epoch 00015: val_loss did not improve from 0.05397
# Epoch 16/300
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0380 - acc: 0.9766 - val_loss: 0.1885 - val_acc: 0.9370
#
# Epoch 00016: val_loss did not improve from 0.05397
# Epoch 17/300
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0288 - acc: 0.9922 - val_loss: 0.1816 - val_acc: 0.9370
#
# Epoch 00017: val_loss did not improve from 0.05397
# Epoch 18/300
# 8/8 [==============================] - 2s 235ms/step - loss: 0.0841 - acc: 0.9688 - val_loss: 0.1768 - val_acc: 0.9370
#
# Epoch 00018: val_loss did not improve from 0.05397
# Epoch 19/300
# 8/8 [==============================] - 2s 224ms/step - loss: 0.0381 - acc: 0.9844 - val_loss: 0.1734 - val_acc: 0.9370
#
# Epoch 00019: val_loss did not improve from 0.05397
# Epoch 20/300
# 8/8 [==============================] - 2s 223ms/step - loss: 0.0822 - acc: 0.9766 - val_loss: 0.1704 - val_acc: 0.9396
#
# Epoch 00020: val_loss did not improve from 0.05397
# Epoch 21/300
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0233 - acc: 1.0000 - val_loss: 0.1680 - val_acc: 0.9396
#
# Epoch 00021: val_loss did not improve from 0.05397
# Epoch 22/300
# 8/8 [==============================] - 2s 225ms/step - loss: 0.0605 - acc: 0.9766 - val_loss: 0.1661 - val_acc: 0.9396
#
# Epoch 00022: val_loss did not improve from 0.05397
# Epoch 23/300
# 8/8 [==============================] - 2s 233ms/step - loss: 0.0220 - acc: 0.9922 - val_loss: 0.1643 - val_acc: 0.9396
#
# Epoch 00023: val_loss did not improve from 0.05397
# Epoch 24/300
# 8/8 [==============================] - 2s 227ms/step - loss: 0.1020 - acc: 0.9609 - val_loss: 0.1615 - val_acc: 0.9423
#
# Epoch 00024: val_loss did not improve from 0.05397
# Epoch 25/300
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0243 - acc: 0.9922 - val_loss: 0.1585 - val_acc: 0.9423
#
# Epoch 00025: val_loss did not improve from 0.05397
# Epoch 26/300
# 8/8 [==============================] - 2s 224ms/step - loss: 0.0798 - acc: 0.9766 - val_loss: 0.1560 - val_acc: 0.9475
#
# Epoch 00026: val_loss did not improve from 0.05397
# Epoch 27/300
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0309 - acc: 0.9766 - val_loss: 0.1544 - val_acc: 0.9475
#
# Epoch 00027: val_loss did not improve from 0.05397
# Epoch 28/300
# 8/8 [==============================] - 2s 233ms/step - loss: 0.0097 - acc: 1.0000 - val_loss: 0.1528 - val_acc: 0.9475
#
# Epoch 00028: val_loss did not improve from 0.05397
# Epoch 29/300
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0624 - acc: 0.9766 - val_loss: 0.1503 - val_acc: 0.9475
#
# Epoch 00029: val_loss did not improve from 0.05397
# Epoch 30/300
# 8/8 [==============================] - 2s 224ms/step - loss: 0.0474 - acc: 0.9922 - val_loss: 0.1473 - val_acc: 0.9475
#
# Epoch 00030: val_loss did not improve from 0.05397
# Epoch 31/300
# 8/8 [==============================] - 2s 224ms/step - loss: 0.0311 - acc: 0.9922 - val_loss: 0.1448 - val_acc: 0.9475
#
# Epoch 00031: val_loss did not improve from 0.05397
# Epoch 32/300
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0587 - acc: 0.9688 - val_loss: 0.1434 - val_acc: 0.9475
#
# Epoch 00032: val_loss did not improve from 0.05397
# Epoch 33/300
# 8/8 [==============================] - 2s 220ms/step - loss: 0.0858 - acc: 0.9688 - val_loss: 0.1415 - val_acc: 0.9501
#
# Epoch 00033: val_loss did not improve from 0.05397
# Epoch 34/300
# 8/8 [==============================] - 2s 222ms/step - loss: 0.0576 - acc: 0.9766 - val_loss: 0.1406 - val_acc: 0.9501
#
# Epoch 00034: val_loss did not improve from 0.05397
# Epoch 35/300
# 8/8 [==============================] - 2s 222ms/step - loss: 0.0694 - acc: 0.9688 - val_loss: 0.1390 - val_acc: 0.9528
#
# Epoch 00035: val_loss did not improve from 0.05397
# Epoch 36/300
# 8/8 [==============================] - 2s 222ms/step - loss: 0.1146 - acc: 0.9766 - val_loss: 0.1381 - val_acc: 0.9554
#
# Epoch 00036: val_loss did not improve from 0.05397
# Epoch 37/300
# 8/8 [==============================] - 2s 218ms/step - loss: 0.0572 - acc: 0.9844 - val_loss: 0.1363 - val_acc: 0.9554
#
# Epoch 00037: val_loss did not improve from 0.05397
# Epoch 38/300
# 8/8 [==============================] - 2s 219ms/step - loss: 0.2379 - acc: 0.9688 - val_loss: 0.1344 - val_acc: 0.9554
#
# Epoch 00038: val_loss did not improve from 0.05397
# Epoch 39/300
# 8/8 [==============================] - 2s 221ms/step - loss: 0.0189 - acc: 0.9922 - val_loss: 0.1327 - val_acc: 0.9554
#
# Epoch 00039: val_loss did not improve from 0.05397
# Epoch 40/300
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0195 - acc: 0.9922 - val_loss: 0.1303 - val_acc: 0.9554
#
# Epoch 00040: val_loss did not improve from 0.05397
# Epoch 41/300
# 8/8 [==============================] - 2s 219ms/step - loss: 0.0420 - acc: 0.9766 - val_loss: 0.1285 - val_acc: 0.9554
#
# Epoch 00041: val_loss did not improve from 0.05397
# Epoch 42/300
# 8/8 [==============================] - 2s 221ms/step - loss: 0.0360 - acc: 0.9922 - val_loss: 0.1270 - val_acc: 0.9554
#
# Epoch 00042: val_loss did not improve from 0.05397
# Epoch 43/300
# 8/8 [==============================] - 2s 219ms/step - loss: 0.1220 - acc: 0.9609 - val_loss: 0.1260 - val_acc: 0.9554
#
# Epoch 00043: val_loss did not improve from 0.05397
# Epoch 44/300
# 8/8 [==============================] - 2s 219ms/step - loss: 0.0287 - acc: 0.9922 - val_loss: 0.1253 - val_acc: 0.9580
#
# Epoch 00044: val_loss did not improve from 0.05397
# Epoch 45/300
# 8/8 [==============================] - 2s 219ms/step - loss: 0.0328 - acc: 0.9922 - val_loss: 0.1235 - val_acc: 0.9554
#
# Epoch 00045: val_loss did not improve from 0.05397
# Epoch 46/300
# 8/8 [==============================] - 2s 218ms/step - loss: 0.0818 - acc: 0.9766 - val_loss: 0.1210 - val_acc: 0.9554
#
# Epoch 00046: val_loss did not improve from 0.05397
# Epoch 47/300
# 8/8 [==============================] - 2s 220ms/step - loss: 0.0403 - acc: 0.9922 - val_loss: 0.1195 - val_acc: 0.9554
#
# Epoch 00047: val_loss did not improve from 0.05397
# Epoch 48/300
# 8/8 [==============================] - 2s 219ms/step - loss: 0.0295 - acc: 0.9844 - val_loss: 0.1173 - val_acc: 0.9554
#
# Epoch 00048: val_loss did not improve from 0.05397
# Epoch 49/300
# 8/8 [==============================] - 2s 220ms/step - loss: 0.0220 - acc: 0.9922 - val_loss: 0.1157 - val_acc: 0.9554
#
# Epoch 00049: val_loss did not improve from 0.05397
# Epoch 50/300
# 8/8 [==============================] - 2s 219ms/step - loss: 0.0324 - acc: 0.9844 - val_loss: 0.1152 - val_acc: 0.9554
#
# Epoch 00050: val_loss did not improve from 0.05397
# Epoch 51/300
# 8/8 [==============================] - 2s 220ms/step - loss: 0.0417 - acc: 0.9922 - val_loss: 0.1145 - val_acc: 0.9606
#
# Epoch 00051: val_loss did not improve from 0.05397
# Epoch 52/300
# 8/8 [==============================] - 2s 219ms/step - loss: 0.1160 - acc: 0.9609 - val_loss: 0.1132 - val_acc: 0.9606
#
# Epoch 00052: val_loss did not improve from 0.05397
# Epoch 53/300
# 8/8 [==============================] - 38s 5s/step - loss: 0.0427 - acc: 0.9921 - val_loss: 0.1123 - val_acc: 0.9633
#
# Epoch 00053: val_loss did not improve from 0.05397
# Epoch 00053: early stopping

# %%
print(mobile_net.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Model) (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 1, 1, 1280)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               327936
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 257
# =================================================================
# Total params: 2,586,177
# Trainable params: 328,193
# Non-trainable params: 2,257,984
# _________________________________________________________________
# None

# %% [markdown]
# ### Loss and Accuracy

# %%
train_loss = mobile_net_history.history['loss']
train_acc = mobile_net_history.history['acc']
test_loss = mobile_net_history.history['val_loss']
test_acc = mobile_net_history.history['val_acc']
epochs = [i for i in range(1, len(test_acc)+1)]

fig, ax = plt.subplots(1,2, figsize = (15,5))
ax[0].plot(epochs, train_loss, label = 'Train Loss')
ax[0].plot(epochs, test_loss, label = 'Test Loss')
ax[0].set_title('Train/Test Loss')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].legend()

ax[1].plot(epochs, train_acc, label = 'Train Accuracy')
ax[1].plot(epochs, test_acc, label = 'Test Accuracy')
ax[1].set_title('Train/Test Accuracy')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend()

# %% [markdown]
# ### ROC and AUC

# %%
from sklearn.metrics import roc_curve, roc_auc_score, precision_recall_curve, f1_score, auc

if var.img_type == 'grey': 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 1)
else: 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 3)
    
mobilenet = get_mobile_net(dim)
mobilenet.load_weights('../models/Test_MobileNet-ModelCheckpointWeights.h5') #load the best weights before overfitting
 

fig, ax = plt.subplots(1,2, figsize = (15,6))
#AUC CURVE
y_test_prob = mobilenet.predict(x_test)

y_test_precision, y_test_recall, spec = precision_recall_curve(y_test, y_test_prob)
y_test_predict = np.where(y_test_prob >= .5, 1, 0).ravel()
y_test_f1= f1_score(y_test, y_test_predict)
y_test_auc = auc(y_test_recall, y_test_precision)
no_skill = len(y_test[y_test==1]) / len(y_test)
ax[0].plot(y_test_recall, y_test_precision, marker='.', label='CNN')
ax[0].plot([0, 1], [no_skill, no_skill], linestyle='--', label='50/50', color = 'Black')
ax[0].set_xlabel('Recall')
ax[0].set_ylabel('Precision')
ax[0].set_title(f'AUC Curve')
ax[0].legend()

#ROC CURVE
ns_probs = [0 for i in range(len(y_test))]
ns_auc = roc_auc_score(y_test, ns_probs)
y_test_roc = roc_auc_score(y_test, y_test_prob)

ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
y_test_fpr, y_test_tpr, threshold = roc_curve(y_test, y_test_prob)
ax[1].plot(ns_fpr, ns_tpr, linestyle='--', label='50/50')
ax[1].plot(y_test_fpr, y_test_tpr, marker='.', label='CNN')
ax[1].set_xlabel('False Positive Rate')
ax[1].set_ylabel('True Positive Rate')
ax[1].set_title(f'ROC Curve')
ax[1].legend()
plt.show()

pd.DataFrame({'F1 Score': round(y_test_f1, 3), 'AUC': round(y_test_auc, 3), 'ROC':round(y_test_roc, 3)}, index = [0])
# Out:
# C:\Users\Heeeb\Anaconda3\lib\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
#    F1 Score    AUC    ROC
# 0     0.986  0.999  0.999

# %%
df = pd.DataFrame({'Threshold': threshold, 'FPR': y_test_fpr, 'TPR': y_test_tpr})
plt.plot(df.Threshold, df.FPR, label = 'False Positive Rate')
plt.plot(df.Threshold, df.TPR, label = 'True Positive Rate')
plt.xlabel('Threshold')
plt.ylabel('FPR/TPR')
plt.title('Change in FPR/TPR with Threshold')
plt.xlim(0, 1)
plt.legend()
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import itertools
import seaborn as sns
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(y_test,y_train, y_train_prob, y_test_prob,thresholds, classes,
                          cmap=plt.cm.Blues):
    fig, ax = plt.subplots(len(thresholds),2, figsize = (10,10))

    for idx, thresh in enumerate(thresholds):
        y_test_predict = np.where(y_test_prob >= thresh, 1, 0)
        y_train_predict = np.where(y_train_prob >= thresh, 1, 0)
        train_cm = confusion_matrix(y_train, y_train_predict) 
        test_cm = confusion_matrix(y_test, y_test_predict)
        
        #test confusion
        ax[idx, 0].imshow(test_cm,  cmap=plt.cm.Blues) 

        ax[idx, 0].set_title(f'Test: Confusion Matrix | Threshold: {thresh}')
        ax[idx, 0].set_ylabel('True label')
        ax[idx, 0].set_xlabel('Predicted label')

        class_names = classes 
        tick_marks = np.arange(len(class_names))
        ax[idx, 0].set_xticks(tick_marks)
        ax[idx,0].set_xticklabels(class_names)
        ax[idx, 0].set_yticks(tick_marks)
        ax[idx, 0].set_yticklabels(class_names)

        th = test_cm.max() / 2. 

        for i, j in itertools.product(range(test_cm.shape[0]), range(test_cm.shape[1])):
                ax[idx, 0].text(j, i, f'{test_cm[i, j]}',# | {int(round(test_cm[i,j]/test_cm.ravel().sum(),5)*100)}%',
                         horizontalalignment='center',
                         color='white' if test_cm[i, j] > th else 'black')
        ax[idx, 0].set_ylim([-.5,1.5])
        
        #TRAIN CONFUSION
        ax[idx, 1].imshow(train_cm,  cmap=plt.cm.Blues) 

        ax[idx, 1].set_title(f'Train: Confusion Matrix | Threshold: {thresh}')
        ax[idx, 1].set_ylabel('True label')
        ax[idx, 1].set_xlabel('Predicted label')

        class_names = classes 
        tick_marks = np.arange(len(class_names))
        ax[idx, 1].set_xticks(tick_marks)
        ax[idx,1].set_xticklabels(class_names)
        ax[idx, 1].set_yticks(tick_marks)
        ax[idx, 1].set_yticklabels(class_names)


        th = train_cm.max() / 2. 

        for i, j in itertools.product(range(train_cm.shape[0]), range(train_cm.shape[1])):
                ax[idx, 1].text(j, i, f'{train_cm[i, j]}',# | {int(round(train_cm[i,j]/train_cm.ravel().sum(),5)*100)}%',
                         horizontalalignment='center',
                         color='white' if train_cm[i, j] > th else 'black')
        ax[idx, 1].set_ylim([-.5,1.5])
    plt.tight_layout()
 
    plt.show()
if var.img_type == 'grey': 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 1)
else: 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 3)
    
mobilenet = get_mobile_net(dim)
mobilenet.load_weights('../models/Test_MobileNet-ModelCheckpointWeights.h5') #load the best weights before overfitting
 

y_test_prob = mobilenet.predict(x_test).ravel()

y_train_prob = mobilenet.predict(x_train).ravel()

plot_confusion_matrix(y_train = y_train, y_test = y_test, y_train_prob = y_train_prob,
                      y_test_prob = y_test_prob,classes = ['No Weapon', 'Weapon'], thresholds = [.2, .5,.6])
# Out:
# C:\Users\Heeeb\Anaconda3\lib\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-a871fdc9ebee> in <module>
# ----> 1 assert False
#
# AssertionError:

# %% [markdown]
# ### Test on Google

# %%
import cv2
from lime import lime_image
from skimage.segmentation import mark_boundaries
import Functions as func

if var.img_type == 'grey': 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 1)
else: 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 3)
    
mobilenet = get_mobile_net(dim)
mobilenet.load_weights('../models/Test_MobileNet-ModelCheckpointWeights.h5') #load the best weights before overfitting
img = func.get_image_value('../test3.jpg', var.mobilenet_dimension, var.img_type)

explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(img, mobilenet.predict, top_labels = 5, hide_color = 0, 
                                         num_samples = 1000)

temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only = False,
                                           num_features = 10, hide_rest = False)
plt.imshow(mark_boundaries(temp/2 + .5, mask))
# Out:
# C:\Users\Heeeb\Anaconda3\lib\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
import cv2
from lime import lime_image
from skimage.segmentation import mark_boundaries
import Functions as func

if var.img_type == 'grey': 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 1)
else: 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 3)
    
mobilenet = get_mobile_net(dim)
mobilenet.load_weights('../models/Test_MobileNet-ModelCheckpointWeights.h5') #load the best weights before overfitting
img = func.get_image_value('../test3.jpg', var.mobilenet_dimension, var.img_type)

explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(img, mobilenet.predict, top_labels = 5, hide_color = 0, 
                                         num_samples = 1000)

temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only = False,
                                           num_features = 10, hide_rest = False)
plt.imshow(mark_boundaries(temp/2 + .5, mask))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
img = cv2.imread('../test3.jpg')
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
ss.setBaseImage(img)
ss.switchToSelectiveSearchFast()
rects = ss.process() 

windows = []
locations = []
for x, y, w,h in rects: 
    startx = x 
    starty = y 
    endx = x+w 
    endy = y+h 
    roi = img[starty:endy, startx:endx]
    roi = cv2.resize(roi, dsize =var.mobilenet_dimension, interpolation = cv2.INTER_CUBIC)
    windows.append(roi)
    locations.append((startx, starty, endx, endy))

    
windows = np.array(windows)

predictions = mobilenet.predict(windows)

# %%
clone = img.copy()
new_loc = [] 
new_prob = [] 
for idx, i in enumerate(predictions): 
    if i < .85: 
        continue
    startx, starty, endx, endy = locations[idx]
    cv2.rectangle(clone, (startx, starty), (endx, endy),  (0,255,0),2)
    text = f'Weapon: {i*100}'
    cv2.putText(clone, text, (startx, y), cv2.FONT_HERSHEY_SIMPLEX, .45, (0,255,0),2)
    new_loc.append(locations[idx])
    new_prob.append(i[0])
    
cv2.imshow('test', clone)
cv2.waitKey(0)
# Out:
# -1

# %%
predictions.max()
# Out:
# 0.98438895

# %%
test = np.array(new_prob).ravel()
print(np.argmax(test), test.max())
test
# Out:
# 882 0.98438895
# array([0.56188476, 0.8606172 , 0.9157505 , ..., 0.2011738 , 0.29416558,
#        0.43156454], dtype=float32)

# %%
print(len(new_loc), len(test))
# Out:
# 1209 1209

# %%
boxids = func.non_max_suppression(np.array(new_loc), np.array(new_prob))[0]
print(boxids)
clone = img.copy()
  
startx, starty, endx, endy = new_loc[180]
cv2.rectangle(clone, (startx, starty), (endx, endy),  (0,255,0),2)
text = f'Weapon: {i*100}'
cv2.putText(clone, text, (startx, y), cv2.FONT_HERSHEY_SIMPLEX, .45, (0,255,0),2)
cv2.imshow('test', clone)
cv2.waitKey(0)
# Out:
# 882
# -1

# %%
import pickle
errors = pickle.load( open('../Pickles/error_array.p', 'rb'))

# %%
len(errors)
# Out:
# 171
