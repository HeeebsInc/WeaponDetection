# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import MobileNetV2
from keras.layers import AveragePooling2D, Dropout, Flatten, Dense, Input
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.applications.mobilenet_v2 import preprocess_input
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os
import pandas as pd
import Functions
import var
import Viz
# Out:
# Using plaidml.keras.backend backend.

# %%
def get_mobile_net(dim):
    model = Sequential()
    optimizer = Adam(lr = .0005)
    baseModel = MobileNetV2(weights="imagenet", include_top=False,
        input_tensor=Input(shape=dim))
    
    model.add(baseModel)
    headModel = model.add(AveragePooling2D(pool_size=(7, 7)))
    headModel = model.add(Flatten(name="flatten"))
    headModel = model.add(Dense(256, activation="relu"))
    headModel = model.add(Dropout(0.3))
    headModel = model.add(Dense(3, activation="softmax", name = 'Output'))

    # place the head FC model on top of the base model (this will become
    # the actual model we will train)


    # loop over all layers in the base model and freeze them so they will
    # *not* be updated during the first training process
    for layer in baseModel.layers:
        layer.trainable = False
    
    model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])
    return model

# %%
x_train, x_test, y_train, y_test = Functions.get_samples('mobilenet')
print(x_train.shape, x_test.shape) 
print(y_train.shape, y_test.shape)
# Out:
# (6512, 224, 224, 3) (724, 224, 224, 3)
# (6512, 3) (724, 3)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator


augment = True 

early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=50)
model_checkpoint = ModelCheckpoint('../models/MobileNet-ModelCheckpointWeights.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 5, mode = 'min')
epochs = 2000
batch_size = 16
if var.img_type == 'grey': 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 1)
else: 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 3)
    
mobile_net = get_mobile_net(dim =dim)

if augment: 
    augmentation =ImageDataGenerator(rotation_range = 15, width_shift_range = .1, height_shift_range = .1, 
                                                           horizontal_flip = True, fill_mode = 'nearest')
    augmentation.fit(x_train)
    mobile_net_history = mobile_net.fit_generator(augmentation.flow(x_train, y_train, batch_size = batch_size),
                epochs = epochs, steps_per_epoch = 8,
         callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
else: 
    
    mobile_net_history = mobile_net.fit(x_train, y_train, batch_size = batch_size,
                epochs = epochs, 
         callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
# Out:
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"
# C:\Users\Heeeb\Anaconda3\lib\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Epoch 1/2000
# 8/8 [==============================] - 38s 5s/step - loss: 1.1443 - acc: 0.5469 - val_loss: 2.1694 - val_acc: 0.4392
#
# Epoch 00001: val_loss improved from inf to 2.16939, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 2/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5673 - acc: 0.7891 - val_loss: 1.6279 - val_acc: 0.5539
#
# Epoch 00002: val_loss improved from 2.16939 to 1.62793, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 3/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.8415 - acc: 0.6250 - val_loss: 2.9565 - val_acc: 0.4406
#
# Epoch 00003: val_loss did not improve from 1.62793
# Epoch 4/2000
# 8/8 [==============================] - 2s 306ms/step - loss: 0.6234 - acc: 0.7422 - val_loss: 1.9876 - val_acc: 0.5318
#
# Epoch 00004: val_loss did not improve from 1.62793
# Epoch 5/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.6921 - acc: 0.7188 - val_loss: 1.8207 - val_acc: 0.5235
#
# Epoch 00005: val_loss did not improve from 1.62793
# Epoch 6/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5457 - acc: 0.8125 - val_loss: 1.9626 - val_acc: 0.5387
#
# Epoch 00006: val_loss did not improve from 1.62793
# Epoch 7/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5654 - acc: 0.7422 - val_loss: 2.3003 - val_acc: 0.5000
#
# Epoch 00007: val_loss did not improve from 1.62793
# Epoch 8/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.6728 - acc: 0.6953 - val_loss: 2.0143 - val_acc: 0.5345
#
# Epoch 00008: val_loss did not improve from 1.62793
# Epoch 9/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4665 - acc: 0.7891 - val_loss: 1.9168 - val_acc: 0.5456
#
# Epoch 00009: val_loss did not improve from 1.62793
# Epoch 10/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.7785 - acc: 0.7188 - val_loss: 1.7943 - val_acc: 0.5552
#
# Epoch 00010: val_loss did not improve from 1.62793
# Epoch 11/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.5605 - acc: 0.7422 - val_loss: 1.7449 - val_acc: 0.5594
#
# Epoch 00011: val_loss did not improve from 1.62793
# Epoch 12/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5426 - acc: 0.7734 - val_loss: 1.7599 - val_acc: 0.5580
#
# Epoch 00012: val_loss did not improve from 1.62793
# Epoch 13/2000
# 8/8 [==============================] - 2s 306ms/step - loss: 0.6294 - acc: 0.7266 - val_loss: 1.7431 - val_acc: 0.5580
#
# Epoch 00013: val_loss did not improve from 1.62793
# Epoch 14/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4481 - acc: 0.8359 - val_loss: 1.7278 - val_acc: 0.5594
#
# Epoch 00014: val_loss did not improve from 1.62793
# Epoch 15/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4985 - acc: 0.7656 - val_loss: 1.7130 - val_acc: 0.5622
#
# Epoch 00015: val_loss did not improve from 1.62793
# Epoch 16/2000
# 8/8 [==============================] - 3s 315ms/step - loss: 0.6257 - acc: 0.7422 - val_loss: 1.6939 - val_acc: 0.5635
#
# Epoch 00016: val_loss did not improve from 1.62793
# Epoch 17/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5002 - acc: 0.7891 - val_loss: 1.6746 - val_acc: 0.5663
#
# Epoch 00017: val_loss did not improve from 1.62793
# Epoch 18/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.5872 - acc: 0.7578 - val_loss: 1.6551 - val_acc: 0.5691
#
# Epoch 00018: val_loss did not improve from 1.62793
# Epoch 19/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6852 - acc: 0.7578 - val_loss: 1.6383 - val_acc: 0.5691
#
# Epoch 00019: val_loss did not improve from 1.62793
# Epoch 20/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4482 - acc: 0.7969 - val_loss: 1.6222 - val_acc: 0.5718
#
# Epoch 00020: val_loss improved from 1.62793 to 1.62222, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 21/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.5725 - acc: 0.7500 - val_loss: 1.6057 - val_acc: 0.5760
#
# Epoch 00021: val_loss improved from 1.62222 to 1.60573, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 22/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4510 - acc: 0.8047 - val_loss: 1.5881 - val_acc: 0.5787
#
# Epoch 00022: val_loss improved from 1.60573 to 1.58809, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 23/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.5752 - acc: 0.7500 - val_loss: 1.5708 - val_acc: 0.5815
#
# Epoch 00023: val_loss improved from 1.58809 to 1.57079, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 24/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.5404 - acc: 0.8203 - val_loss: 1.5557 - val_acc: 0.5856
#
# Epoch 00024: val_loss improved from 1.57079 to 1.55568, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 25/2000
# 8/8 [==============================] - 3s 320ms/step - loss: 0.4516 - acc: 0.7812 - val_loss: 1.5394 - val_acc: 0.5856
#
# Epoch 00025: val_loss improved from 1.55568 to 1.53944, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 26/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.5595 - acc: 0.7891 - val_loss: 1.5243 - val_acc: 0.5870
#
# Epoch 00026: val_loss improved from 1.53944 to 1.52428, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 27/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5336 - acc: 0.7734 - val_loss: 1.5057 - val_acc: 0.5939
#
# Epoch 00027: val_loss improved from 1.52428 to 1.50566, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 28/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5706 - acc: 0.7656 - val_loss: 1.4906 - val_acc: 0.5939
#
# Epoch 00028: val_loss improved from 1.50566 to 1.49059, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 29/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6262 - acc: 0.7344 - val_loss: 1.4768 - val_acc: 0.5953
#
# Epoch 00029: val_loss improved from 1.49059 to 1.47678, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 30/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.6355 - acc: 0.6953 - val_loss: 1.4644 - val_acc: 0.5994
#
# Epoch 00030: val_loss improved from 1.47678 to 1.46438, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 31/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6174 - acc: 0.7734 - val_loss: 1.4525 - val_acc: 0.5994
#
# Epoch 00031: val_loss improved from 1.46438 to 1.45253, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 32/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5859 - acc: 0.8047 - val_loss: 1.4385 - val_acc: 0.6008
#
# Epoch 00032: val_loss improved from 1.45253 to 1.43847, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 33/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.5435 - acc: 0.7891 - val_loss: 1.4268 - val_acc: 0.6008
#
# Epoch 00033: val_loss improved from 1.43847 to 1.42681, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 34/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4885 - acc: 0.7812 - val_loss: 1.4134 - val_acc: 0.6008
#
# Epoch 00034: val_loss improved from 1.42681 to 1.41338, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 35/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5494 - acc: 0.7500 - val_loss: 1.4005 - val_acc: 0.6022
#
# Epoch 00035: val_loss improved from 1.41338 to 1.40048, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 36/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5278 - acc: 0.7969 - val_loss: 1.3875 - val_acc: 0.6022
#
# Epoch 00036: val_loss improved from 1.40048 to 1.38752, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 37/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.5032 - acc: 0.7812 - val_loss: 1.3743 - val_acc: 0.6036
#
# Epoch 00037: val_loss improved from 1.38752 to 1.37434, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 38/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5177 - acc: 0.7891 - val_loss: 1.3623 - val_acc: 0.6050
#
# Epoch 00038: val_loss improved from 1.37434 to 1.36231, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 39/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6016 - acc: 0.7578 - val_loss: 1.3491 - val_acc: 0.6091
#
# Epoch 00039: val_loss improved from 1.36231 to 1.34906, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 40/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.6059 - acc: 0.7344 - val_loss: 1.3366 - val_acc: 0.6105
#
# Epoch 00040: val_loss improved from 1.34906 to 1.33660, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 41/2000
# 8/8 [==============================] - 3s 316ms/step - loss: 0.4650 - acc: 0.8438 - val_loss: 1.3252 - val_acc: 0.6133
#
# Epoch 00041: val_loss improved from 1.33660 to 1.32521, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 42/2000
# 8/8 [==============================] - 3s 315ms/step - loss: 0.5369 - acc: 0.7812 - val_loss: 1.3121 - val_acc: 0.6119
#
# Epoch 00042: val_loss improved from 1.32521 to 1.31208, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 43/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5396 - acc: 0.7656 - val_loss: 1.3015 - val_acc: 0.6119
#
# Epoch 00043: val_loss improved from 1.31208 to 1.30148, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 44/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.5586 - acc: 0.7891 - val_loss: 1.2906 - val_acc: 0.6119
#
# Epoch 00044: val_loss improved from 1.30148 to 1.29056, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 45/2000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.4271 - acc: 0.8281 - val_loss: 1.2825 - val_acc: 0.6133
#
# Epoch 00045: val_loss improved from 1.29056 to 1.28254, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 46/2000
# 8/8 [==============================] - 3s 315ms/step - loss: 0.5163 - acc: 0.7578 - val_loss: 1.2728 - val_acc: 0.6160
#
# Epoch 00046: val_loss improved from 1.28254 to 1.27277, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 47/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.4868 - acc: 0.8047 - val_loss: 1.2627 - val_acc: 0.6202
#
# Epoch 00047: val_loss improved from 1.27277 to 1.26272, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 48/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.5399 - acc: 0.7656 - val_loss: 1.2517 - val_acc: 0.6202
#
# Epoch 00048: val_loss improved from 1.26272 to 1.25171, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 49/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4966 - acc: 0.8047 - val_loss: 1.2411 - val_acc: 0.6229
#
# Epoch 00049: val_loss improved from 1.25171 to 1.24114, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 50/2000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.5247 - acc: 0.7812 - val_loss: 1.2304 - val_acc: 0.6243
#
# Epoch 00050: val_loss improved from 1.24114 to 1.23042, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 51/2000
# 8/8 [==============================] - 3s 321ms/step - loss: 0.5377 - acc: 0.7812 - val_loss: 1.2201 - val_acc: 0.6243
#
# Epoch 00051: val_loss improved from 1.23042 to 1.22014, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 52/2000
# 8/8 [==============================] - 3s 315ms/step - loss: 0.4746 - acc: 0.8125 - val_loss: 1.2113 - val_acc: 0.6257
#
# Epoch 00052: val_loss improved from 1.22014 to 1.21127, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 53/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.7794 - acc: 0.6797 - val_loss: 1.2024 - val_acc: 0.6271
#
# Epoch 00053: val_loss improved from 1.21127 to 1.20241, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 54/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4516 - acc: 0.7969 - val_loss: 1.1924 - val_acc: 0.6312
#
# Epoch 00054: val_loss improved from 1.20241 to 1.19243, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 55/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4611 - acc: 0.8047 - val_loss: 1.1842 - val_acc: 0.6381
#
# Epoch 00055: val_loss improved from 1.19243 to 1.18420, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 56/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.4863 - acc: 0.7891 - val_loss: 1.1757 - val_acc: 0.6395
#
# Epoch 00056: val_loss improved from 1.18420 to 1.17565, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 57/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.5632 - acc: 0.7656 - val_loss: 1.1680 - val_acc: 0.6395
#
# Epoch 00057: val_loss improved from 1.17565 to 1.16798, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 58/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.5062 - acc: 0.7812 - val_loss: 1.1600 - val_acc: 0.6381
#
# Epoch 00058: val_loss improved from 1.16798 to 1.16002, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 59/2000
# 8/8 [==============================] - 3s 315ms/step - loss: 0.5124 - acc: 0.7578 - val_loss: 1.1512 - val_acc: 0.6381
#
# Epoch 00059: val_loss improved from 1.16002 to 1.15122, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 60/2000
# 8/8 [==============================] - 3s 321ms/step - loss: 0.5313 - acc: 0.7812 - val_loss: 1.1432 - val_acc: 0.6395
#
# Epoch 00060: val_loss improved from 1.15122 to 1.14319, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 61/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.6515 - acc: 0.7344 - val_loss: 1.1357 - val_acc: 0.6409
#
# Epoch 00061: val_loss improved from 1.14319 to 1.13573, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 62/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5247 - acc: 0.7734 - val_loss: 1.1285 - val_acc: 0.6436
#
# Epoch 00062: val_loss improved from 1.13573 to 1.12849, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 63/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.5744 - acc: 0.7109 - val_loss: 1.1210 - val_acc: 0.6492
#
# Epoch 00063: val_loss improved from 1.12849 to 1.12098, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 64/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.5663 - acc: 0.7812 - val_loss: 1.1145 - val_acc: 0.6478
#
# Epoch 00064: val_loss improved from 1.12098 to 1.11451, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 65/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.4451 - acc: 0.8047 - val_loss: 1.1063 - val_acc: 0.6478
#
# Epoch 00065: val_loss improved from 1.11451 to 1.10633, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 66/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.4584 - acc: 0.8203 - val_loss: 1.0970 - val_acc: 0.6519
#
# Epoch 00066: val_loss improved from 1.10633 to 1.09699, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 67/2000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.5974 - acc: 0.7656 - val_loss: 1.0907 - val_acc: 0.6561
#
# Epoch 00067: val_loss improved from 1.09699 to 1.09067, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 68/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6226 - acc: 0.7422 - val_loss: 1.0834 - val_acc: 0.6575
#
# Epoch 00068: val_loss improved from 1.09067 to 1.08337, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 69/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.6467 - acc: 0.7422 - val_loss: 1.0764 - val_acc: 0.6588
#
# Epoch 00069: val_loss improved from 1.08337 to 1.07644, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 70/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6691 - acc: 0.7344 - val_loss: 1.0700 - val_acc: 0.6602
#
# Epoch 00070: val_loss improved from 1.07644 to 1.06999, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 71/2000
# 8/8 [==============================] - 3s 319ms/step - loss: 0.5078 - acc: 0.8281 - val_loss: 1.0626 - val_acc: 0.6602
#
# Epoch 00071: val_loss improved from 1.06999 to 1.06256, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 72/2000
# 8/8 [==============================] - 3s 321ms/step - loss: 0.4297 - acc: 0.7969 - val_loss: 1.0555 - val_acc: 0.6630
#
# Epoch 00072: val_loss improved from 1.06256 to 1.05554, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 73/2000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.5043 - acc: 0.7969 - val_loss: 1.0498 - val_acc: 0.6644
#
# Epoch 00073: val_loss improved from 1.05554 to 1.04979, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 74/2000
# 8/8 [==============================] - 3s 325ms/step - loss: 0.5404 - acc: 0.7734 - val_loss: 1.0437 - val_acc: 0.6657
#
# Epoch 00074: val_loss improved from 1.04979 to 1.04366, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 75/2000
# 8/8 [==============================] - 3s 333ms/step - loss: 0.5434 - acc: 0.7578 - val_loss: 1.0378 - val_acc: 0.6671
#
# Epoch 00075: val_loss improved from 1.04366 to 1.03778, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 76/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.5400 - acc: 0.7891 - val_loss: 1.0313 - val_acc: 0.6671
#
# Epoch 00076: val_loss improved from 1.03778 to 1.03132, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 77/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.4634 - acc: 0.7422 - val_loss: 1.0251 - val_acc: 0.6671
#
# Epoch 00077: val_loss improved from 1.03132 to 1.02512, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 78/2000
# 8/8 [==============================] - 3s 318ms/step - loss: 0.5342 - acc: 0.8047 - val_loss: 1.0194 - val_acc: 0.6685
#
# Epoch 00078: val_loss improved from 1.02512 to 1.01937, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 79/2000
# 8/8 [==============================] - 3s 322ms/step - loss: 0.7007 - acc: 0.7891 - val_loss: 1.0131 - val_acc: 0.6685
#
# Epoch 00079: val_loss improved from 1.01937 to 1.01306, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 80/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.5378 - acc: 0.8125 - val_loss: 1.0084 - val_acc: 0.6685
#
# Epoch 00080: val_loss improved from 1.01306 to 1.00837, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 81/2000
# 8/8 [==============================] - 3s 319ms/step - loss: 0.4428 - acc: 0.8438 - val_loss: 1.0019 - val_acc: 0.6685
#
# Epoch 00081: val_loss improved from 1.00837 to 1.00193, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 82/2000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.4827 - acc: 0.7969 - val_loss: 0.9963 - val_acc: 0.6713
#
# Epoch 00082: val_loss improved from 1.00193 to 0.99628, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 83/2000
# 8/8 [==============================] - 3s 316ms/step - loss: 0.5300 - acc: 0.7578 - val_loss: 0.9913 - val_acc: 0.6727
#
# Epoch 00083: val_loss improved from 0.99628 to 0.99132, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 84/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.4393 - acc: 0.8203 - val_loss: 0.9846 - val_acc: 0.6727
#
# Epoch 00084: val_loss improved from 0.99132 to 0.98461, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 85/2000
# 8/8 [==============================] - 3s 318ms/step - loss: 0.8215 - acc: 0.6797 - val_loss: 0.9799 - val_acc: 0.6727
#
# Epoch 00085: val_loss improved from 0.98461 to 0.97991, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 86/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.6818 - acc: 0.6953 - val_loss: 0.9745 - val_acc: 0.6685
#
# Epoch 00086: val_loss improved from 0.97991 to 0.97449, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 87/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4536 - acc: 0.8047 - val_loss: 0.9692 - val_acc: 0.6699
#
# Epoch 00087: val_loss improved from 0.97449 to 0.96919, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 88/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4054 - acc: 0.8125 - val_loss: 0.9641 - val_acc: 0.6713
#
# Epoch 00088: val_loss improved from 0.96919 to 0.96406, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 89/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.5178 - acc: 0.7656 - val_loss: 0.9589 - val_acc: 0.6740
#
# Epoch 00089: val_loss improved from 0.96406 to 0.95895, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 90/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6570 - acc: 0.7422 - val_loss: 0.9535 - val_acc: 0.6740
#
# Epoch 00090: val_loss improved from 0.95895 to 0.95346, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 91/2000
# 8/8 [==============================] - 3s 316ms/step - loss: 0.4930 - acc: 0.8125 - val_loss: 0.9481 - val_acc: 0.6740
#
# Epoch 00091: val_loss improved from 0.95346 to 0.94811, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 92/2000
# 8/8 [==============================] - 3s 319ms/step - loss: 0.5107 - acc: 0.7812 - val_loss: 0.9418 - val_acc: 0.6740
#
# Epoch 00092: val_loss improved from 0.94811 to 0.94175, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 93/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5750 - acc: 0.7500 - val_loss: 0.9362 - val_acc: 0.6740
#
# Epoch 00093: val_loss improved from 0.94175 to 0.93617, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 94/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.3901 - acc: 0.8438 - val_loss: 0.9307 - val_acc: 0.6727
#
# Epoch 00094: val_loss improved from 0.93617 to 0.93066, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 95/2000
# 8/8 [==============================] - 3s 316ms/step - loss: 0.4858 - acc: 0.8281 - val_loss: 0.9261 - val_acc: 0.6727
#
# Epoch 00095: val_loss improved from 0.93066 to 0.92615, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 96/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.5888 - acc: 0.7500 - val_loss: 0.9211 - val_acc: 0.6727
#
# Epoch 00096: val_loss improved from 0.92615 to 0.92110, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 97/2000
# 8/8 [==============================] - 3s 318ms/step - loss: 0.3592 - acc: 0.8672 - val_loss: 0.9173 - val_acc: 0.6713
#
# Epoch 00097: val_loss improved from 0.92110 to 0.91732, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 98/2000
# 8/8 [==============================] - 3s 320ms/step - loss: 0.4781 - acc: 0.7734 - val_loss: 0.9118 - val_acc: 0.6727
#
# Epoch 00098: val_loss improved from 0.91732 to 0.91177, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 99/2000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.5106 - acc: 0.7969 - val_loss: 0.9068 - val_acc: 0.6713
#
# Epoch 00099: val_loss improved from 0.91177 to 0.90684, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 100/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5606 - acc: 0.7812 - val_loss: 0.9020 - val_acc: 0.6740
#
# Epoch 00100: val_loss improved from 0.90684 to 0.90202, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 101/2000
# 8/8 [==============================] - 2s 306ms/step - loss: 0.5650 - acc: 0.7109 - val_loss: 0.8979 - val_acc: 0.6768
#
# Epoch 00101: val_loss improved from 0.90202 to 0.89792, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 102/2000
# 8/8 [==============================] - 3s 333ms/step - loss: 0.4842 - acc: 0.7656 - val_loss: 0.8944 - val_acc: 0.6768
#
# Epoch 00102: val_loss improved from 0.89792 to 0.89440, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 103/2000
# 8/8 [==============================] - 3s 316ms/step - loss: 0.6300 - acc: 0.6875 - val_loss: 0.8902 - val_acc: 0.6768
# Epoch 00103: val_loss improved from 0.89440 to 0.89020, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 104/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4058 - acc: 0.8672 - val_loss: 0.8857 - val_acc: 0.6768
#
# Epoch 00104: val_loss improved from 0.89020 to 0.88568, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 105/2000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.6520 - acc: 0.7266 - val_loss: 0.8822 - val_acc: 0.6782
#
# Epoch 00105: val_loss improved from 0.88568 to 0.88218, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 106/2000
# 8/8 [==============================] - 3s 315ms/step - loss: 0.5610 - acc: 0.7969 - val_loss: 0.8787 - val_acc: 0.6782
#
# Epoch 00106: val_loss improved from 0.88218 to 0.87871, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 107/2000
# 8/8 [==============================] - 3s 325ms/step - loss: 0.5351 - acc: 0.7734 - val_loss: 0.8739 - val_acc: 0.6782
#
# Epoch 00107: val_loss improved from 0.87871 to 0.87392, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 108/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.4560 - acc: 0.8125 - val_loss: 0.8699 - val_acc: 0.6796
#
# Epoch 00108: val_loss improved from 0.87392 to 0.86995, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 109/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.4435 - acc: 0.8125 - val_loss: 0.8655 - val_acc: 0.6823
#
# Epoch 00109: val_loss improved from 0.86995 to 0.86547, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 110/2000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.5131 - acc: 0.7969 - val_loss: 0.8619 - val_acc: 0.6837
#
# Epoch 00110: val_loss improved from 0.86547 to 0.86193, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 111/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.4593 - acc: 0.8125 - val_loss: 0.8576 - val_acc: 0.6837
#
# Epoch 00111: val_loss improved from 0.86193 to 0.85755, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 112/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6201 - acc: 0.7188 - val_loss: 0.8535 - val_acc: 0.6837
#
# Epoch 00112: val_loss improved from 0.85755 to 0.85349, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 113/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.6006 - acc: 0.7656 - val_loss: 0.8498 - val_acc: 0.6865
#
# Epoch 00113: val_loss improved from 0.85349 to 0.84977, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 114/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6012 - acc: 0.7188 - val_loss: 0.8458 - val_acc: 0.6878
#
# Epoch 00114: val_loss improved from 0.84977 to 0.84576, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 115/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.5493 - acc: 0.7734 - val_loss: 0.8419 - val_acc: 0.6906
#
# Epoch 00115: val_loss improved from 0.84576 to 0.84186, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 116/2000
# 8/8 [==============================] - 3s 320ms/step - loss: 0.4904 - acc: 0.8125 - val_loss: 0.8386 - val_acc: 0.6892
#
# Epoch 00116: val_loss improved from 0.84186 to 0.83855, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 117/2000
# 8/8 [==============================] - 3s 320ms/step - loss: 0.6408 - acc: 0.7188 - val_loss: 0.8354 - val_acc: 0.6892
#
# Epoch 00117: val_loss improved from 0.83855 to 0.83545, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 118/2000
# 8/8 [==============================] - 3s 325ms/step - loss: 0.4775 - acc: 0.7656 - val_loss: 0.8311 - val_acc: 0.6892
#
# Epoch 00118: val_loss improved from 0.83545 to 0.83113, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 119/2000
# 8/8 [==============================] - 3s 320ms/step - loss: 0.4831 - acc: 0.8047 - val_loss: 0.8272 - val_acc: 0.6906
#
# Epoch 00119: val_loss improved from 0.83113 to 0.82722, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 120/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.5835 - acc: 0.7422 - val_loss: 0.8244 - val_acc: 0.6934
#
# Epoch 00120: val_loss improved from 0.82722 to 0.82442, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 121/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6583 - acc: 0.7422 - val_loss: 0.8211 - val_acc: 0.6975
#
# Epoch 00121: val_loss improved from 0.82442 to 0.82112, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 122/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.5956 - acc: 0.7891 - val_loss: 0.8170 - val_acc: 0.7003
#
# Epoch 00122: val_loss improved from 0.82112 to 0.81700, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 123/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4908 - acc: 0.7891 - val_loss: 0.8133 - val_acc: 0.7030
#
# Epoch 00123: val_loss improved from 0.81700 to 0.81325, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 124/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.6613 - acc: 0.7344 - val_loss: 0.8094 - val_acc: 0.7044
#
# Epoch 00124: val_loss improved from 0.81325 to 0.80942, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 125/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.4308 - acc: 0.8203 - val_loss: 0.8057 - val_acc: 0.7044
#
# Epoch 00125: val_loss improved from 0.80942 to 0.80569, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 126/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5523 - acc: 0.7969 - val_loss: 0.8030 - val_acc: 0.7044
#
# Epoch 00126: val_loss improved from 0.80569 to 0.80301, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 127/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4451 - acc: 0.8047 - val_loss: 0.7996 - val_acc: 0.7044
#
# Epoch 00127: val_loss improved from 0.80301 to 0.79958, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 128/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6735 - acc: 0.7422 - val_loss: 0.7955 - val_acc: 0.7072
#
# Epoch 00128: val_loss improved from 0.79958 to 0.79553, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 129/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.5086 - acc: 0.8125 - val_loss: 0.7924 - val_acc: 0.7072
#
# Epoch 00129: val_loss improved from 0.79553 to 0.79237, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 130/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.4739 - acc: 0.8125 - val_loss: 0.7889 - val_acc: 0.7086
#
# Epoch 00130: val_loss improved from 0.79237 to 0.78892, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 131/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4228 - acc: 0.7969 - val_loss: 0.7849 - val_acc: 0.7099
#
# Epoch 00131: val_loss improved from 0.78892 to 0.78492, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 132/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4435 - acc: 0.8125 - val_loss: 0.7819 - val_acc: 0.7099
#
# Epoch 00132: val_loss improved from 0.78492 to 0.78193, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 133/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5130 - acc: 0.7891 - val_loss: 0.7786 - val_acc: 0.7113
#
# Epoch 00133: val_loss improved from 0.78193 to 0.77858, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 134/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.6004 - acc: 0.7500 - val_loss: 0.7746 - val_acc: 0.7127
#
# Epoch 00134: val_loss improved from 0.77858 to 0.77459, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 135/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5626 - acc: 0.7500 - val_loss: 0.7711 - val_acc: 0.7127
#
# Epoch 00135: val_loss improved from 0.77459 to 0.77113, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 136/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5743 - acc: 0.7578 - val_loss: 0.7676 - val_acc: 0.7169
#
# Epoch 00136: val_loss improved from 0.77113 to 0.76763, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 137/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4595 - acc: 0.8203 - val_loss: 0.7642 - val_acc: 0.7182
#
# Epoch 00137: val_loss improved from 0.76763 to 0.76417, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 138/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4890 - acc: 0.8281 - val_loss: 0.7614 - val_acc: 0.7182
#
# Epoch 00138: val_loss improved from 0.76417 to 0.76142, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 139/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4130 - acc: 0.8438 - val_loss: 0.7588 - val_acc: 0.7196
#
# Epoch 00139: val_loss improved from 0.76142 to 0.75881, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 140/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4167 - acc: 0.8594 - val_loss: 0.7560 - val_acc: 0.7210
#
# Epoch 00140: val_loss improved from 0.75881 to 0.75596, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 141/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4800 - acc: 0.8125 - val_loss: 0.7534 - val_acc: 0.7210
#
# Epoch 00141: val_loss improved from 0.75596 to 0.75344, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 142/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4819 - acc: 0.7969 - val_loss: 0.7501 - val_acc: 0.7224
#
# Epoch 00142: val_loss improved from 0.75344 to 0.75014, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 143/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4973 - acc: 0.8125 - val_loss: 0.7478 - val_acc: 0.7210
#
# Epoch 00143: val_loss improved from 0.75014 to 0.74783, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 144/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.3908 - acc: 0.8438 - val_loss: 0.7446 - val_acc: 0.7210
#
# Epoch 00144: val_loss improved from 0.74783 to 0.74460, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 145/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5827 - acc: 0.7656 - val_loss: 0.7408 - val_acc: 0.7224
#
# Epoch 00145: val_loss improved from 0.74460 to 0.74083, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 146/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.6515 - acc: 0.7266 - val_loss: 0.7386 - val_acc: 0.7224
#
# Epoch 00146: val_loss improved from 0.74083 to 0.73864, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 147/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5417 - acc: 0.8047 - val_loss: 0.7361 - val_acc: 0.7251
#
# Epoch 00147: val_loss improved from 0.73864 to 0.73607, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 148/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.7338 - acc: 0.7031 - val_loss: 0.7345 - val_acc: 0.7251
#
# Epoch 00148: val_loss improved from 0.73607 to 0.73447, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 149/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4658 - acc: 0.8203 - val_loss: 0.7318 - val_acc: 0.7251
#
# Epoch 00149: val_loss improved from 0.73447 to 0.73180, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 150/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4743 - acc: 0.8047 - val_loss: 0.7296 - val_acc: 0.7265
#
# Epoch 00150: val_loss improved from 0.73180 to 0.72958, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 151/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6575 - acc: 0.7188 - val_loss: 0.7275 - val_acc: 0.7251
#
# Epoch 00151: val_loss improved from 0.72958 to 0.72754, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 152/2000
# 8/8 [==============================] - 2s 305ms/step - loss: 0.5205 - acc: 0.7812 - val_loss: 0.7254 - val_acc: 0.7251
#
# Epoch 00152: val_loss improved from 0.72754 to 0.72541, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 153/2000
# 8/8 [==============================] - 3s 341ms/step - loss: 0.4686 - acc: 0.8125 - val_loss: 0.7229 - val_acc: 0.7251
#
# Epoch 00153: val_loss improved from 0.72541 to 0.72291, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 154/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5530 - acc: 0.7656 - val_loss: 0.7204 - val_acc: 0.7251
#
# Epoch 00154: val_loss improved from 0.72291 to 0.72039, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 155/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4318 - acc: 0.8047 - val_loss: 0.7178 - val_acc: 0.7265
#
# Epoch 00155: val_loss improved from 0.72039 to 0.71785, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 156/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4507 - acc: 0.8281 - val_loss: 0.7151 - val_acc: 0.7279
#
# Epoch 00156: val_loss improved from 0.71785 to 0.71514, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 157/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4688 - acc: 0.8203 - val_loss: 0.7130 - val_acc: 0.7293
#
# Epoch 00157: val_loss improved from 0.71514 to 0.71303, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 158/2000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.5105 - acc: 0.7500 - val_loss: 0.7102 - val_acc: 0.7334
#
# Epoch 00158: val_loss improved from 0.71303 to 0.71020, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 159/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5024 - acc: 0.7891 - val_loss: 0.7078 - val_acc: 0.7348
#
# Epoch 00159: val_loss improved from 0.71020 to 0.70778, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 160/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5473 - acc: 0.7578 - val_loss: 0.7057 - val_acc: 0.7362
#
# Epoch 00160: val_loss improved from 0.70778 to 0.70565, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 161/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6523 - acc: 0.6953 - val_loss: 0.7036 - val_acc: 0.7376
#
# Epoch 00161: val_loss improved from 0.70565 to 0.70363, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 162/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5026 - acc: 0.7734 - val_loss: 0.7010 - val_acc: 0.7390
#
# Epoch 00162: val_loss improved from 0.70363 to 0.70104, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 163/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5707 - acc: 0.7734 - val_loss: 0.6980 - val_acc: 0.7390
#
# Epoch 00163: val_loss improved from 0.70104 to 0.69797, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 164/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5906 - acc: 0.7422 - val_loss: 0.6964 - val_acc: 0.7403
#
# Epoch 00164: val_loss improved from 0.69797 to 0.69641, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 165/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6289 - acc: 0.7344 - val_loss: 0.6939 - val_acc: 0.7431
#
# Epoch 00165: val_loss improved from 0.69641 to 0.69390, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 166/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5654 - acc: 0.7812 - val_loss: 0.6916 - val_acc: 0.7445
#
# Epoch 00166: val_loss improved from 0.69390 to 0.69160, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 167/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4570 - acc: 0.7812 - val_loss: 0.6890 - val_acc: 0.7459
#
# Epoch 00167: val_loss improved from 0.69160 to 0.68897, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 168/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5318 - acc: 0.8125 - val_loss: 0.6860 - val_acc: 0.7472
# Epoch 00168: val_loss improved from 0.68897 to 0.68599, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 169/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4812 - acc: 0.8281 - val_loss: 0.6832 - val_acc: 0.7472
#
# Epoch 00169: val_loss improved from 0.68599 to 0.68316, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 170/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5318 - acc: 0.7734 - val_loss: 0.6815 - val_acc: 0.7486
#
# Epoch 00170: val_loss improved from 0.68316 to 0.68145, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 171/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5306 - acc: 0.8047 - val_loss: 0.6786 - val_acc: 0.7514
#
# Epoch 00171: val_loss improved from 0.68145 to 0.67861, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 172/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5998 - acc: 0.7500 - val_loss: 0.6771 - val_acc: 0.7514
#
# Epoch 00172: val_loss improved from 0.67861 to 0.67714, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 173/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4701 - acc: 0.8047 - val_loss: 0.6746 - val_acc: 0.7514
#
# Epoch 00173: val_loss improved from 0.67714 to 0.67458, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 174/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.5210 - acc: 0.8281 - val_loss: 0.6721 - val_acc: 0.7514
#
# Epoch 00174: val_loss improved from 0.67458 to 0.67215, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 175/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4450 - acc: 0.8047 - val_loss: 0.6692 - val_acc: 0.7528
#
# Epoch 00175: val_loss improved from 0.67215 to 0.66924, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 176/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5192 - acc: 0.7891 - val_loss: 0.6670 - val_acc: 0.7528
#
# Epoch 00176: val_loss improved from 0.66924 to 0.66696, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 177/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6058 - acc: 0.7422 - val_loss: 0.6655 - val_acc: 0.7541
#
# Epoch 00177: val_loss improved from 0.66696 to 0.66545, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 178/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6090 - acc: 0.7266 - val_loss: 0.6635 - val_acc: 0.7541
#
# Epoch 00178: val_loss improved from 0.66545 to 0.66354, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 179/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5650 - acc: 0.7422 - val_loss: 0.6616 - val_acc: 0.7528
#
# Epoch 00179: val_loss improved from 0.66354 to 0.66162, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 180/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4853 - acc: 0.7969 - val_loss: 0.6596 - val_acc: 0.7528
#
# Epoch 00180: val_loss improved from 0.66162 to 0.65959, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 181/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4649 - acc: 0.8281 - val_loss: 0.6576 - val_acc: 0.7514
#
# Epoch 00181: val_loss improved from 0.65959 to 0.65761, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 182/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4881 - acc: 0.7891 - val_loss: 0.6556 - val_acc: 0.7514
#
# Epoch 00182: val_loss improved from 0.65761 to 0.65555, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 183/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4788 - acc: 0.8281 - val_loss: 0.6535 - val_acc: 0.7514
#
# Epoch 00183: val_loss improved from 0.65555 to 0.65346, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 184/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5381 - acc: 0.7344 - val_loss: 0.6516 - val_acc: 0.7528
#
# Epoch 00184: val_loss improved from 0.65346 to 0.65164, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 185/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5830 - acc: 0.7109 - val_loss: 0.6501 - val_acc: 0.7528
#
# Epoch 00185: val_loss improved from 0.65164 to 0.65013, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 186/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4799 - acc: 0.8125 - val_loss: 0.6483 - val_acc: 0.7528
#
# Epoch 00186: val_loss improved from 0.65013 to 0.64830, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 187/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5272 - acc: 0.7812 - val_loss: 0.6468 - val_acc: 0.7528
#
# Epoch 00187: val_loss improved from 0.64830 to 0.64679, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 188/2000
# 8/8 [==============================] - 2s 306ms/step - loss: 0.5858 - acc: 0.7734 - val_loss: 0.6449 - val_acc: 0.7528
#
# Epoch 00188: val_loss improved from 0.64679 to 0.64492, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 189/2000
# 8/8 [==============================] - 2s 306ms/step - loss: 0.5602 - acc: 0.7578 - val_loss: 0.6430 - val_acc: 0.7528
#
# Epoch 00189: val_loss improved from 0.64492 to 0.64301, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 190/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5432 - acc: 0.7891 - val_loss: 0.6411 - val_acc: 0.7528
#
# Epoch 00190: val_loss improved from 0.64301 to 0.64109, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 191/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5823 - acc: 0.7344 - val_loss: 0.6393 - val_acc: 0.7555
#
# Epoch 00191: val_loss improved from 0.64109 to 0.63926, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 192/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5573 - acc: 0.8047 - val_loss: 0.6374 - val_acc: 0.7555
#
# Epoch 00192: val_loss improved from 0.63926 to 0.63744, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 193/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5030 - acc: 0.8047 - val_loss: 0.6363 - val_acc: 0.7583
#
# Epoch 00193: val_loss improved from 0.63744 to 0.63628, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 194/2000
# ...
# Epoch 702/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5301 - acc: 0.7891 - val_loss: 0.5036 - val_acc: 0.7831
#
# Epoch 00702: val_loss improved from 0.50374 to 0.50356, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 703/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4706 - acc: 0.8047 - val_loss: 0.5037 - val_acc: 0.7818
#
# Epoch 00703: val_loss did not improve from 0.50356
# Epoch 704/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.6222 - acc: 0.7734 - val_loss: 0.5036 - val_acc: 0.7818
#
# Epoch 00704: val_loss did not improve from 0.50356
# Epoch 705/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6207 - acc: 0.7422 - val_loss: 0.5040 - val_acc: 0.7818
#
# Epoch 00705: val_loss did not improve from 0.50356
# Epoch 706/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4899 - acc: 0.8516 - val_loss: 0.5040 - val_acc: 0.7818
#
# Epoch 00706: val_loss did not improve from 0.50356
# Epoch 707/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4998 - acc: 0.7734 - val_loss: 0.5044 - val_acc: 0.7804
#
# Epoch 00707: val_loss did not improve from 0.50356
# Epoch 708/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5164 - acc: 0.7812 - val_loss: 0.5044 - val_acc: 0.7804
#
# Epoch 00708: val_loss did not improve from 0.50356
# Epoch 709/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5224 - acc: 0.7891 - val_loss: 0.5046 - val_acc: 0.7818
#
# Epoch 00709: val_loss did not improve from 0.50356
# Epoch 710/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4114 - acc: 0.8047 - val_loss: 0.5047 - val_acc: 0.7818
#
# Epoch 00710: val_loss did not improve from 0.50356
# Epoch 711/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5652 - acc: 0.7188 - val_loss: 0.5049 - val_acc: 0.7776
#
# Epoch 00711: val_loss did not improve from 0.50356
# Epoch 712/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6008 - acc: 0.7266 - val_loss: 0.5048 - val_acc: 0.7804
#
# Epoch 00712: val_loss did not improve from 0.50356
# Epoch 713/2000
# 8/8 [==============================] - 3s 362ms/step - loss: 0.4688 - acc: 0.7891 - val_loss: 0.5043 - val_acc: 0.7804
#
# Epoch 00713: val_loss did not improve from 0.50356
# Epoch 714/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4907 - acc: 0.7812 - val_loss: 0.5042 - val_acc: 0.7804
#
# Epoch 00714: val_loss did not improve from 0.50356
# Epoch 715/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.5506 - acc: 0.7578 - val_loss: 0.5042 - val_acc: 0.7804
#
# Epoch 00715: val_loss did not improve from 0.50356
# Epoch 716/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5236 - acc: 0.7812 - val_loss: 0.5040 - val_acc: 0.7804
#
# Epoch 00716: val_loss did not improve from 0.50356
# Epoch 717/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5145 - acc: 0.7812 - val_loss: 0.5035 - val_acc: 0.7804
#
# Epoch 00717: val_loss improved from 0.50356 to 0.50349, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 718/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6046 - acc: 0.7734 - val_loss: 0.5035 - val_acc: 0.7804
#
# Epoch 00718: val_loss did not improve from 0.50349
# Epoch 719/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4896 - acc: 0.7656 - val_loss: 0.5040 - val_acc: 0.7804
#
# Epoch 00719: val_loss did not improve from 0.50349
# Epoch 720/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.4101 - acc: 0.8438 - val_loss: 0.5040 - val_acc: 0.7804
#
# Epoch 00720: val_loss did not improve from 0.50349
# Epoch 721/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5240 - acc: 0.7812 - val_loss: 0.5041 - val_acc: 0.7790
#
# Epoch 00721: val_loss did not improve from 0.50349
# Epoch 722/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4726 - acc: 0.7891 - val_loss: 0.5042 - val_acc: 0.7790
#
# Epoch 00722: val_loss did not improve from 0.50349
# Epoch 723/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5462 - acc: 0.7969 - val_loss: 0.5039 - val_acc: 0.7790
#
# Epoch 00723: val_loss did not improve from 0.50349
# Epoch 724/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5305 - acc: 0.8047 - val_loss: 0.5036 - val_acc: 0.7790
#
# Epoch 00724: val_loss did not improve from 0.50349
# Epoch 725/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5284 - acc: 0.7734 - val_loss: 0.5036 - val_acc: 0.7790
#
# Epoch 00725: val_loss did not improve from 0.50349
# Epoch 726/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4972 - acc: 0.7891 - val_loss: 0.5036 - val_acc: 0.7790
#
# Epoch 00726: val_loss did not improve from 0.50349
# Epoch 727/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6207 - acc: 0.7578 - val_loss: 0.5032 - val_acc: 0.7804
#
# Epoch 00727: val_loss improved from 0.50349 to 0.50319, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 728/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6588 - acc: 0.6953 - val_loss: 0.5033 - val_acc: 0.7790
#
# Epoch 00728: val_loss did not improve from 0.50319
# Epoch 729/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5031 - acc: 0.7656 - val_loss: 0.5035 - val_acc: 0.7790
#
# Epoch 00729: val_loss did not improve from 0.50319
# Epoch 730/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6044 - acc: 0.7578 - val_loss: 0.5035 - val_acc: 0.7790
#
# Epoch 00730: val_loss did not improve from 0.50319
# Epoch 731/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6277 - acc: 0.7500 - val_loss: 0.5036 - val_acc: 0.7804
#
# Epoch 00731: val_loss did not improve from 0.50319
# Epoch 732/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6932 - acc: 0.6875 - val_loss: 0.5037 - val_acc: 0.7804
#
# Epoch 00732: val_loss did not improve from 0.50319
# Epoch 733/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.6158 - acc: 0.7344 - val_loss: 0.5037 - val_acc: 0.7804
#
# Epoch 00733: val_loss did not improve from 0.50319
# Epoch 734/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.6990 - acc: 0.7422 - val_loss: 0.5034 - val_acc: 0.7818
#
# Epoch 00734: val_loss did not improve from 0.50319
# Epoch 735/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.6656 - acc: 0.7344 - val_loss: 0.5031 - val_acc: 0.7818
#
# Epoch 00735: val_loss improved from 0.50319 to 0.50312, saving model to ../models/MobileNet-ModelCheckpointWeights.h5
# Epoch 736/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.6451 - acc: 0.7500 - val_loss: 0.5033 - val_acc: 0.7818
#
# Epoch 00736: val_loss did not improve from 0.50312
# Epoch 737/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5571 - acc: 0.7500 - val_loss: 0.5036 - val_acc: 0.7818
#
# Epoch 00737: val_loss did not improve from 0.50312
# Epoch 738/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4898 - acc: 0.8047 - val_loss: 0.5034 - val_acc: 0.7818
#
# Epoch 00738: val_loss did not improve from 0.50312
# Epoch 739/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5185 - acc: 0.8047 - val_loss: 0.5033 - val_acc: 0.7818
#
# Epoch 00739: val_loss did not improve from 0.50312
# Epoch 740/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4513 - acc: 0.7969 - val_loss: 0.5034 - val_acc: 0.7818
#
# Epoch 00740: val_loss did not improve from 0.50312
# Epoch 741/2000
# 8/8 [==============================] - 2s 306ms/step - loss: 0.5086 - acc: 0.7734 - val_loss: 0.5032 - val_acc: 0.7818
#
# Epoch 00741: val_loss did not improve from 0.50312
# Epoch 742/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6001 - acc: 0.7188 - val_loss: 0.5031 - val_acc: 0.7804
#
# Epoch 00742: val_loss did not improve from 0.50312
# Epoch 743/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4563 - acc: 0.8203 - val_loss: 0.5032 - val_acc: 0.7804
#
# Epoch 00743: val_loss did not improve from 0.50312
# Epoch 744/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.5066 - acc: 0.7812 - val_loss: 0.5034 - val_acc: 0.7804
#
# Epoch 00744: val_loss did not improve from 0.50312
# Epoch 745/2000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.5520 - acc: 0.7891 - val_loss: 0.5035 - val_acc: 0.7804
#
# Epoch 00745: val_loss did not improve from 0.50312
# Epoch 746/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6066 - acc: 0.7656 - val_loss: 0.5036 - val_acc: 0.7804
#
# Epoch 00746: val_loss did not improve from 0.50312
# Epoch 747/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5918 - acc: 0.7109 - val_loss: 0.5038 - val_acc: 0.7804
#
# Epoch 00747: val_loss did not improve from 0.50312
# Epoch 748/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5405 - acc: 0.7812 - val_loss: 0.5036 - val_acc: 0.7804
#
# Epoch 00748: val_loss did not improve from 0.50312
# Epoch 749/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.3928 - acc: 0.8281 - val_loss: 0.5039 - val_acc: 0.7804
#
# Epoch 00749: val_loss did not improve from 0.50312
# Epoch 750/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4391 - acc: 0.8203 - val_loss: 0.5040 - val_acc: 0.7804
#
# Epoch 00750: val_loss did not improve from 0.50312
# Epoch 751/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5242 - acc: 0.7578 - val_loss: 0.5040 - val_acc: 0.7804
#
# Epoch 00751: val_loss did not improve from 0.50312
# Epoch 752/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5731 - acc: 0.7656 - val_loss: 0.5035 - val_acc: 0.7804
#
# Epoch 00752: val_loss did not improve from 0.50312
# Epoch 753/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4145 - acc: 0.8438 - val_loss: 0.5038 - val_acc: 0.7804
#
# Epoch 00753: val_loss did not improve from 0.50312
# Epoch 754/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5243 - acc: 0.7812 - val_loss: 0.5038 - val_acc: 0.7804
#
# Epoch 00754: val_loss did not improve from 0.50312
# Epoch 755/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5372 - acc: 0.7969 - val_loss: 0.5040 - val_acc: 0.7804
#
# Epoch 00755: val_loss did not improve from 0.50312
# Epoch 756/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4309 - acc: 0.7969 - val_loss: 0.5041 - val_acc: 0.7804
#
# Epoch 00756: val_loss did not improve from 0.50312
# Epoch 757/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5388 - acc: 0.7891 - val_loss: 0.5040 - val_acc: 0.7804
#
# Epoch 00757: val_loss did not improve from 0.50312
# Epoch 758/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4907 - acc: 0.7969 - val_loss: 0.5042 - val_acc: 0.7804
#
# Epoch 00758: val_loss did not improve from 0.50312
# Epoch 759/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4855 - acc: 0.7578 - val_loss: 0.5041 - val_acc: 0.7790
#
# Epoch 00759: val_loss did not improve from 0.50312
# Epoch 760/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4997 - acc: 0.8125 - val_loss: 0.5043 - val_acc: 0.7790
#
# Epoch 00760: val_loss did not improve from 0.50312
# Epoch 761/2000
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4489 - acc: 0.8359 - val_loss: 0.5041 - val_acc: 0.7804
#
# Epoch 00761: val_loss did not improve from 0.50312
# Epoch 762/2000
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4651 - acc: 0.8281 - val_loss: 0.5044 - val_acc: 0.7790
#
# Epoch 00762: val_loss did not improve from 0.50312
# Epoch 763/2000
# 8/8 [==============================] - 2s 304ms/step - loss: 0.5614 - acc: 0.7969 - val_loss: 0.5046 - val_acc: 0.7804
#
# Epoch 00763: val_loss did not improve from 0.50312
# Epoch 764/2000
# 8/8 [==============================] - 3s 368ms/step - loss: 0.4409 - acc: 0.7969 - val_loss: 0.5045 - val_acc: 0.7790
#
# Epoch 00764: val_loss did not improve from 0.50312
# Epoch 765/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6325 - acc: 0.7344 - val_loss: 0.5045 - val_acc: 0.7790
#
# Epoch 00765: val_loss did not improve from 0.50312
# Epoch 766/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5693 - acc: 0.7734 - val_loss: 0.5049 - val_acc: 0.7790
#
# Epoch 00766: val_loss did not improve from 0.50312
# Epoch 767/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5199 - acc: 0.7734 - val_loss: 0.5049 - val_acc: 0.7790
#
# Epoch 00767: val_loss did not improve from 0.50312
# Epoch 768/2000
# 8/8 [==============================] - 3s 314ms/step - loss: 0.5291 - acc: 0.7812 - val_loss: 0.5048 - val_acc: 0.7804
#
# Epoch 00768: val_loss did not improve from 0.50312
# Epoch 769/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.6281 - acc: 0.7266 - val_loss: 0.5048 - val_acc: 0.7804
#
# Epoch 00769: val_loss did not improve from 0.50312
# Epoch 770/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5633 - acc: 0.7812 - val_loss: 0.5046 - val_acc: 0.7804
#
# Epoch 00770: val_loss did not improve from 0.50312
# Epoch 771/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5528 - acc: 0.7812 - val_loss: 0.5048 - val_acc: 0.7804
#
# Epoch 00771: val_loss did not improve from 0.50312
# Epoch 772/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4412 - acc: 0.8516 - val_loss: 0.5048 - val_acc: 0.7804
#
# Epoch 00772: val_loss did not improve from 0.50312
# Epoch 773/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6853 - acc: 0.7109 - val_loss: 0.5049 - val_acc: 0.7776
#
# Epoch 00773: val_loss did not improve from 0.50312
# Epoch 774/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5392 - acc: 0.7578 - val_loss: 0.5044 - val_acc: 0.7804
#
# Epoch 00774: val_loss did not improve from 0.50312
# Epoch 775/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.4492 - acc: 0.8359 - val_loss: 0.5044 - val_acc: 0.7790
#
# Epoch 00775: val_loss did not improve from 0.50312
# Epoch 776/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5618 - acc: 0.7734 - val_loss: 0.5042 - val_acc: 0.7790
#
# Epoch 00776: val_loss did not improve from 0.50312
# Epoch 777/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5590 - acc: 0.7891 - val_loss: 0.5039 - val_acc: 0.7804
#
# Epoch 00777: val_loss did not improve from 0.50312
# Epoch 778/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4175 - acc: 0.8516 - val_loss: 0.5038 - val_acc: 0.7804
#
# Epoch 00778: val_loss did not improve from 0.50312
# Epoch 779/2000
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4046 - acc: 0.8516 - val_loss: 0.5040 - val_acc: 0.7804
#
# Epoch 00779: val_loss did not improve from 0.50312
# Epoch 780/2000
# 8/8 [==============================] - 3s 313ms/step - loss: 0.5801 - acc: 0.7656 - val_loss: 0.5042 - val_acc: 0.7790
#
# Epoch 00780: val_loss did not improve from 0.50312
# Epoch 781/2000
# 8/8 [==============================] - 2s 311ms/step - loss: 0.5896 - acc: 0.7500 - val_loss: 0.5043 - val_acc: 0.7790
#
# Epoch 00781: val_loss did not improve from 0.50312
# Epoch 782/2000
# 8/8 [==============================] - 2s 310ms/step - loss: 0.5851 - acc: 0.7344 - val_loss: 0.5044 - val_acc: 0.7790
#
# Epoch 00782: val_loss did not improve from 0.50312
# Epoch 783/2000
# 8/8 [==============================] - 2s 312ms/step - loss: 0.4679 - acc: 0.8281 - val_loss: 0.5045 - val_acc: 0.7804
#
# Epoch 00783: val_loss did not improve from 0.50312
# Epoch 784/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5695 - acc: 0.7344 - val_loss: 0.5048 - val_acc: 0.7790
#
# Epoch 00784: val_loss did not improve from 0.50312
# Epoch 785/2000
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4361 - acc: 0.8359 - val_loss: 0.5045 - val_acc: 0.7790
#
# Epoch 00785: val_loss did not improve from 0.50312
# Epoch 00785: early stopping

# %%
print(mobile_net.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Model) (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 1, 1, 1280)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               327936
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# Output (Dense)               (None, 3)                 771
# =================================================================
# Total params: 2,586,691
# Trainable params: 328,707
# Non-trainable params: 2,257,984
# _________________________________________________________________
# None

# %% [markdown]
# ### Loss and Accuracy

# %%
Viz.plot_loss_accuracy(mobile_net_history)

# %% [markdown]
# ### ROC and AUC

# %%
if var.img_type == 'grey': 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 1)
else: 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 3)
    
    
mobilenet = get_mobile_net(dim)
mobilenet.load_weights('../models/MobileNet-ModelCheckpointWeights.h5') #load the best weights before overfitting

Viz.plot_roc_auc(mobilenet, x_test, y_test)
# Out:
# C:\Users\Heeeb\Anaconda3\lib\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# F1 Scores Test
# ~~~~~~~~~~~~~~~~~~~~~~
# No Weapon: 0.8860353130016051
# HandGun: 0.7553366174055829
# Rifle: 0.5555555555555557

# %% [markdown]
# ### Confusion Matrix

# %%
if var.img_type == 'grey': 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 1)
else: 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 3)
    
    
mobilenet = get_mobile_net(dim)
mobilenet.load_weights('../models/MobileNet-ModelCheckpointWeights.h5') #load the best weights before overfitting





y_test_prob = [np.argmax(i) for i in mobilenet.predict(x_test)]
y_test_labels = [np.argmax(
    i) for i in y_test]
test_cnf = confusion_matrix(y_test_labels, y_test_prob)

y_train_prob = [np.argmax(i) for i in mobilenet.predict(x_train)]
y_train_labels = [np.argmax(i) for i in y_train]
train_cnf = confusion_matrix(y_train_labels, y_train_prob)

Viz.plot_model_cm(test_cnf, train_cnf, classes = ['No Weapon', 'Handgun', 'Rifle'])
# Out:
# C:\Users\Heeeb\Anaconda3\lib\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '

# %%
# assert False

# %% [markdown]
# ### Test on Google

# %%
import cv2
from lime import lime_image

# %%
base_path = '../Tests/Photos'
if var.img_type == 'grey': 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 1)
else: 
    dim = (var.mobilenet_dimension[0], var.mobilenet_dimension[1], 3)
    
    
mobilenet = get_mobile_net(dim)
mobilenet.load_weights('../models/MobileNet-ModelCheckpointWeights.h5') #load the best weights before overfitting

for file in os.listdir(base_path): 
    if file == '.ipynb_checkpoints':
        continue
    full_path = f'{base_path}/{file}'
    img = Functions.get_image_value(full_path, var.mobilenet_dimension, var.img_type)
    img = img.reshape(1, img.shape[0], img.shape[1], img.shape[2])
    pred = mobilenet.predict(img)[0]
    print(f'{file}\t\t{np.argmax(pred)}\t\t{pred.max()}\t\t{pred}')
# Out:
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"
# C:\Users\Heeeb\Anaconda3\lib\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# AR.jpg		2		0.8876814246177673		[0.0606606  0.05165793 0.8876814 ]
# NonGun.jpeg		2		0.7327125668525696		[0.16004795 0.10723949 0.73271257]
# Pistol.jpg		1		0.9563262462615967		[0.02489684 0.95632625 0.01877694]
# Pistol2.jpg		0		0.8669840097427368		[0.866984   0.10398667 0.02902921]
# Pistol3.jpg		1		0.7548778057098389		[0.02969078 0.7548778  0.21543148]

# %%
img = GetPickles.get_image_value('../TestImages/AR.jpg', var.mobilenet_dimension, var.img_type)

explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(img, mobilenet.predict, top_labels = 5, hide_color = 0, 
                                         num_samples = 1000)

temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only = False,
                                           num_features = 10, hide_rest = False)
plt.imshow(mark_boundaries(temp/2 + .5, mask))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
Functions.get_prediction_bounding_box('../TestImages/AR.jpg', mobilenet, var.mobilenet_dimension)
# Out:
# ../TestImages/AR.jpg		2||Rifle		0.8876814246177673		[0.0606606  0.05165793 0.8876814 ]

# %%
assert False

# %%
from tqdm import tqdm
def get_vid_prediction_bounding_box(path, model, dim): 
    vid = cv2.VideoCapture(path)
    total_frames = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
    pbar = tqdm(total = total_frames, desc = f'Splitting Video Into {total_frames} Frames')
    images = [] 
    sucess =1 
    while True: 
        try:
            success, img = vid.read() 
            img = cv2.resize(img, dim, interpolation = cv2.INTER_CUBIC)
            images.append(img)
            pbar.update(1)
        except: 
            break
        

    pbar.close()
    print(total_frames)
    print(np.array(images).shape)
    return np.array(images)
   



images = get_vid_prediction_bounding_box('../Tests/Videos/Pistol.mp4', mobilenet, var.mobilenet_dimension)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2322/2322 [00:07<00:00, 308.71it/s]
# 2322
# (2322, 224, 224, 3)

# %%
predictions = mobilenet.predict(images)

# %%
model = mobilenet
pbar = tqdm(list(zip(predictions, images)), desc= 'Getting Base Prediction and Extracting Sliding Window... Sit Back, This Will Take A While')
windows_prob = []
for pred, img in pbar: 
    category_dict = {0: 'No Weapon', 1: 'Handgun', 2: 'Rifle'}
    cat_index = np.argmax(pred)
    cat = category_dict[cat_index]
    
    ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
    ss.setBaseImage(img)
    ss.switchToSelectiveSearchFast()
    rects = ss.process() 

    windows = []
    locations = []
    for x, y, w,h in rects: 
        startx = x 
        starty = y 
        endx = x+w 
        endy = y+h 
        roi = img[starty:endy, startx:endx]
        roi = cv2.resize(roi, dsize =var.mobilenet_dimension, interpolation = cv2.INTER_CUBIC)
        windows.append(roi)
        locations.append((startx, starty, endx, endy))

    windows = np.array(windows)

    predictions = model.predict(windows)

    clone = img.copy()
    cat_predictions = predictions[:,cat_index]
    pred_max_idx = np.argmax(cat_predictions)
    pred_max = cat_predictions[pred_max_idx]
    
    pred_max_window = locations[pred_max_idx]
    startx, starty, endx, endy = pred_max_window
    
    windows_prob.append((cat, (startx, starty, endx, endy)))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2322/2322 [1:27:25<00:00,  2.26s/it]

# %%
import pickle 
pickle.dump(windows_prob, open('../Pickles/WindowsPropPistol.p', 'wb'))

# %%
for i in windows_prob: 
    if i[0] != 'No Weapon': 
        print(i)

# %%
count = 0 
success = 1 
images = []
while success: 
    success, img = vid.read()
    orig_img = img
    orig_img = cv2.resize(img, var.mobilenet_dimension, interpolation = cv2.INTER_CUBIC)
    orig_img = orig_img.reshape(1, orig_img.shape[0], orig_img.shape[1], orig_img.shape[2])
    pred = mobilenet.predict(orig_img)[0]
    category_dict = {0: 'No Weapon', 1: 'Handgun', 2: 'Rifle'}
    cat_index = np.argmax(pred)
    cat = category_dict[cat_index]

    print(f'{cat_index}||{cat}\t\t{pred.max()}\t\t{pred}')


    break
#     cv2.imwrite(f'../Tests/VideoFrames/{count}.jpg', image)
    count += 1
# Out:
# 0||No Weapon		0.9197449088096619		[0.9197449  0.03330551 0.04694955]

# %%
img = get_image_value(path, dim, var.img_type)
img = img.reshape(1, img.shape[0], img.shape[1], img.shape[2])
pred = model.predict(img)[0]

category_dict = {0: 'No Weapon', 1: 'Handgun', 2: 'Rifle'}
cat_index = np.argmax(pred)
cat = category_dict[cat_index]

print(f'{path}\t\t{cat_index}||{cat}\t\t{pred.max()}\t\t{pred}')


img = cv2.imread(path)
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
ss.setBaseImage(img)
ss.switchToSelectiveSearchFast()
rects = ss.process() 

windows = []
locations = []
for x, y, w,h in rects: 
    startx = x 
    starty = y 
    endx = x+w 
    endy = y+h 
    roi = img[starty:endy, startx:endx]
    roi = cv2.resize(roi, dsize =var.mobilenet_dimension, interpolation = cv2.INTER_CUBIC)
    windows.append(roi)
    locations.append((startx, starty, endx, endy))

windows = np.array(windows)

predictions = model.predict(windows)

clone = img.copy()
cat_predictions = predictions[:,cat_index]
pred_max_idx = np.argmax(cat_predictions)
pred_max = cat_predictions[pred_max_idx]

pred_max_window = locations[pred_max_idx]
startx, starty, endx, endy = pred_max_window
cv2.rectangle(clone, (startx, starty), (endx, endy),  (0,255,0),2)

text = f'{cat}'
cv2.putText(clone, text, (startx, starty), cv2.FONT_HERSHEY_SIMPLEX, .45, (0,255,0),2)


cv2.imshow(f'{cat}', clone)
cv2.waitKey(0)
