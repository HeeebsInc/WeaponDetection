# %%
import pandas as pd
import numpy as np 
import os
import glob
import xml.etree.ElementTree as ET

# %%
def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for member in root.findall('object'):
            value = (root.find('filename').text,
                     int(root.find('size')[0].text),
                     int(root.find('size')[1].text),
                     member[0].text,
                     int(member[4][0].text),
                     int(member[4][1].text),
                     int(member[4][2].text),
                     int(member[4][3].text)
                     )
            xml_list.append(value)
    column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df


def main():
    for folder in ['train', 'test']:
        image_path = os.path.join(os.getcwd(), ('images/' + folder))
        xml_df = xml_to_csv(image_path)
        xml_df.to_csv(('images/'+folder+'_labels.csv'), index=None)
    print('Successfully converted xml to csv.')


df = xml_to_csv('../100_1/Labels')

# %%
def get_labels(x): 
    x = x[:-4]
    x = 'Labels/' + x + '.xml'
    return x 

df['xml'] = df.filename.map(get_labels)

# %%
df
# Out:
#                        filename  width  height class  xmin  ymin  xmax  ymax  \
# 0                 armas (2).jpg    259     194   Gun    17    28   222   172
# 1               armas (512).jpg    192     203   Gun    63    26    87    44
# 2    Assault_Rifle_1415_116.jpg    500     333   Gun    92   290   421   320
# 3    Assault_Rifle_1415_116.jpg    500     333   Gun   133   225   313   244
# 4        Assault_Rifle_1_13.jpg    600     323   Gun     1    94   567   323
# ..                          ...    ...     ...   ...   ...   ...   ...   ...
# 131    Assault_Rifle_722_33.jpg    600     255   Gun   236    39   323   172
# 132    Assault_Rifle_1628_8.jpg    600     251   Gun   445   120   469   155
# 133    Assault_Rifle_1628_8.jpg    600     251   Gun   208    75   264   147
# 134            armas (2781).jpg    634     350   Gun   199   161   272   219
# 135   Assault_Rifle_1379_13.jpg    600     338   Gun   216    54   380   256
#
#                                    xml
# 0                 Labels/armas (2).xml
# 1               Labels/armas (512).xml
# 2    Labels/Assault_Rifle_1415_116.xml
# 3    Labels/Assault_Rifle_1415_116.xml
# 4        Labels/Assault_Rifle_1_13.xml
# ..                                 ...
# 131    Labels/Assault_Rifle_722_33.xml
# 132    Labels/Assault_Rifle_1628_8.xml
# 133    Labels/Assault_Rifle_1628_8.xml
# 134            Labels/armas (2781).xml
# 135   Labels/Assault_Rifle_1379_13.xml
#
# [136 rows x 9 columns]

# %%
df.to_csv('../100_1/PATHS.csv')
