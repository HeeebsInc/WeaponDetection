# %%
import pandas as pd
import numpy as np 
import os
import glob
import xml.etree.ElementTree as ET

# %%
# print(len(os.listdir('../Combined/Labels')))

# %%
def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for member in root.findall('object'):
            value = (root.find('filename').text,
                     int(root.find('size')[0].text),
                     int(root.find('size')[1].text),
                     member[0].text,
                     int(member[4][0].text),
                     int(member[4][1].text),
                     int(member[4][2].text),
                     int(member[4][3].text)
                     )
            xml_list.append(value)
    column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df


df = xml_to_csv('../Separated/Labels')

# %%
def get_labels(x): 
    x = x[:-4]
    x = 'Labels/' + x + '.xml'
    return x 

df['xml'] = df.filename.map(get_labels)

# %%
df
# Out:
#                    filename  width  height class  xmin  ymin  xmax  ymax  \
# 0             armas (2).jpg    259     194   Gun    17    28   222   172
# 1           armas (230).jpg   1067     854   Gun   636   214   748   279
# 2           armas (231).jpg    425     260   Gun   171   218   218   260
# 3           armas (232).jpg    434     578   Gun   285   192   328   239
# 4           armas (233).jpg   1600     974   Gun   454   694   591   787
# 5           armas (249).jpg    432     324   Gun   195   119   256   168
# 6          armas (2781).jpg    634     350   Gun   199   161   272   219
# 7          armas (2861).jpg    699     311   Gun     1   208    36   284
# 8          armas (2861).jpg    699     311   Gun   176   237   209   311
# 9          armas (2862).jpg    650     366   Gun   390   184   406   213
# 10         armas (2906).jpg    640     360   Gun   346   172   378   202
# 11         armas (2922).jpg    640     360   Gun   153   263   179   298
# 12         armas (2922).jpg    640     360   Gun   208   272   238   304
# 13         armas (2923).jpg    113     168   Gun    41    26    97    63
# 14         armas (2924).jpg    531     333   Gun   256   140   292   171
# 15         armas (2933).jpg   1300    1031   Gun   394   167  1052   956
# 16         armas (2942).jpg    553     422   Gun   212   102   261   147
# 17         armas (2946).jpg    640     380   Gun   190    55   204    78
# 18         armas (2946).jpg    640     380   Gun   510    34   524    90
# 19         armas (2947).jpg    640     380   Gun   230    70   269    98
# 20         armas (2947).jpg    640     380   Gun   477    66   487    89
# 21         armas (2992).jpg    450     300   Gun   274    80   317   130
# 22            armas (5).jpg   1300     866   Gun   365     5   826   600
# 23          armas (510).jpg    300     168   Gun   174    71   201    94
# 24          armas (512).jpg    192     203   Gun    63    26    87    44
# 25          armas (537).jpg    260     194   Gun    50   140   108   171
# 26      Assault_Rifle_0.jpg    500     126  Guns     2     5   500   120
# 27      Assault_Rifle_1.jpg    400     238  Guns    21    22   374   215
# 28     Assault_Rifle_10.jpg    450     144  Guns     2     3   450   140
# 29    Assault_Rifle_100.jpg    450     132  Guns     2     2   450   132
# ...                     ...    ...     ...   ...   ...   ...   ...   ...
# 6172       Pistol_97_93.jpg    601     257  Guns    62   170   311   257
# 6173       Pistol_97_93.jpg    601     257  Guns    27   118    50   159
# 6174      Pistol_981_42.jpg    600     251  Guns   139    93   264   214
# 6175      Pistol_981_43.jpg    600     249   Gun   102    51   198   132
# 6176      Pistol_981_50.jpg    600     250  Guns   278    87   337   145
# 6177      Pistol_981_80.jpg    600     338   Gun    19   122   392   242
# 6178      Pistol_983_14.jpg    600     248  Guns   296   100   513   199
# 6179      Pistol_983_16.jpg    601     248  Guns   388    85   473   166
# 6180      Pistol_983_31.jpg    600     248  Guns   107    65   136   114
# 6181      Pistol_983_31.jpg    600     248  Guns   249    64   290    90
# 6182      Pistol_983_42.jpg    500     485  Guns    10     3    65    92
# 6183      Pistol_983_44.jpg    300     463  Guns    85   357   113   441
# 6184      Pistol_983_46.jpg    600     251   Gun   434   122   539   214
# 6185      Pistol_983_52.jpg    600     250   Gun   339   124   433   160
# 6186      Pistol_983_52.jpg    600     250   Gun   356   161   388   198
# 6187      Pistol_983_52.jpg    600     250   Gun   148   140   174   177
# 6188      Pistol_983_62.jpg    600     251  Guns   187   158   404   251
# 6189      Pistol_983_63.jpg    600     251  Guns   142   100   272   183
# 6190      Pistol_983_67.jpg    601     252  Guns   107   129   235   252
# 6191      Pistol_983_68.jpg    601     252  Guns   168    96   269   252
# 6192      Pistol_983_76.jpg    602     252  Guns   277    53   544   159
# 6193       Pistol_991_8.jpg    601     255  Guns   143    86   162   120
# 6194       Pistol_991_8.jpg    601     255  Guns   419    43   497    97
# 6195      Pistol_993_43.jpg    600     253   Gun   322   135   530   253
# 6196      Pistol_993_57.jpg    600     253   Gun   132    82   222   253
# 6197       Pistol_993_9.jpg    600     253   Gun   162    19   600   253
# 6198      Pistol_996_35.jpg    500     386  Guns   258   135   338   181
# 6199      Pistol_996_35.jpg    500     386  Guns   221   191   260   304
# 6200      Pistol_996_54.jpg    500     386  Guns    98    15   142   336
# 6201      Pistol_996_72.jpg    500     389   Gun   135   211   200   328
#
#                                xml
# 0             Labels/armas (2).xml
# 1           Labels/armas (230).xml
# 2           Labels/armas (231).xml
# 3           Labels/armas (232).xml
# 4           Labels/armas (233).xml
# 5           Labels/armas (249).xml
# 6          Labels/armas (2781).xml
# 7          Labels/armas (2861).xml
# 8          Labels/armas (2861).xml
# 9          Labels/armas (2862).xml
# 10         Labels/armas (2906).xml
# 11         Labels/armas (2922).xml
# 12         Labels/armas (2922).xml
# 13         Labels/armas (2923).xml
# 14         Labels/armas (2924).xml
# 15         Labels/armas (2933).xml
# 16         Labels/armas (2942).xml
# 17         Labels/armas (2946).xml
# 18         Labels/armas (2946).xml
# 19         Labels/armas (2947).xml
# 20         Labels/armas (2947).xml
# 21         Labels/armas (2992).xml
# 22            Labels/armas (5).xml
# 23          Labels/armas (510).xml
# 24          Labels/armas (512).xml
# 25          Labels/armas (537).xml
# 26      Labels/Assault_Rifle_0.xml
# 27      Labels/Assault_Rifle_1.xml
# 28     Labels/Assault_Rifle_10.xml
# 29    Labels/Assault_Rifle_100.xml
# ...                            ...
# 6172       Labels/Pistol_97_93.xml
# 6173       Labels/Pistol_97_93.xml
# 6174      Labels/Pistol_981_42.xml
# 6175      Labels/Pistol_981_43.xml
# 6176      Labels/Pistol_981_50.xml
# 6177      Labels/Pistol_981_80.xml
# 6178      Labels/Pistol_983_14.xml
# 6179      Labels/Pistol_983_16.xml
# 6180      Labels/Pistol_983_31.xml
# 6181      Labels/Pistol_983_31.xml
# 6182      Labels/Pistol_983_42.xml
# 6183      Labels/Pistol_983_44.xml
# 6184      Labels/Pistol_983_46.xml
# 6185      Labels/Pistol_983_52.xml
# 6186      Labels/Pistol_983_52.xml
# 6187      Labels/Pistol_983_52.xml
# 6188      Labels/Pistol_983_62.xml
# 6189      Labels/Pistol_983_63.xml
# 6190      Labels/Pistol_983_67.xml
# 6191      Labels/Pistol_983_68.xml
# 6192      Labels/Pistol_983_76.xml
# 6193       Labels/Pistol_991_8.xml
# 6194       Labels/Pistol_991_8.xml
# 6195      Labels/Pistol_993_43.xml
# 6196      Labels/Pistol_993_57.xml
# 6197       Labels/Pistol_993_9.xml
# 6198      Labels/Pistol_996_35.xml
# 6199      Labels/Pistol_996_35.xml
# 6200      Labels/Pistol_996_54.xml
# 6201      Labels/Pistol_996_72.xml
#
# [6202 rows x 9 columns]

# %%
df.to_csv('../Separated/PATHS.csv')
